# %%
import tensorflow as tf
from keras import regularizers
from keras.callbacks import EarlyStopping
import tensorflow_model_optimization as tfmot
import keras
import keras as sparsity
from sklearn.model_selection import GridSearchCV
import pandas as pd
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras

# %%
# Setting the random seed so there is consistent data splitting between runs
tf.random.set_seed(42)
# importing the lowPPM matrix
allData = r"../../Output/LowPPMMatrix.csv"

# Reading in the data to csv and removing any data at 150 ppm as this was incorrect data from testing
# NOTE: the 150 ppm is not in all outputs. but it is left in as a safeguard
df = pd.read_csv(allData)
df=df[df['Target PPM']!=150]
# Dropping all unneeded columns from the output
df = df.drop(columns=['Unnamed: 0','lowInterval','highInterval','Ratio'])
print(df.head())

# Declaring what sensor is used for the test set
test_sensor_id = 0  # Replace with the ID of the sensor you want in the test set
train_data = df[df['SensorID'] != test_sensor_id]
test_data = df[df['SensorID'] == test_sensor_id]

# Drop the SensorID column as we don't need it anymore
train_data = train_data.drop(columns=['SensorID'])
test_data = test_data.drop(columns=['SensorID'])
# Convert to TensorFlow tensors
train_data_tf = tf.convert_to_tensor(train_data, dtype=tf.float32)
test_data_tf = tf.convert_to_tensor(test_data, dtype=tf.float32)
# Out:
#    SensorID  Target PPM  Resistance  Temperature  RelativeHumidity
# 0       0.0         0.0    7.812575     35.42292         45.221903
# 1       1.0         0.0    7.314638     35.42292         45.221903
# 2       2.0         0.0    6.600787     35.42292         45.221903
# 3       3.0         0.0    6.089138     35.42292         45.221903
# 4       4.0         0.0    6.809271     35.42292         45.221903

# %%
# Randomizes the data for training to minimize fitting to false trends
train_data_shuffled = tf.random.shuffle(train_data_tf, seed=42)

# Separate features and labels
x_train, y_train = train_data_shuffled[:, 1:], train_data_shuffled[:, 0]
x_test, y_test = test_data_tf[:, 1:], test_data_tf[:, 0]

# %%
@keras.saving.register_keras_serializable()
def mse_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_pred - y_true))

@keras.saving.register_keras_serializable()
def rmse(y_true, y_pred):
    return tf.sqrt(mse_loss(y_pred, y_true))

@keras.saving.register_keras_serializable()
def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# Used to trace history of RMSE as the neural network gets trained
class RMSEHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE = []
        self.validationRMSE = []

    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE.append(logs.get('rmse'))
        self.validationRMSE.append(logs.get('val_rmse'))

# %%
rmse_history = RMSEHistory()
# Compile and train the model
input_shape = (x_train.shape[1],)

# %%
# Initialize a CSV file to store the results
csvfile = open('experiment_results.csv', 'w', newline='')
csvwriter = csv.writer(csvfile)
csvwriter.writerow(['BaseNum', 'Run', 'Test_RMSE', 'Test_Accuracy'])

for baseNum in tqdm(range(1, 16), desc='BaseNum Loop'):  # Wrap outer loop with tqdm
    for run in tqdm(range(1, 101), desc=f'Run Loop for BaseNum {baseNum}', leave=False):  # Wrap inner loop with tqdm

# Define your original model with regularization
        def build_model(input_shape, regularization_factor=0.01):
            model = tf.keras.Sequential([
                tf.keras.layers.Dense(baseNum*2, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
                tf.keras.layers.Dense(baseNum*4, activation='mish', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(1)
            ])
            return model

        with tf.device('/GPU:0'):
            model = build_model(input_shape)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[rmse_history],verbose=0)
            test_metrics = model.evaluate(x_test, y_test,verbose=0)
            test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
        # Save the results
        csvwriter.writerow([baseNum, run, test_rmse, test_accuracy])
        csvfile.flush()
csvfile.close()

# %%
df1 = pd.read_csv("./experiment_results.csv")

# Create a figure and axis object for the boxplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Create a boxplot for Test_RMSE grouped by BaseNum
df1.boxplot(column='Test_RMSE', by='BaseNum', ax=ax[0])
ax[0].set_title('Boxplot of Test_RMSE Grouped by BaseNum')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Test_RMSE')

# Create a boxplot for Test_Accuracy grouped by BaseNum
df1.boxplot(column='Test_Accuracy', by='BaseNum', ax=ax[1])
ax[1].set_title('Boxplot of Test_Accuracy Grouped by BaseNum')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Test_Accuracy')

# Show the plots
plt.suptitle('Boxplots Grouped by BaseNum')
plt.show()

# Group by BaseNum and calculate the mean
grouped_means = df1.groupby('BaseNum').mean()

# Create a figure and axis objects
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the mean of Test_RMSE
ax[0].plot(grouped_means.index, grouped_means['Test_RMSE'], label='Test_RMSE', marker='o')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Mean of Test_RMSE')
ax[0].set_title('Mean of Test_RMSE Grouped by BaseNum')
ax[0].legend()

# Plot the mean of Test_Accuracy
ax[1].plot(grouped_means.index, grouped_means['Test_Accuracy'], label='Test_Accuracy', marker='x')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Mean of Test_Accuracy')
ax[1].set_title('Mean of Test_Accuracy Grouped by BaseNum')
ax[1].legend()

# Show the plot
plt.show()

# %%
import random
from keras.src.losses import mean_squared_error

activation_functions = ['relu', 'sigmoid', 'elu', 'selu', 'swish', 'linear']

best_activation = None
lowest_mse = float('inf')
baseNum = 4
n=100
def build_model(input_shape, activations, regularization_factor=0.01,):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation=activations[0], kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation=activations[1], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation=activations[2], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation=activations[3], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model
for _ in tqdm(range(n), desc='BaseNum Loop'):
    # Randomly select activation functions for each layer
    activation = [random.choice(activation_functions) for _ in range(4)]
    rmse_list = []

    early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
    for _ in range(int(n/4)):
        # Create and train the model
        with tf.device('/GPU:0'):
    #regular model training
            model = build_model(input_shape,activation)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)

        # Evaluate on validation data
            y_val_pred = model.predict(x_test,verbose=0)
            rmse1 = rmse(y_test, y_val_pred)
            rmse_list.append(rmse1)

    # Average RMSE for this sequence of activations
    avg_rmse = np.mean(rmse_list)
    print(f"Average RMSE with activations {activation}: {avg_rmse}")

    # Update the best activation function if needed
    if avg_rmse < lowest_mse:
        best_activation = activation
        lowest_mse = avg_rmse

print(f"Best activation function is {best_activation} with RMSE {lowest_mse}")
# Out:
# BaseNum Loop:   1%|          | 1/100 [02:00<3:19:09, 120.70s/it]
# Average RMSE with activations ['swish', 'selu', 'relu', 'relu']: 23.442481994628906
# BaseNum Loop:   1%|          | 1/100 [02:28<4:04:41, 148.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 31
#      29     model = build_model(input_shape,activation)
#      30     model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
# ---> 31     model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)
#      33 # Evaluate on validation data
#      34     y_val_pred = model.predict(x_test,verbose=0)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:2189, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2187 self._test_counter.assign(0)
#    2188 callbacks.on_test_begin()
# -> 2189 for (
#    2190     _,
#    2191     dataset_or_iterator,
#    2192 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2193     self.reset_metrics()
#    2194     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# NOTE: with =2 (Or any small int) it is hit or miss whether the model will go down the best optimized path. rerun a few times to determine what the best value is
#Used to quickly change size of neural net
baseNum = 4

# Define your original model with regularization
def build_model(input_shape, regularization_factor=0.01):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

with tf.device('/GPU:0'):
    #regular model training
    model = build_model(input_shape)
    model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
    model.fit(x_train, y_train, epochs=500, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history])
    # if no improvement has been made in 100 generations (epochs) stop the model
    if early_stopping.stopped_epoch > 0:
        print(f"Early stopping occurred at epoch {early_stopping.stopped_epoch}")
        print(f"Restoring model weights from the end of the best epoch.")
    else:
        print("Early stopping did not occur.")

    test_metrics = model.evaluate(x_test, y_test)
    test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
    print(f"Test Loss (MSE): {test_loss}")
    print(f"Test Accuracy: {test_accuracy*100}")
    print(f"Test RMSE: {test_rmse}")
    # Plotting RMSE values
    plt.figure(figsize=(10, 5))
    plt.plot(rmse_history.modelRMSE, label='Train RMSE')
    plt.plot(rmse_history.validationRMSE, label='Validation RMSE')
    plt.xlabel('Generation')
    plt.ylabel('RMSE')
    plt.title('RMSE During Training')
    plt.legend()
    plt.show()
# model.save('MethaneModel.keras')
# Out:
# Epoch 1/500
# 25/25 [==============================] - 0s 3ms/step - loss: 286859.9688 - r_squared: -1.7166 - rmse: 534.1730 - val_loss: 261365.0469 - val_r_squared: -inf - val_rmse: 546.0989
# Epoch 2/500
# 25/25 [==============================] - 0s 882us/step - loss: 264773.8750 - r_squared: -1.4762 - rmse: 512.5730 - val_loss: 238456.2969 - val_r_squared: -inf - val_rmse: 521.3170
# Epoch 3/500
# 25/25 [==============================] - 0s 943us/step - loss: 234453.0156 - r_squared: -1.2618 - rmse: 485.3233 - val_loss: 204889.4062 - val_r_squared: -inf - val_rmse: 482.1071
# Epoch 4/500
# 25/25 [==============================] - 0s 849us/step - loss: 190884.9375 - r_squared: -0.8434 - rmse: 437.4698 - val_loss: 163621.2656 - val_r_squared: -inf - val_rmse: 426.3321
# Epoch 5/500
# 25/25 [==============================] - 0s 729us/step - loss: 146081.1406 - r_squared: -0.3800 - rmse: 378.1401 - val_loss: 142079.2812 - val_r_squared: -inf - val_rmse: 385.0880
# Epoch 6/500
# 25/25 [==============================] - 0s 753us/step - loss: 129476.4375 - r_squared: -0.2456 - rmse: 362.3193 - val_loss: 143511.1719 - val_r_squared: -inf - val_rmse: 378.2581
# Epoch 7/500
# 25/25 [==============================] - 0s 779us/step - loss: 128528.4375 - r_squared: -0.2086 - rmse: 355.4485 - val_loss: 142674.2812 - val_r_squared: -inf - val_rmse: 377.2226
# Epoch 8/500
# 25/25 [==============================] - 0s 820us/step - loss: 127676.0156 - r_squared: -0.2082 - rmse: 357.0143 - val_loss: 140922.3125 - val_r_squared: -inf - val_rmse: 376.7896
# Epoch 9/500
# 25/25 [==============================] - 0s 786us/step - loss: 127150.2422 - r_squared: -0.2024 - rmse: 356.3699 - val_loss: 140877.5781 - val_r_squared: -inf - val_rmse: 375.5938
# Epoch 10/500
# 25/25 [==============================] - 0s 836us/step - loss: 126386.2969 - r_squared: -0.1887 - rmse: 354.1038 - val_loss: 140113.0312 - val_r_squared: -inf - val_rmse: 374.8454
# Epoch 11/500
# 25/25 [==============================] - 0s 757us/step - loss: 125665.2109 - r_squared: -0.1919 - rmse: 351.0247 - val_loss: 139944.3281 - val_r_squared: -inf - val_rmse: 373.7428
# Epoch 12/500
# 25/25 [==============================] - 0s 842us/step - loss: 125025.0000 - r_squared: -0.1885 - rmse: 352.0403 - val_loss: 138733.7500 - val_r_squared: -inf - val_rmse: 373.0620
# Epoch 13/500
# 25/25 [==============================] - 0s 774us/step - loss: 124373.5078 - r_squared: -0.1881 - rmse: 347.5287 - val_loss: 138707.7812 - val_r_squared: -inf - val_rmse: 371.8939
# Epoch 14/500
# 25/25 [==============================] - 0s 787us/step - loss: 123610.5078 - r_squared: -0.1827 - rmse: 347.5805 - val_loss: 137283.0000 - val_r_squared: -inf - val_rmse: 371.4401
# Epoch 15/500
# 25/25 [==============================] - 0s 791us/step - loss: 123527.3906 - r_squared: -0.1771 - rmse: 348.4879 - val_loss: 136724.7188 - val_r_squared: -inf - val_rmse: 370.4866
# Epoch 16/500
# 25/25 [==============================] - 0s 819us/step - loss: 122251.0781 - r_squared: -0.1715 - rmse: 349.1122 - val_loss: 137082.2812 - val_r_squared: -inf - val_rmse: 369.1472
# Epoch 17/500
# 25/25 [==============================] - 0s 800us/step - loss: 121618.0703 - r_squared: -0.1746 - rmse: 350.0538 - val_loss: 135477.0625 - val_r_squared: -inf - val_rmse: 368.6979
# Epoch 18/500
# 25/25 [==============================] - 0s 833us/step - loss: 120869.9766 - r_squared: -0.1507 - rmse: 345.5584 - val_loss: 135252.7188 - val_r_squared: -inf - val_rmse: 367.4845
# Epoch 19/500
# 25/25 [==============================] - 0s 807us/step - loss: 120226.3516 - r_squared: -0.1558 - rmse: 345.2579 - val_loss: 134724.3125 - val_r_squared: -inf - val_rmse: 366.4496
# Epoch 20/500
# 25/25 [==============================] - 0s 781us/step - loss: 119547.4297 - r_squared: -0.1270 - rmse: 345.7316 - val_loss: 133438.5781 - val_r_squared: -inf - val_rmse: 365.7659
# Epoch 21/500
# 25/25 [==============================] - 0s 766us/step - loss: 118659.6016 - r_squared: -0.1408 - rmse: 341.1324 - val_loss: 133200.2969 - val_r_squared: -inf - val_rmse: 364.4070
# Epoch 22/500
# 25/25 [==============================] - 0s 773us/step - loss: 117860.2500 - r_squared: -0.1181 - rmse: 341.7566 - val_loss: 132051.2500 - val_r_squared: -inf - val_rmse: 363.5818
# Epoch 23/500
# 25/25 [==============================] - 0s 733us/step - loss: 117183.8281 - r_squared: -0.1032 - rmse: 342.8157 - val_loss: 131751.9688 - val_r_squared: -inf - val_rmse: 362.0836
# Epoch 24/500
# 25/25 [==============================] - 0s 755us/step - loss: 116031.6719 - r_squared: -0.1143 - rmse: 337.1632 - val_loss: 130402.4141 - val_r_squared: -inf - val_rmse: 360.9733
# Epoch 25/500
# 25/25 [==============================] - 0s 773us/step - loss: 115174.9141 - r_squared: -0.1266 - rmse: 335.6520 - val_loss: 129714.0312 - val_r_squared: -inf - val_rmse: 359.2658
# Epoch 26/500
# 25/25 [==============================] - 0s 733us/step - loss: 114183.0234 - r_squared: -0.0707 - rmse: 334.5504 - val_loss: 128309.0859 - val_r_squared: -inf - val_rmse: 357.9178
# Epoch 27/500
# 25/25 [==============================] - 0s 759us/step - loss: 112904.7812 - r_squared: -0.0583 - rmse: 332.2929 - val_loss: 127272.0938 - val_r_squared: -inf - val_rmse: 355.6290
# Epoch 28/500
# 25/25 [==============================] - 0s 710us/step - loss: 111177.4141 - r_squared: -0.0503 - rmse: 332.9510 - val_loss: 126122.0312 - val_r_squared: -inf - val_rmse: 353.7472
# Epoch 29/500
# 25/25 [==============================] - 0s 817us/step - loss: 109513.7188 - r_squared: -0.0457 - rmse: 330.4013 - val_loss: 123665.2656 - val_r_squared: -inf - val_rmse: 350.3369
# Epoch 30/500
# 25/25 [==============================] - 0s 774us/step - loss: 106234.4688 - r_squared: -0.0169 - rmse: 327.3409 - val_loss: 117708.9609 - val_r_squared: -inf - val_rmse: 342.6922
# Epoch 31/500
# 25/25 [==============================] - 0s 821us/step - loss: 100700.7109 - r_squared: 0.0122 - rmse: 313.4334 - val_loss: 111468.5391 - val_r_squared: -inf - val_rmse: 335.4707
# Epoch 32/500
# 25/25 [==============================] - 0s 853us/step - loss: 96242.1719 - r_squared: 0.0876 - rmse: 310.6458 - val_loss: 107570.2031 - val_r_squared: -inf - val_rmse: 327.6053
# Epoch 33/500
# 25/25 [==============================] - 0s 777us/step - loss: 92162.7891 - r_squared: 0.0815 - rmse: 298.9221 - val_loss: 103339.5000 - val_r_squared: -inf - val_rmse: 320.8672
# Epoch 34/500
# 25/25 [==============================] - 0s 765us/step - loss: 88690.6328 - r_squared: 0.1589 - rmse: 296.6638 - val_loss: 99260.9219 - val_r_squared: -inf - val_rmse: 315.1296
# Epoch 35/500
# 25/25 [==============================] - 0s 756us/step - loss: 84859.6797 - r_squared: 0.1944 - rmse: 288.7270 - val_loss: 96281.2969 - val_r_squared: -inf - val_rmse: 309.1694
# Epoch 36/500
# 25/25 [==============================] - 0s 782us/step - loss: 82235.2969 - r_squared: 0.2161 - rmse: 287.2021 - val_loss: 91751.7656 - val_r_squared: -inf - val_rmse: 305.3202
# Epoch 37/500
# 25/25 [==============================] - 0s 760us/step - loss: 79571.4297 - r_squared: 0.2569 - rmse: 280.6355 - val_loss: 88586.6562 - val_r_squared: -inf - val_rmse: 300.7368
# Epoch 38/500
# 25/25 [==============================] - 0s 775us/step - loss: 77007.3672 - r_squared: 0.2695 - rmse: 274.5826 - val_loss: 85384.9297 - val_r_squared: -inf - val_rmse: 297.3747
# Epoch 39/500
# 25/25 [==============================] - 0s 764us/step - loss: 74531.8438 - r_squared: 0.2901 - rmse: 273.1388 - val_loss: 82983.2656 - val_r_squared: -inf - val_rmse: 290.4008
# Epoch 40/500
# 25/25 [==============================] - 0s 757us/step - loss: 72316.2734 - r_squared: 0.3185 - rmse: 263.9135 - val_loss: 79551.5859 - val_r_squared: -inf - val_rmse: 287.2435
# Epoch 41/500
# 25/25 [==============================] - 0s 717us/step - loss: 69975.8516 - r_squared: 0.3494 - rmse: 259.2451 - val_loss: 79341.4609 - val_r_squared: -inf - val_rmse: 280.3042
# Epoch 42/500
# 25/25 [==============================] - 0s 769us/step - loss: 68469.6016 - r_squared: 0.3368 - rmse: 258.1127 - val_loss: 74253.5156 - val_r_squared: -inf - val_rmse: 278.0703
# Epoch 43/500
# 25/25 [==============================] - 0s 716us/step - loss: 66320.7812 - r_squared: 0.3676 - rmse: 257.2733 - val_loss: 72007.1953 - val_r_squared: -inf - val_rmse: 272.5973
# Epoch 44/500
# 25/25 [==============================] - 0s 758us/step - loss: 63684.1992 - r_squared: 0.3977 - rmse: 249.2044 - val_loss: 69490.9219 - val_r_squared: -inf - val_rmse: 267.9224
# Epoch 45/500
# 25/25 [==============================] - 0s 784us/step - loss: 61908.8828 - r_squared: 0.4036 - rmse: 245.1346 - val_loss: 66954.4609 - val_r_squared: -inf - val_rmse: 264.1533
# Epoch 46/500
# 25/25 [==============================] - 0s 760us/step - loss: 59839.6562 - r_squared: 0.4345 - rmse: 240.6140 - val_loss: 64780.5352 - val_r_squared: -inf - val_rmse: 260.0077
# Epoch 47/500
# 25/25 [==============================] - 0s 757us/step - loss: 57976.9492 - r_squared: 0.4474 - rmse: 239.3037 - val_loss: 62374.9688 - val_r_squared: -inf - val_rmse: 255.6367
# Epoch 48/500
# 25/25 [==============================] - 0s 746us/step - loss: 55705.0625 - r_squared: 0.4682 - rmse: 235.3656 - val_loss: 60050.6602 - val_r_squared: -inf - val_rmse: 249.5414
# Epoch 49/500
# 25/25 [==============================] - 0s 812us/step - loss: 53566.1797 - r_squared: 0.4967 - rmse: 226.9443 - val_loss: 57685.7695 - val_r_squared: -inf - val_rmse: 245.7195
# Epoch 50/500
# 25/25 [==============================] - 0s 729us/step - loss: 51687.7188 - r_squared: 0.5069 - rmse: 226.2187 - val_loss: 55615.7695 - val_r_squared: -inf - val_rmse: 242.4794
# Epoch 51/500
# 25/25 [==============================] - 0s 800us/step - loss: 49786.3672 - r_squared: 0.5275 - rmse: 221.0143 - val_loss: 53201.8203 - val_r_squared: -inf - val_rmse: 236.7124
# Epoch 52/500
# 25/25 [==============================] - 0s 723us/step - loss: 48045.6914 - r_squared: 0.5121 - rmse: 218.8815 - val_loss: 51672.3242 - val_r_squared: -inf - val_rmse: 229.4424
# Epoch 53/500
# 25/25 [==============================] - 0s 785us/step - loss: 46690.6836 - r_squared: 0.5627 - rmse: 215.1299 - val_loss: 49402.5703 - val_r_squared: -inf - val_rmse: 229.0590
# Epoch 54/500
# 25/25 [==============================] - 0s 719us/step - loss: 44191.3398 - r_squared: 0.5773 - rmse: 209.8308 - val_loss: 47094.3984 - val_r_squared: -inf - val_rmse: 220.7260
# Epoch 55/500
# 25/25 [==============================] - 0s 787us/step - loss: 42262.0547 - r_squared: 0.6104 - rmse: 202.1332 - val_loss: 45076.9688 - val_r_squared: -inf - val_rmse: 216.0662
# Epoch 56/500
# 25/25 [==============================] - 0s 712us/step - loss: 40532.3203 - r_squared: 0.6235 - rmse: 196.6691 - val_loss: 43558.7539 - val_r_squared: -inf - val_rmse: 217.3191
# Epoch 57/500
# 25/25 [==============================] - 0s 753us/step - loss: 38716.0039 - r_squared: 0.6233 - rmse: 195.9499 - val_loss: 40949.6211 - val_r_squared: -inf - val_rmse: 207.0319
# Epoch 58/500
# 25/25 [==============================] - 0s 759us/step - loss: 36978.5586 - r_squared: 0.6561 - rmse: 190.1201 - val_loss: 38900.8945 - val_r_squared: -inf - val_rmse: 202.1271
# Epoch 59/500
# 25/25 [==============================] - 0s 766us/step - loss: 35125.4648 - r_squared: 0.6684 - rmse: 185.2023 - val_loss: 37046.3516 - val_r_squared: -inf - val_rmse: 198.7178
# Epoch 60/500
# 25/25 [==============================] - 0s 754us/step - loss: 33433.6680 - r_squared: 0.6795 - rmse: 180.5361 - val_loss: 36124.9883 - val_r_squared: -inf - val_rmse: 197.8838
# Epoch 61/500
# 25/25 [==============================] - 0s 752us/step - loss: 32063.8711 - r_squared: 0.7000 - rmse: 176.5720 - val_loss: 34498.6289 - val_r_squared: -inf - val_rmse: 192.4412
# Epoch 62/500
# 25/25 [==============================] - 0s 785us/step - loss: 30833.1094 - r_squared: 0.7090 - rmse: 172.7103 - val_loss: 33864.0781 - val_r_squared: -inf - val_rmse: 192.2372
# Epoch 63/500
# 25/25 [==============================] - 0s 821us/step - loss: 28817.2578 - r_squared: 0.7253 - rmse: 169.3062 - val_loss: 30608.0684 - val_r_squared: -inf - val_rmse: 180.8721
# Epoch 64/500
# 25/25 [==============================] - 0s 715us/step - loss: 27340.3652 - r_squared: 0.7499 - rmse: 161.9158 - val_loss: 29253.0430 - val_r_squared: -inf - val_rmse: 175.7737
# Epoch 65/500
# 25/25 [==============================] - 0s 813us/step - loss: 26313.2168 - r_squared: 0.7460 - rmse: 160.8615 - val_loss: 27681.8242 - val_r_squared: -inf - val_rmse: 171.9220
# Epoch 66/500
# 25/25 [==============================] - 0s 731us/step - loss: 25151.8770 - r_squared: 0.7647 - rmse: 156.3490 - val_loss: 26319.9961 - val_r_squared: -inf - val_rmse: 168.6441
# Epoch 67/500
# 25/25 [==============================] - 0s 753us/step - loss: 23749.3359 - r_squared: 0.7739 - rmse: 151.5706 - val_loss: 25456.3457 - val_r_squared: -inf - val_rmse: 167.1614
# Epoch 68/500
# 25/25 [==============================] - 0s 727us/step - loss: 22796.7988 - r_squared: 0.7800 - rmse: 151.4553 - val_loss: 23959.9141 - val_r_squared: -inf - val_rmse: 160.2681
# Epoch 69/500
# 25/25 [==============================] - 0s 765us/step - loss: 21346.1562 - r_squared: 0.7938 - rmse: 145.2575 - val_loss: 22930.5059 - val_r_squared: -inf - val_rmse: 158.1611
# Epoch 70/500
# 25/25 [==============================] - 0s 756us/step - loss: 20451.4297 - r_squared: 0.8052 - rmse: 143.1526 - val_loss: 22084.1035 - val_r_squared: -inf - val_rmse: 151.8158
# Epoch 71/500
# 25/25 [==============================] - 0s 719us/step - loss: 20141.2090 - r_squared: 0.8068 - rmse: 141.3848 - val_loss: 23120.5977 - val_r_squared: -inf - val_rmse: 161.6410
# Epoch 72/500
# 25/25 [==============================] - 0s 807us/step - loss: 18657.1973 - r_squared: 0.8233 - rmse: 136.3427 - val_loss: 20188.6816 - val_r_squared: -inf - val_rmse: 147.7677
# Epoch 73/500
# 25/25 [==============================] - 0s 728us/step - loss: 17818.3984 - r_squared: 0.8223 - rmse: 133.8015 - val_loss: 19169.7734 - val_r_squared: -inf - val_rmse: 141.6321
# Epoch 74/500
# 25/25 [==============================] - 0s 748us/step - loss: 16562.0391 - r_squared: 0.8456 - rmse: 126.0333 - val_loss: 19211.6113 - val_r_squared: -inf - val_rmse: 145.8382
# Epoch 75/500
# 25/25 [==============================] - 0s 799us/step - loss: 17081.6035 - r_squared: 0.8413 - rmse: 128.4024 - val_loss: 17102.2324 - val_r_squared: -inf - val_rmse: 135.2906
# Epoch 76/500
# 25/25 [==============================] - 0s 756us/step - loss: 15133.6367 - r_squared: 0.8579 - rmse: 121.9657 - val_loss: 16503.6855 - val_r_squared: -inf - val_rmse: 132.7663
# Epoch 77/500
# 25/25 [==============================] - 0s 752us/step - loss: 14934.3418 - r_squared: 0.8618 - rmse: 119.7748 - val_loss: 16218.1865 - val_r_squared: -inf - val_rmse: 131.8648
# Epoch 78/500
# 25/25 [==============================] - 0s 710us/step - loss: 13742.9590 - r_squared: 0.8697 - rmse: 115.4927 - val_loss: 15447.8008 - val_r_squared: -inf - val_rmse: 129.3193
# Epoch 79/500
# 25/25 [==============================] - 0s 727us/step - loss: 12809.0059 - r_squared: 0.8816 - rmse: 111.4606 - val_loss: 14243.7900 - val_r_squared: -inf - val_rmse: 122.6556
# Epoch 80/500
# 25/25 [==============================] - 0s 828us/step - loss: 12443.6270 - r_squared: 0.8814 - rmse: 110.0910 - val_loss: 13700.6641 - val_r_squared: -inf - val_rmse: 120.5996
# Epoch 81/500
# 25/25 [==============================] - 0s 805us/step - loss: 11732.0918 - r_squared: 0.8804 - rmse: 109.6846 - val_loss: 15292.3584 - val_r_squared: -inf - val_rmse: 129.2992
# Epoch 82/500
# 25/25 [==============================] - 0s 854us/step - loss: 11449.6943 - r_squared: 0.8895 - rmse: 106.4232 - val_loss: 12855.4707 - val_r_squared: -inf - val_rmse: 117.2556
# Epoch 83/500
# 25/25 [==============================] - 0s 827us/step - loss: 11047.6201 - r_squared: 0.8954 - rmse: 104.4744 - val_loss: 13386.2383 - val_r_squared: -inf - val_rmse: 120.4768
# Epoch 84/500
# 25/25 [==============================] - 0s 801us/step - loss: 10596.8594 - r_squared: 0.8994 - rmse: 102.6790 - val_loss: 12202.7139 - val_r_squared: -inf - val_rmse: 114.6040
# Epoch 85/500
# 25/25 [==============================] - 0s 798us/step - loss: 10157.1914 - r_squared: 0.9032 - rmse: 99.2985 - val_loss: 14828.8252 - val_r_squared: -inf - val_rmse: 127.5436
# Epoch 86/500
# 25/25 [==============================] - 0s 760us/step - loss: 10187.2715 - r_squared: 0.9042 - rmse: 99.7084 - val_loss: 12202.8838 - val_r_squared: -inf - val_rmse: 115.4062
# Epoch 87/500
# 25/25 [==============================] - 0s 747us/step - loss: 9659.9580 - r_squared: 0.9060 - rmse: 97.9910 - val_loss: 12306.3691 - val_r_squared: -inf - val_rmse: 115.5107
# Epoch 88/500
# 25/25 [==============================] - 0s 753us/step - loss: 9792.4209 - r_squared: 0.9043 - rmse: 99.0270 - val_loss: 10616.9238 - val_r_squared: -inf - val_rmse: 105.5644
# Epoch 89/500
# 25/25 [==============================] - 0s 799us/step - loss: 9034.3906 - r_squared: 0.9119 - rmse: 94.9286 - val_loss: 10245.8330 - val_r_squared: -inf - val_rmse: 104.3270
# Epoch 90/500
# 25/25 [==============================] - 0s 784us/step - loss: 8682.2148 - r_squared: 0.9174 - rmse: 92.6824 - val_loss: 9899.4404 - val_r_squared: -inf - val_rmse: 102.0738
# Epoch 91/500
# 25/25 [==============================] - 0s 689us/step - loss: 8639.4072 - r_squared: 0.9140 - rmse: 92.1034 - val_loss: 9633.3887 - val_r_squared: -inf - val_rmse: 100.4895
# Epoch 92/500
# 25/25 [==============================] - 0s 717us/step - loss: 8443.3760 - r_squared: 0.9197 - rmse: 91.2457 - val_loss: 9448.5840 - val_r_squared: -inf - val_rmse: 99.4435
# Epoch 93/500
# 25/25 [==============================] - 0s 706us/step - loss: 8166.1948 - r_squared: 0.9213 - rmse: 90.6264 - val_loss: 10084.7764 - val_r_squared: -inf - val_rmse: 103.5644
# Epoch 94/500
# 25/25 [==============================] - 0s 727us/step - loss: 7749.0239 - r_squared: 0.9256 - rmse: 87.3455 - val_loss: 9203.5303 - val_r_squared: -inf - val_rmse: 97.6508
# Epoch 95/500
# 25/25 [==============================] - 0s 707us/step - loss: 7489.1147 - r_squared: 0.9261 - rmse: 86.5338 - val_loss: 8980.1914 - val_r_squared: -inf - val_rmse: 96.7679
# Epoch 96/500
# 25/25 [==============================] - 0s 722us/step - loss: 7458.7822 - r_squared: 0.9290 - rmse: 86.4870 - val_loss: 9062.2207 - val_r_squared: -inf - val_rmse: 96.5945
# Epoch 97/500
# 25/25 [==============================] - 0s 725us/step - loss: 7309.9678 - r_squared: 0.9293 - rmse: 85.0304 - val_loss: 8442.8564 - val_r_squared: -inf - val_rmse: 93.2404
# Epoch 98/500
# 25/25 [==============================] - 0s 751us/step - loss: 7473.9692 - r_squared: 0.9295 - rmse: 85.1702 - val_loss: 8339.6064 - val_r_squared: -inf - val_rmse: 93.2883
# Epoch 99/500
# 25/25 [==============================] - 0s 693us/step - loss: 7062.4185 - r_squared: 0.9341 - rmse: 82.5422 - val_loss: 8089.7095 - val_r_squared: -inf - val_rmse: 91.3457
# Epoch 100/500
# 25/25 [==============================] - 0s 734us/step - loss: 7018.9126 - r_squared: 0.9297 - rmse: 83.7341 - val_loss: 7963.3696 - val_r_squared: -inf - val_rmse: 90.9392
# Epoch 101/500
# 25/25 [==============================] - 0s 695us/step - loss: 6850.4937 - r_squared: 0.9338 - rmse: 83.1797 - val_loss: 8000.9644 - val_r_squared: -inf - val_rmse: 91.0082
# Epoch 102/500
# 25/25 [==============================] - 0s 736us/step - loss: 6743.1357 - r_squared: 0.9352 - rmse: 81.9250 - val_loss: 7837.6289 - val_r_squared: -inf - val_rmse: 90.4972
# Epoch 103/500
# 25/25 [==============================] - 0s 686us/step - loss: 6531.9438 - r_squared: 0.9391 - rmse: 79.5592 - val_loss: 9848.7861 - val_r_squared: -inf - val_rmse: 103.2184
# Epoch 104/500
# 25/25 [==============================] - 0s 698us/step - loss: 6822.9883 - r_squared: 0.9338 - rmse: 82.1974 - val_loss: 7753.1206 - val_r_squared: -inf - val_rmse: 90.4127
# Epoch 105/500
# 25/25 [==============================] - 0s 695us/step - loss: 6530.1880 - r_squared: 0.9301 - rmse: 81.1097 - val_loss: 7991.4751 - val_r_squared: -inf - val_rmse: 91.7081
# Epoch 106/500
# 25/25 [==============================] - 0s 763us/step - loss: 6544.3569 - r_squared: 0.9379 - rmse: 80.1767 - val_loss: 8168.0278 - val_r_squared: -inf - val_rmse: 92.7934
# Epoch 107/500
# 25/25 [==============================] - 0s 725us/step - loss: 6316.8906 - r_squared: 0.9391 - rmse: 79.4485 - val_loss: 7108.5083 - val_r_squared: -inf - val_rmse: 86.2117
# Epoch 108/500
# 25/25 [==============================] - 0s 713us/step - loss: 6159.8306 - r_squared: 0.9413 - rmse: 77.9807 - val_loss: 7064.2046 - val_r_squared: -inf - val_rmse: 85.7456
# Epoch 109/500
# 25/25 [==============================] - 0s 714us/step - loss: 6721.4653 - r_squared: 0.9362 - rmse: 81.8017 - val_loss: 7069.9487 - val_r_squared: -inf - val_rmse: 85.7513
# Epoch 110/500
# 25/25 [==============================] - 0s 737us/step - loss: 6226.6558 - r_squared: 0.9420 - rmse: 78.2263 - val_loss: 7739.0439 - val_r_squared: -inf - val_rmse: 90.9287
# Epoch 111/500
# 25/25 [==============================] - 0s 686us/step - loss: 6300.5410 - r_squared: 0.9403 - rmse: 78.9554 - val_loss: 8950.4756 - val_r_squared: -inf - val_rmse: 99.1200
# Epoch 112/500
# 25/25 [==============================] - 0s 740us/step - loss: 6026.4482 - r_squared: 0.9424 - rmse: 77.0163 - val_loss: 6947.7739 - val_r_squared: -inf - val_rmse: 85.4181
# Epoch 113/500
# 25/25 [==============================] - 0s 696us/step - loss: 5853.3096 - r_squared: 0.9437 - rmse: 76.3755 - val_loss: 6507.5000 - val_r_squared: -inf - val_rmse: 82.3843
# Epoch 114/500
# 25/25 [==============================] - 0s 727us/step - loss: 5744.9961 - r_squared: 0.9449 - rmse: 75.3955 - val_loss: 6431.5586 - val_r_squared: -inf - val_rmse: 82.1444
# Epoch 115/500
# 25/25 [==============================] - 0s 701us/step - loss: 5731.1963 - r_squared: 0.9439 - rmse: 76.0401 - val_loss: 6422.4219 - val_r_squared: -inf - val_rmse: 82.1804
# Epoch 116/500
# 25/25 [==============================] - 0s 727us/step - loss: 5614.6533 - r_squared: 0.9470 - rmse: 74.4638 - val_loss: 6338.2729 - val_r_squared: -inf - val_rmse: 81.5151
# Epoch 117/500
# 25/25 [==============================] - 0s 757us/step - loss: 5715.1108 - r_squared: 0.9463 - rmse: 74.4591 - val_loss: 6257.4912 - val_r_squared: -inf - val_rmse: 81.2255
# Epoch 118/500
# 25/25 [==============================] - 0s 749us/step - loss: 5642.8823 - r_squared: 0.9472 - rmse: 73.9900 - val_loss: 7377.8735 - val_r_squared: -inf - val_rmse: 89.6289
# Epoch 119/500
# 25/25 [==============================] - 0s 737us/step - loss: 5574.5127 - r_squared: 0.9472 - rmse: 74.5761 - val_loss: 6921.4688 - val_r_squared: -inf - val_rmse: 85.7553
# Epoch 120/500
# 25/25 [==============================] - 0s 683us/step - loss: 5741.0859 - r_squared: 0.9474 - rmse: 73.9312 - val_loss: 5986.1025 - val_r_squared: -inf - val_rmse: 79.5943
# Epoch 121/500
# 25/25 [==============================] - 0s 720us/step - loss: 5622.3501 - r_squared: 0.9444 - rmse: 75.6884 - val_loss: 6025.0078 - val_r_squared: -inf - val_rmse: 79.7728
# Epoch 122/500
# 25/25 [==============================] - 0s 743us/step - loss: 5291.0059 - r_squared: 0.9491 - rmse: 72.9720 - val_loss: 5855.9380 - val_r_squared: -inf - val_rmse: 78.5538
# Epoch 123/500
# 25/25 [==============================] - 0s 694us/step - loss: 5341.7314 - r_squared: 0.9499 - rmse: 72.2662 - val_loss: 6131.1855 - val_r_squared: -inf - val_rmse: 80.3309
# Epoch 124/500
# 25/25 [==============================] - 0s 747us/step - loss: 5483.9507 - r_squared: 0.9473 - rmse: 74.0067 - val_loss: 5897.8096 - val_r_squared: -inf - val_rmse: 78.9240
# Epoch 125/500
# 25/25 [==============================] - 0s 760us/step - loss: 5175.4927 - r_squared: 0.9501 - rmse: 71.5631 - val_loss: 5768.6582 - val_r_squared: -inf - val_rmse: 78.0009
# Epoch 126/500
# 25/25 [==============================] - 0s 723us/step - loss: 5198.4565 - r_squared: 0.9505 - rmse: 71.6695 - val_loss: 5808.5122 - val_r_squared: -inf - val_rmse: 78.6279
# Epoch 127/500
# 25/25 [==============================] - 0s 697us/step - loss: 5090.4229 - r_squared: 0.9514 - rmse: 70.6413 - val_loss: 5573.2231 - val_r_squared: -inf - val_rmse: 76.9516
# Epoch 128/500
# 25/25 [==============================] - 0s 693us/step - loss: 5172.8843 - r_squared: 0.9512 - rmse: 70.9473 - val_loss: 5937.2080 - val_r_squared: -inf - val_rmse: 79.8917
# Epoch 129/500
# 25/25 [==============================] - 0s 813us/step - loss: 5040.3623 - r_squared: 0.9523 - rmse: 69.3586 - val_loss: 5720.9561 - val_r_squared: -inf - val_rmse: 78.1017
# Epoch 130/500
# 25/25 [==============================] - 0s 717us/step - loss: 4981.6157 - r_squared: 0.9527 - rmse: 69.9629 - val_loss: 5707.9448 - val_r_squared: -inf - val_rmse: 78.3753
# Epoch 131/500
# 25/25 [==============================] - 0s 768us/step - loss: 4884.8711 - r_squared: 0.9536 - rmse: 68.7990 - val_loss: 5774.5439 - val_r_squared: -inf - val_rmse: 79.2142
# Epoch 132/500
# 25/25 [==============================] - 0s 695us/step - loss: 5182.1768 - r_squared: 0.9511 - rmse: 71.4205 - val_loss: 5359.1265 - val_r_squared: -inf - val_rmse: 75.7278
# Epoch 133/500
# 25/25 [==============================] - 0s 783us/step - loss: 4893.7246 - r_squared: 0.9533 - rmse: 69.1528 - val_loss: 6007.4346 - val_r_squared: -inf - val_rmse: 80.3946
# Epoch 134/500
# 25/25 [==============================] - 0s 744us/step - loss: 5150.8184 - r_squared: 0.9507 - rmse: 70.4703 - val_loss: 6344.5254 - val_r_squared: -inf - val_rmse: 83.4184
# Epoch 135/500
# 25/25 [==============================] - 0s 766us/step - loss: 5054.3867 - r_squared: 0.9520 - rmse: 70.4311 - val_loss: 5608.7949 - val_r_squared: -inf - val_rmse: 77.8472
# Epoch 136/500
# 25/25 [==============================] - 0s 731us/step - loss: 5079.5469 - r_squared: 0.9526 - rmse: 70.3533 - val_loss: 5278.7759 - val_r_squared: -inf - val_rmse: 75.2707
# Epoch 137/500
# 25/25 [==============================] - 0s 710us/step - loss: 4827.2954 - r_squared: 0.9505 - rmse: 69.5442 - val_loss: 5175.8643 - val_r_squared: -inf - val_rmse: 74.4747
# Epoch 138/500
# 25/25 [==============================] - 0s 707us/step - loss: 4904.8496 - r_squared: 0.9479 - rmse: 70.6306 - val_loss: 5757.9434 - val_r_squared: -inf - val_rmse: 79.4476
# Epoch 139/500
# 25/25 [==============================] - 0s 718us/step - loss: 5325.7236 - r_squared: 0.9483 - rmse: 72.0275 - val_loss: 6216.3359 - val_r_squared: -inf - val_rmse: 82.6747
# Epoch 140/500
# 25/25 [==============================] - 0s 768us/step - loss: 4819.9160 - r_squared: 0.9541 - rmse: 68.2136 - val_loss: 5101.1929 - val_r_squared: -inf - val_rmse: 74.2889
# Epoch 141/500
# 25/25 [==============================] - 0s 732us/step - loss: 4748.4062 - r_squared: 0.9551 - rmse: 67.1669 - val_loss: 5883.6421 - val_r_squared: -inf - val_rmse: 80.2245
# Epoch 142/500
# 25/25 [==============================] - 0s 838us/step - loss: 5166.2808 - r_squared: 0.9496 - rmse: 70.2421 - val_loss: 5050.4937 - val_r_squared: -inf - val_rmse: 73.8437
# Epoch 143/500
# 25/25 [==============================] - 0s 776us/step - loss: 4590.2285 - r_squared: 0.9551 - rmse: 67.9185 - val_loss: 4947.7817 - val_r_squared: -inf - val_rmse: 72.8708
# Epoch 144/500
# 25/25 [==============================] - 0s 759us/step - loss: 4586.3022 - r_squared: 0.9564 - rmse: 67.0502 - val_loss: 4935.8618 - val_r_squared: -inf - val_rmse: 73.0688
# Epoch 145/500
# 25/25 [==============================] - 0s 722us/step - loss: 4753.7207 - r_squared: 0.9540 - rmse: 68.6580 - val_loss: 5401.9829 - val_r_squared: -inf - val_rmse: 76.8649
# Epoch 146/500
# 25/25 [==============================] - 0s 709us/step - loss: 4822.9819 - r_squared: 0.9546 - rmse: 68.2048 - val_loss: 5329.0806 - val_r_squared: -inf - val_rmse: 76.4572
# Epoch 147/500
# 25/25 [==============================] - 0s 732us/step - loss: 4722.4741 - r_squared: 0.9544 - rmse: 69.1006 - val_loss: 4782.7729 - val_r_squared: -inf - val_rmse: 71.5201
# Epoch 148/500
# 25/25 [==============================] - 0s 741us/step - loss: 4706.2173 - r_squared: 0.9553 - rmse: 68.7348 - val_loss: 4837.2583 - val_r_squared: -inf - val_rmse: 71.8941
# Epoch 149/500
# 25/25 [==============================] - 0s 753us/step - loss: 4706.7998 - r_squared: 0.9560 - rmse: 67.6152 - val_loss: 5081.0342 - val_r_squared: -inf - val_rmse: 74.0099
# Epoch 150/500
# 25/25 [==============================] - 0s 739us/step - loss: 4464.8018 - r_squared: 0.9578 - rmse: 66.1531 - val_loss: 4745.9077 - val_r_squared: -inf - val_rmse: 71.1444
# Epoch 151/500
# 25/25 [==============================] - 0s 700us/step - loss: 4651.8779 - r_squared: 0.9557 - rmse: 67.5810 - val_loss: 4766.6699 - val_r_squared: -inf - val_rmse: 71.8316
# Epoch 152/500
# 25/25 [==============================] - 0s 719us/step - loss: 4499.1289 - r_squared: 0.9570 - rmse: 66.6460 - val_loss: 4754.8452 - val_r_squared: -inf - val_rmse: 71.8011
# Epoch 153/500
# 25/25 [==============================] - 0s 727us/step - loss: 4634.5352 - r_squared: 0.9570 - rmse: 67.2265 - val_loss: 4850.2139 - val_r_squared: -inf - val_rmse: 72.3727
# Epoch 154/500
# 25/25 [==============================] - 0s 743us/step - loss: 4505.9639 - r_squared: 0.9568 - rmse: 67.1053 - val_loss: 5188.1118 - val_r_squared: -inf - val_rmse: 75.5296
# Epoch 155/500
# 25/25 [==============================] - 0s 716us/step - loss: 4407.4961 - r_squared: 0.9578 - rmse: 65.8076 - val_loss: 4728.2734 - val_r_squared: -inf - val_rmse: 71.3915
# Epoch 156/500
# 25/25 [==============================] - 0s 760us/step - loss: 4437.7148 - r_squared: 0.9587 - rmse: 65.2511 - val_loss: 5795.7080 - val_r_squared: -inf - val_rmse: 80.3809
# Epoch 157/500
# 25/25 [==============================] - 0s 697us/step - loss: 4475.9292 - r_squared: 0.9571 - rmse: 66.3545 - val_loss: 4700.4419 - val_r_squared: -inf - val_rmse: 71.5746
# Epoch 158/500
# 25/25 [==============================] - 0s 699us/step - loss: 4442.7715 - r_squared: 0.9568 - rmse: 66.6240 - val_loss: 5195.5391 - val_r_squared: -inf - val_rmse: 75.7601
# Epoch 159/500
# 25/25 [==============================] - 0s 745us/step - loss: 4588.9297 - r_squared: 0.9568 - rmse: 66.9091 - val_loss: 4659.7910 - val_r_squared: -inf - val_rmse: 71.3058
# Epoch 160/500
# 25/25 [==============================] - 0s 754us/step - loss: 4390.2119 - r_squared: 0.9589 - rmse: 65.1999 - val_loss: 4557.1611 - val_r_squared: -inf - val_rmse: 70.1590
# Epoch 161/500
# 25/25 [==============================] - 0s 725us/step - loss: 4684.7344 - r_squared: 0.9555 - rmse: 66.8968 - val_loss: 4663.8765 - val_r_squared: -inf - val_rmse: 71.4482
# Epoch 162/500
# 25/25 [==============================] - 0s 714us/step - loss: 4360.3423 - r_squared: 0.9586 - rmse: 64.2051 - val_loss: 4825.2754 - val_r_squared: -inf - val_rmse: 72.7902
# Epoch 163/500
# 25/25 [==============================] - 0s 747us/step - loss: 4368.5015 - r_squared: 0.9586 - rmse: 65.2944 - val_loss: 4762.0659 - val_r_squared: -inf - val_rmse: 72.3923
# Epoch 164/500
# 25/25 [==============================] - 0s 710us/step - loss: 4580.8691 - r_squared: 0.9559 - rmse: 66.8577 - val_loss: 4525.2495 - val_r_squared: -inf - val_rmse: 69.9964
# Epoch 165/500
# 25/25 [==============================] - 0s 714us/step - loss: 4473.6611 - r_squared: 0.9573 - rmse: 66.8395 - val_loss: 4433.4971 - val_r_squared: -inf - val_rmse: 69.2984
# Epoch 166/500
# 25/25 [==============================] - 0s 679us/step - loss: 4558.6348 - r_squared: 0.9563 - rmse: 66.5098 - val_loss: 4492.3149 - val_r_squared: -inf - val_rmse: 69.5404
# Epoch 167/500
# 25/25 [==============================] - 0s 706us/step - loss: 4331.1675 - r_squared: 0.9583 - rmse: 64.5633 - val_loss: 4762.5132 - val_r_squared: -inf - val_rmse: 72.3001
# Epoch 168/500
# 25/25 [==============================] - 0s 693us/step - loss: 4469.4663 - r_squared: 0.9581 - rmse: 66.0685 - val_loss: 4753.1870 - val_r_squared: -inf - val_rmse: 72.3089
# Epoch 169/500
# 25/25 [==============================] - 0s 743us/step - loss: 4254.2515 - r_squared: 0.9587 - rmse: 65.0559 - val_loss: 4664.8579 - val_r_squared: -inf - val_rmse: 71.5239
# Epoch 170/500
# 25/25 [==============================] - 0s 723us/step - loss: 4329.4448 - r_squared: 0.9587 - rmse: 65.0237 - val_loss: 4502.5811 - val_r_squared: -inf - val_rmse: 69.7630
# Epoch 171/500
# 25/25 [==============================] - 0s 722us/step - loss: 4458.4785 - r_squared: 0.9551 - rmse: 65.9483 - val_loss: 4496.2168 - val_r_squared: -inf - val_rmse: 70.0355
# Epoch 172/500
# 25/25 [==============================] - 0s 677us/step - loss: 4463.0620 - r_squared: 0.9563 - rmse: 66.6198 - val_loss: 6719.2637 - val_r_squared: -inf - val_rmse: 87.5288
# Epoch 173/500
# 25/25 [==============================] - 0s 736us/step - loss: 5076.1294 - r_squared: 0.9507 - rmse: 69.7614 - val_loss: 4773.0557 - val_r_squared: -inf - val_rmse: 72.8764
# Epoch 174/500
# 25/25 [==============================] - 0s 728us/step - loss: 4710.4155 - r_squared: 0.9548 - rmse: 68.0351 - val_loss: 4372.6348 - val_r_squared: -inf - val_rmse: 69.0738
# Epoch 175/500
# 25/25 [==============================] - 0s 767us/step - loss: 4793.4741 - r_squared: 0.9535 - rmse: 68.4587 - val_loss: 4482.4526 - val_r_squared: -inf - val_rmse: 69.7597
# Epoch 176/500
# 25/25 [==============================] - 0s 779us/step - loss: 4282.1826 - r_squared: 0.9598 - rmse: 64.0297 - val_loss: 5003.9395 - val_r_squared: -inf - val_rmse: 74.3901
# Epoch 177/500
# 25/25 [==============================] - 0s 780us/step - loss: 4450.4551 - r_squared: 0.9573 - rmse: 66.2654 - val_loss: 4796.2451 - val_r_squared: -inf - val_rmse: 72.9321
# Epoch 178/500
# 25/25 [==============================] - 0s 795us/step - loss: 4375.8208 - r_squared: 0.9581 - rmse: 66.0601 - val_loss: 4462.0122 - val_r_squared: -inf - val_rmse: 69.5593
# Epoch 179/500
# 25/25 [==============================] - 0s 785us/step - loss: 4542.8486 - r_squared: 0.9570 - rmse: 66.6382 - val_loss: 4320.3154 - val_r_squared: -inf - val_rmse: 68.9770
# Epoch 180/500
# 25/25 [==============================] - 0s 785us/step - loss: 4383.0850 - r_squared: 0.9593 - rmse: 64.5245 - val_loss: 4299.2554 - val_r_squared: -inf - val_rmse: 68.7031
# Epoch 181/500
# 25/25 [==============================] - 0s 763us/step - loss: 4291.3594 - r_squared: 0.9586 - rmse: 65.3700 - val_loss: 4937.9727 - val_r_squared: -inf - val_rmse: 73.9139
# Epoch 182/500
# 25/25 [==============================] - 0s 705us/step - loss: 4283.6826 - r_squared: 0.9562 - rmse: 64.9841 - val_loss: 4526.0054 - val_r_squared: -inf - val_rmse: 70.0678
# Epoch 183/500
# 25/25 [==============================] - 0s 731us/step - loss: 4621.9087 - r_squared: 0.9566 - rmse: 66.8007 - val_loss: 5029.9658 - val_r_squared: -inf - val_rmse: 74.7168
# Epoch 184/500
# 25/25 [==============================] - 0s 719us/step - loss: 4551.2974 - r_squared: 0.9574 - rmse: 66.1525 - val_loss: 4747.2632 - val_r_squared: -inf - val_rmse: 72.6065
# Epoch 185/500
# 25/25 [==============================] - 0s 821us/step - loss: 4667.4951 - r_squared: 0.9554 - rmse: 67.2395 - val_loss: 4727.9258 - val_r_squared: -inf - val_rmse: 72.1506
# Epoch 186/500
# 25/25 [==============================] - 0s 767us/step - loss: 4434.1655 - r_squared: 0.9574 - rmse: 65.4401 - val_loss: 4516.6113 - val_r_squared: -inf - val_rmse: 70.7971
# Epoch 187/500
# 25/25 [==============================] - 0s 810us/step - loss: 4427.4927 - r_squared: 0.9564 - rmse: 66.2820 - val_loss: 4765.5840 - val_r_squared: -inf - val_rmse: 72.6143
# Epoch 188/500
# 25/25 [==============================] - 0s 764us/step - loss: 4708.9097 - r_squared: 0.9544 - rmse: 67.5980 - val_loss: 4613.8193 - val_r_squared: -inf - val_rmse: 71.5025
# Epoch 189/500
# 25/25 [==============================] - 0s 736us/step - loss: 4306.2676 - r_squared: 0.9583 - rmse: 65.6005 - val_loss: 4244.3125 - val_r_squared: -inf - val_rmse: 68.1798
# Epoch 190/500
# 25/25 [==============================] - 0s 752us/step - loss: 4242.2573 - r_squared: 0.9589 - rmse: 64.5628 - val_loss: 4302.6646 - val_r_squared: -inf - val_rmse: 68.9770
# Epoch 191/500
# 25/25 [==============================] - 0s 730us/step - loss: 4380.4766 - r_squared: 0.9577 - rmse: 65.4628 - val_loss: 4303.8647 - val_r_squared: -inf - val_rmse: 68.8136
# Epoch 192/500
# 25/25 [==============================] - 0s 728us/step - loss: 4380.9058 - r_squared: 0.9562 - rmse: 66.6095 - val_loss: 4569.2339 - val_r_squared: -inf - val_rmse: 70.5297
# Epoch 193/500
# 25/25 [==============================] - 0s 757us/step - loss: 4365.3350 - r_squared: 0.9578 - rmse: 65.6543 - val_loss: 4369.5220 - val_r_squared: -inf - val_rmse: 69.0826
# Epoch 194/500
# 25/25 [==============================] - 0s 713us/step - loss: 4255.9819 - r_squared: 0.9591 - rmse: 64.2327 - val_loss: 4240.6016 - val_r_squared: -inf - val_rmse: 68.1974
# Epoch 195/500
# 25/25 [==============================] - 0s 743us/step - loss: 4339.1689 - r_squared: 0.9585 - rmse: 65.6792 - val_loss: 4217.0684 - val_r_squared: -inf - val_rmse: 68.1707
# Epoch 196/500
# 25/25 [==============================] - 0s 670us/step - loss: 4293.2251 - r_squared: 0.9592 - rmse: 64.5363 - val_loss: 4741.3999 - val_r_squared: -inf - val_rmse: 72.7439
# Epoch 197/500
# 25/25 [==============================] - 0s 708us/step - loss: 4682.3608 - r_squared: 0.9561 - rmse: 67.6403 - val_loss: 4974.9448 - val_r_squared: -inf - val_rmse: 74.5440
# Epoch 198/500
# 25/25 [==============================] - 0s 693us/step - loss: 4402.6328 - r_squared: 0.9561 - rmse: 66.4097 - val_loss: 5011.2383 - val_r_squared: -inf - val_rmse: 74.0538
# Epoch 199/500
# 25/25 [==============================] - 0s 717us/step - loss: 4556.6377 - r_squared: 0.9565 - rmse: 67.0749 - val_loss: 4231.7305 - val_r_squared: -inf - val_rmse: 68.5710
# Epoch 200/500
# 25/25 [==============================] - 0s 679us/step - loss: 4215.6543 - r_squared: 0.9595 - rmse: 63.9872 - val_loss: 4277.3794 - val_r_squared: -inf - val_rmse: 68.6507
# Epoch 201/500
# 25/25 [==============================] - 0s 742us/step - loss: 4207.6016 - r_squared: 0.9607 - rmse: 63.5930 - val_loss: 4195.3340 - val_r_squared: -inf - val_rmse: 68.0728
# Epoch 202/500
# 25/25 [==============================] - 0s 706us/step - loss: 4216.4512 - r_squared: 0.9590 - rmse: 64.2079 - val_loss: 5151.0757 - val_r_squared: -inf - val_rmse: 76.2161
# Epoch 203/500
# 25/25 [==============================] - 0s 705us/step - loss: 4215.5571 - r_squared: 0.9591 - rmse: 64.6674 - val_loss: 4305.4053 - val_r_squared: -inf - val_rmse: 69.0178
# Epoch 204/500
# 25/25 [==============================] - 0s 717us/step - loss: 4160.1235 - r_squared: 0.9611 - rmse: 62.9939 - val_loss: 4265.2939 - val_r_squared: -inf - val_rmse: 68.7264
# Epoch 205/500
# 25/25 [==============================] - 0s 731us/step - loss: 4270.9697 - r_squared: 0.9597 - rmse: 64.8139 - val_loss: 4257.3989 - val_r_squared: -inf - val_rmse: 68.3752
# Epoch 206/500
# 25/25 [==============================] - 0s 683us/step - loss: 4405.6924 - r_squared: 0.9558 - rmse: 66.2093 - val_loss: 4323.9614 - val_r_squared: -inf - val_rmse: 69.0651
# Epoch 207/500
# 25/25 [==============================] - 0s 700us/step - loss: 4285.5112 - r_squared: 0.9587 - rmse: 64.3607 - val_loss: 4404.3472 - val_r_squared: -inf - val_rmse: 70.2690
# Epoch 208/500
# 25/25 [==============================] - 0s 712us/step - loss: 4123.6147 - r_squared: 0.9615 - rmse: 63.3213 - val_loss: 4170.8901 - val_r_squared: -inf - val_rmse: 67.9061
# Epoch 209/500
# 25/25 [==============================] - 0s 726us/step - loss: 4166.7437 - r_squared: 0.9604 - rmse: 63.3521 - val_loss: 4161.3447 - val_r_squared: -inf - val_rmse: 67.9274
# Epoch 210/500
# 25/25 [==============================] - 0s 675us/step - loss: 4723.9160 - r_squared: 0.9555 - rmse: 66.5545 - val_loss: 4269.5708 - val_r_squared: -inf - val_rmse: 68.6873
# Epoch 211/500
# 25/25 [==============================] - 0s 773us/step - loss: 4196.6011 - r_squared: 0.9588 - rmse: 64.6871 - val_loss: 4212.7510 - val_r_squared: -inf - val_rmse: 68.3794
# Epoch 212/500
# 25/25 [==============================] - 0s 705us/step - loss: 4176.8403 - r_squared: 0.9609 - rmse: 63.7951 - val_loss: 4452.7520 - val_r_squared: -inf - val_rmse: 70.7104
# Epoch 213/500
# 25/25 [==============================] - 0s 705us/step - loss: 4297.9453 - r_squared: 0.9588 - rmse: 64.9090 - val_loss: 4266.3022 - val_r_squared: -inf - val_rmse: 68.5510
# Epoch 214/500
# 25/25 [==============================] - 0s 683us/step - loss: 4471.6094 - r_squared: 0.9584 - rmse: 65.5883 - val_loss: 4453.3716 - val_r_squared: -inf - val_rmse: 70.1135
# Epoch 215/500
# 25/25 [==============================] - 0s 767us/step - loss: 4198.7520 - r_squared: 0.9607 - rmse: 63.8345 - val_loss: 4614.4712 - val_r_squared: -inf - val_rmse: 71.3313
# Epoch 216/500
# 25/25 [==============================] - 0s 705us/step - loss: 4393.6890 - r_squared: 0.9589 - rmse: 64.7952 - val_loss: 4158.3862 - val_r_squared: -inf - val_rmse: 67.9774
# Epoch 217/500
# 25/25 [==============================] - 0s 772us/step - loss: 4087.8611 - r_squared: 0.9603 - rmse: 64.1554 - val_loss: 4207.1768 - val_r_squared: -inf - val_rmse: 68.4855
# Epoch 218/500
# 25/25 [==============================] - 0s 1ms/step - loss: 4371.1997 - r_squared: 0.9589 - rmse: 64.6416 - val_loss: 4334.1699 - val_r_squared: -inf - val_rmse: 69.6606
# Epoch 219/500
# 25/25 [==============================] - 0s 834us/step - loss: 4125.1509 - r_squared: 0.9608 - rmse: 63.6480 - val_loss: 4435.7002 - val_r_squared: -inf - val_rmse: 70.6088
# Epoch 220/500
# 25/25 [==============================] - 0s 759us/step - loss: 4158.8770 - r_squared: 0.9595 - rmse: 64.4569 - val_loss: 4659.7012 - val_r_squared: -inf - val_rmse: 72.2638
# Epoch 221/500
# 25/25 [==============================] - 0s 786us/step - loss: 4218.4985 - r_squared: 0.9605 - rmse: 63.3345 - val_loss: 4296.3311 - val_r_squared: -inf - val_rmse: 69.3446
# Epoch 222/500
# 25/25 [==============================] - 0s 762us/step - loss: 4314.7720 - r_squared: 0.9594 - rmse: 64.5235 - val_loss: 4610.2446 - val_r_squared: -inf - val_rmse: 71.9310
# Epoch 223/500
# 25/25 [==============================] - 0s 759us/step - loss: 4303.1553 - r_squared: 0.9585 - rmse: 65.0962 - val_loss: 5157.9268 - val_r_squared: -inf - val_rmse: 76.4591
# Epoch 224/500
# 25/25 [==============================] - 0s 799us/step - loss: 4596.7188 - r_squared: 0.9561 - rmse: 67.0737 - val_loss: 5013.8589 - val_r_squared: -inf - val_rmse: 75.1609
# Epoch 225/500
# 25/25 [==============================] - 0s 725us/step - loss: 4245.5283 - r_squared: 0.9577 - rmse: 65.0144 - val_loss: 4467.1479 - val_r_squared: -inf - val_rmse: 70.3554
# Epoch 226/500
# 25/25 [==============================] - 0s 832us/step - loss: 4622.1201 - r_squared: 0.9558 - rmse: 66.6795 - val_loss: 4117.2593 - val_r_squared: -inf - val_rmse: 67.6870
# Epoch 227/500
# 25/25 [==============================] - 0s 684us/step - loss: 4110.1338 - r_squared: 0.9609 - rmse: 63.4757 - val_loss: 4812.4399 - val_r_squared: -inf - val_rmse: 73.1260
# Epoch 228/500
# 25/25 [==============================] - 0s 749us/step - loss: 4308.3672 - r_squared: 0.9581 - rmse: 64.6359 - val_loss: 5141.9824 - val_r_squared: -inf - val_rmse: 76.5401
# Epoch 229/500
# 25/25 [==============================] - 0s 688us/step - loss: 4238.2129 - r_squared: 0.9594 - rmse: 64.0896 - val_loss: 4185.2739 - val_r_squared: -inf - val_rmse: 68.5420
# Epoch 230/500
# 25/25 [==============================] - 0s 710us/step - loss: 4049.6868 - r_squared: 0.9615 - rmse: 63.0557 - val_loss: 4702.3838 - val_r_squared: -inf - val_rmse: 72.7186
# Epoch 231/500
# 25/25 [==============================] - 0s 708us/step - loss: 4044.7202 - r_squared: 0.9608 - rmse: 63.1316 - val_loss: 4273.2749 - val_r_squared: -inf - val_rmse: 69.3207
# Epoch 232/500
# 25/25 [==============================] - 0s 729us/step - loss: 4181.6353 - r_squared: 0.9610 - rmse: 63.4885 - val_loss: 4289.5532 - val_r_squared: -inf - val_rmse: 69.1387
# Epoch 233/500
# 25/25 [==============================] - 0s 687us/step - loss: 4184.7944 - r_squared: 0.9608 - rmse: 63.8515 - val_loss: 4285.8262 - val_r_squared: -inf - val_rmse: 69.3869
# Epoch 234/500
# 25/25 [==============================] - 0s 728us/step - loss: 4265.9878 - r_squared: 0.9606 - rmse: 63.7721 - val_loss: 4132.1719 - val_r_squared: -inf - val_rmse: 68.1391
# Epoch 235/500
# 25/25 [==============================] - 0s 699us/step - loss: 4039.6465 - r_squared: 0.9609 - rmse: 63.5746 - val_loss: 4112.2944 - val_r_squared: -inf - val_rmse: 67.9682
# Epoch 236/500
# 25/25 [==============================] - 0s 774us/step - loss: 4377.3760 - r_squared: 0.9580 - rmse: 65.3010 - val_loss: 4278.6953 - val_r_squared: -inf - val_rmse: 69.5385
# Epoch 237/500
# 25/25 [==============================] - 0s 719us/step - loss: 4100.4761 - r_squared: 0.9618 - rmse: 62.7562 - val_loss: 4247.9341 - val_r_squared: -inf - val_rmse: 68.8055
# Epoch 238/500
# 25/25 [==============================] - 0s 697us/step - loss: 4150.0615 - r_squared: 0.9605 - rmse: 63.2410 - val_loss: 4260.0454 - val_r_squared: -inf - val_rmse: 69.2232
# Epoch 239/500
# 25/25 [==============================] - 0s 681us/step - loss: 4216.2090 - r_squared: 0.9605 - rmse: 63.8403 - val_loss: 4127.8701 - val_r_squared: -inf - val_rmse: 67.8693
# Epoch 240/500
# 25/25 [==============================] - 0s 711us/step - loss: 4141.8110 - r_squared: 0.9578 - rmse: 63.9177 - val_loss: 4542.6401 - val_r_squared: -inf - val_rmse: 71.4811
# Epoch 241/500
# 25/25 [==============================] - 0s 696us/step - loss: 4284.2974 - r_squared: 0.9591 - rmse: 64.6259 - val_loss: 4714.1470 - val_r_squared: -inf - val_rmse: 72.6592
# Epoch 242/500
# 25/25 [==============================] - 0s 717us/step - loss: 4239.7432 - r_squared: 0.9550 - rmse: 64.9888 - val_loss: 5043.8599 - val_r_squared: -inf - val_rmse: 75.2926
# Epoch 243/500
# 25/25 [==============================] - 0s 705us/step - loss: 4089.3577 - r_squared: 0.9606 - rmse: 63.6724 - val_loss: 4117.6553 - val_r_squared: -inf - val_rmse: 67.9591
# Epoch 244/500
# 25/25 [==============================] - 0s 692us/step - loss: 4532.3125 - r_squared: 0.9570 - rmse: 66.6528 - val_loss: 4547.7842 - val_r_squared: -inf - val_rmse: 71.2153
# Epoch 245/500
# 25/25 [==============================] - 0s 710us/step - loss: 4105.2749 - r_squared: 0.9617 - rmse: 62.7348 - val_loss: 4423.0068 - val_r_squared: -inf - val_rmse: 70.6755
# Epoch 246/500
# 25/25 [==============================] - 0s 692us/step - loss: 4088.5325 - r_squared: 0.9617 - rmse: 63.1114 - val_loss: 4208.3003 - val_r_squared: -inf - val_rmse: 68.6636
# Epoch 247/500
# 25/25 [==============================] - 0s 660us/step - loss: 4099.1504 - r_squared: 0.9605 - rmse: 62.6506 - val_loss: 4624.4512 - val_r_squared: -inf - val_rmse: 72.3669
# Epoch 248/500
# 25/25 [==============================] - 0s 738us/step - loss: 4156.6816 - r_squared: 0.9611 - rmse: 63.0669 - val_loss: 4341.8896 - val_r_squared: -inf - val_rmse: 69.9145
# Epoch 249/500
# 25/25 [==============================] - 0s 678us/step - loss: 4180.3872 - r_squared: 0.9600 - rmse: 64.5471 - val_loss: 4459.6714 - val_r_squared: -inf - val_rmse: 70.8015
# Epoch 250/500
# 25/25 [==============================] - 0s 740us/step - loss: 4285.4819 - r_squared: 0.9596 - rmse: 63.9560 - val_loss: 4858.7407 - val_r_squared: -inf - val_rmse: 74.2222
# Epoch 251/500
# 25/25 [==============================] - 0s 657us/step - loss: 4128.3628 - r_squared: 0.9615 - rmse: 63.3621 - val_loss: 5270.7056 - val_r_squared: -inf - val_rmse: 77.4037
# Epoch 252/500
# 25/25 [==============================] - 0s 731us/step - loss: 4096.0386 - r_squared: 0.9599 - rmse: 64.1348 - val_loss: 4334.1968 - val_r_squared: -inf - val_rmse: 69.7972
# Epoch 253/500
# 25/25 [==============================] - 0s 790us/step - loss: 4261.1899 - r_squared: 0.9584 - rmse: 65.3092 - val_loss: 4229.1348 - val_r_squared: -inf - val_rmse: 68.8540
# Epoch 254/500
# 25/25 [==============================] - 0s 720us/step - loss: 4321.3843 - r_squared: 0.9582 - rmse: 64.3010 - val_loss: 4745.1914 - val_r_squared: -inf - val_rmse: 73.2110
# Epoch 255/500
# ...
# Epoch 417/500
# 25/25 [==============================] - 0s 720us/step - loss: 3935.0198 - r_squared: 0.9614 - rmse: 62.3305 - val_loss: 3956.5227 - val_r_squared: -inf - val_rmse: 67.0642
# Epoch 418/500
# 25/25 [==============================] - 0s 727us/step - loss: 3883.6189 - r_squared: 0.9643 - rmse: 60.2163 - val_loss: 4000.0232 - val_r_squared: -inf - val_rmse: 67.5004
# Epoch 419/500
# 25/25 [==============================] - 0s 703us/step - loss: 3938.8552 - r_squared: 0.9627 - rmse: 61.9463 - val_loss: 4095.1890 - val_r_squared: -inf - val_rmse: 68.3467
# Epoch 420/500
# 25/25 [==============================] - 0s 782us/step - loss: 3982.8569 - r_squared: 0.9610 - rmse: 63.0728 - val_loss: 3947.5413 - val_r_squared: -inf - val_rmse: 66.8717
# Epoch 421/500
# 25/25 [==============================] - 0s 717us/step - loss: 4060.0916 - r_squared: 0.9618 - rmse: 62.6627 - val_loss: 4147.1006 - val_r_squared: -inf - val_rmse: 68.4104
# Epoch 422/500
# 25/25 [==============================] - 0s 693us/step - loss: 4163.2300 - r_squared: 0.9613 - rmse: 63.4264 - val_loss: 4061.5132 - val_r_squared: -inf - val_rmse: 67.7260
# Epoch 423/500
# 25/25 [==============================] - 0s 710us/step - loss: 4105.2222 - r_squared: 0.9581 - rmse: 64.6389 - val_loss: 3976.7236 - val_r_squared: -inf - val_rmse: 67.2327
# Epoch 424/500
# 25/25 [==============================] - 0s 726us/step - loss: 4285.4795 - r_squared: 0.9595 - rmse: 63.9951 - val_loss: 4192.0068 - val_r_squared: -inf - val_rmse: 69.1636
# Epoch 425/500
# 25/25 [==============================] - 0s 761us/step - loss: 3922.9312 - r_squared: 0.9630 - rmse: 61.1464 - val_loss: 4173.8818 - val_r_squared: -inf - val_rmse: 69.0606
# Epoch 426/500
# 25/25 [==============================] - 0s 740us/step - loss: 3949.4509 - r_squared: 0.9621 - rmse: 62.4399 - val_loss: 3977.5903 - val_r_squared: -inf - val_rmse: 67.1490
# Epoch 427/500
# 25/25 [==============================] - 0s 723us/step - loss: 3967.6018 - r_squared: 0.9615 - rmse: 62.9018 - val_loss: 4149.1235 - val_r_squared: -inf - val_rmse: 68.7774
# Epoch 428/500
# 25/25 [==============================] - 0s 742us/step - loss: 3983.6567 - r_squared: 0.9621 - rmse: 63.0574 - val_loss: 4862.5464 - val_r_squared: -inf - val_rmse: 74.2729
# Epoch 429/500
# 25/25 [==============================] - 0s 755us/step - loss: 3961.2764 - r_squared: 0.9623 - rmse: 62.1486 - val_loss: 4010.3665 - val_r_squared: -inf - val_rmse: 67.5078
# Epoch 430/500
# 25/25 [==============================] - 0s 731us/step - loss: 3930.7905 - r_squared: 0.9628 - rmse: 62.3996 - val_loss: 3996.5801 - val_r_squared: -inf - val_rmse: 67.2967
# Epoch 431/500
# 25/25 [==============================] - 0s 712us/step - loss: 4021.0632 - r_squared: 0.9631 - rmse: 61.0731 - val_loss: 3971.6453 - val_r_squared: -inf - val_rmse: 66.9910
# Epoch 432/500
# 25/25 [==============================] - 0s 751us/step - loss: 4462.1104 - r_squared: 0.9554 - rmse: 66.6184 - val_loss: 3951.0020 - val_r_squared: -inf - val_rmse: 66.9352
# Epoch 433/500
# 25/25 [==============================] - 0s 717us/step - loss: 3951.2146 - r_squared: 0.9631 - rmse: 61.1861 - val_loss: 3977.2327 - val_r_squared: -inf - val_rmse: 67.2259
# Epoch 434/500
# 25/25 [==============================] - 0s 737us/step - loss: 4154.4248 - r_squared: 0.9602 - rmse: 63.7599 - val_loss: 4641.3184 - val_r_squared: -inf - val_rmse: 72.8782
# Epoch 435/500
# 25/25 [==============================] - 0s 707us/step - loss: 3993.5879 - r_squared: 0.9616 - rmse: 62.3586 - val_loss: 4024.6150 - val_r_squared: -inf - val_rmse: 67.6421
# Epoch 436/500
# 25/25 [==============================] - 0s 767us/step - loss: 4090.5388 - r_squared: 0.9611 - rmse: 63.1104 - val_loss: 3990.3862 - val_r_squared: -inf - val_rmse: 67.2666
# Epoch 437/500
# 25/25 [==============================] - 0s 694us/step - loss: 4015.6023 - r_squared: 0.9623 - rmse: 62.1777 - val_loss: 3947.8606 - val_r_squared: -inf - val_rmse: 66.8812
# Epoch 438/500
# 25/25 [==============================] - 0s 764us/step - loss: 3870.6694 - r_squared: 0.9627 - rmse: 61.5979 - val_loss: 4136.8213 - val_r_squared: -inf - val_rmse: 68.8078
# Epoch 439/500
# 25/25 [==============================] - 0s 767us/step - loss: 3865.3787 - r_squared: 0.9623 - rmse: 61.8905 - val_loss: 4003.7830 - val_r_squared: -inf - val_rmse: 67.4385
# Epoch 440/500
# 25/25 [==============================] - 0s 759us/step - loss: 3868.4529 - r_squared: 0.9624 - rmse: 62.1995 - val_loss: 3983.3213 - val_r_squared: -inf - val_rmse: 67.1932
# Epoch 441/500
# 25/25 [==============================] - 0s 760us/step - loss: 3997.0725 - r_squared: 0.9623 - rmse: 61.8466 - val_loss: 3956.8013 - val_r_squared: -inf - val_rmse: 67.0568
# Epoch 442/500
# 25/25 [==============================] - 0s 728us/step - loss: 3961.0479 - r_squared: 0.9618 - rmse: 61.9083 - val_loss: 4120.3403 - val_r_squared: -inf - val_rmse: 68.1612
# Epoch 443/500
# 25/25 [==============================] - 0s 745us/step - loss: 4291.2695 - r_squared: 0.9572 - rmse: 64.7987 - val_loss: 5452.1646 - val_r_squared: -inf - val_rmse: 78.9372
# Epoch 444/500
# 25/25 [==============================] - 0s 679us/step - loss: 4511.9321 - r_squared: 0.9561 - rmse: 67.1621 - val_loss: 4279.9497 - val_r_squared: -inf - val_rmse: 69.8240
# Epoch 445/500
# 25/25 [==============================] - 0s 693us/step - loss: 3926.6919 - r_squared: 0.9605 - rmse: 62.7484 - val_loss: 3993.8672 - val_r_squared: -inf - val_rmse: 67.3423
# Epoch 446/500
# 25/25 [==============================] - 0s 759us/step - loss: 3904.6077 - r_squared: 0.9632 - rmse: 60.8530 - val_loss: 3937.3557 - val_r_squared: -inf - val_rmse: 66.6921
# Epoch 447/500
# 25/25 [==============================] - 0s 688us/step - loss: 3952.3594 - r_squared: 0.9622 - rmse: 62.7596 - val_loss: 4065.7285 - val_r_squared: -inf - val_rmse: 67.7898
# Epoch 448/500
# 25/25 [==============================] - 0s 750us/step - loss: 4285.5410 - r_squared: 0.9596 - rmse: 64.4356 - val_loss: 3945.7476 - val_r_squared: -inf - val_rmse: 66.8496
# Epoch 449/500
# 25/25 [==============================] - 0s 707us/step - loss: 3964.5557 - r_squared: 0.9623 - rmse: 61.7774 - val_loss: 3997.1304 - val_r_squared: -inf - val_rmse: 67.4301
# Epoch 450/500
# 25/25 [==============================] - 0s 732us/step - loss: 4024.9270 - r_squared: 0.9620 - rmse: 61.8767 - val_loss: 4300.3447 - val_r_squared: -inf - val_rmse: 69.8938
# Epoch 451/500
# 25/25 [==============================] - 0s 699us/step - loss: 4159.8984 - r_squared: 0.9595 - rmse: 63.4561 - val_loss: 5470.6792 - val_r_squared: -inf - val_rmse: 78.9529
# Epoch 452/500
# 25/25 [==============================] - 0s 739us/step - loss: 4017.2554 - r_squared: 0.9615 - rmse: 63.4501 - val_loss: 3973.2307 - val_r_squared: -inf - val_rmse: 67.0987
# Epoch 453/500
# 25/25 [==============================] - 0s 703us/step - loss: 4403.8711 - r_squared: 0.9584 - rmse: 65.9580 - val_loss: 4291.4141 - val_r_squared: -inf - val_rmse: 69.6552
# Epoch 454/500
# 25/25 [==============================] - 0s 721us/step - loss: 4079.7639 - r_squared: 0.9616 - rmse: 62.3427 - val_loss: 5002.2651 - val_r_squared: -inf - val_rmse: 75.7305
# Epoch 455/500
# 25/25 [==============================] - 0s 698us/step - loss: 4064.8635 - r_squared: 0.9606 - rmse: 62.6855 - val_loss: 4229.9307 - val_r_squared: -inf - val_rmse: 69.0444
# Epoch 456/500
# 25/25 [==============================] - 0s 735us/step - loss: 4047.4546 - r_squared: 0.9613 - rmse: 62.2200 - val_loss: 4145.1157 - val_r_squared: -inf - val_rmse: 68.3347
# Epoch 457/500
# 25/25 [==============================] - 0s 749us/step - loss: 4221.6743 - r_squared: 0.9582 - rmse: 64.1233 - val_loss: 4269.7622 - val_r_squared: -inf - val_rmse: 69.4200
# Epoch 458/500
# 25/25 [==============================] - 0s 726us/step - loss: 4057.7190 - r_squared: 0.9596 - rmse: 63.4164 - val_loss: 4064.0173 - val_r_squared: -inf - val_rmse: 67.8090
# Epoch 459/500
# 25/25 [==============================] - 0s 722us/step - loss: 3876.7039 - r_squared: 0.9633 - rmse: 62.1197 - val_loss: 4243.1445 - val_r_squared: -inf - val_rmse: 69.4921
# Epoch 460/500
# 25/25 [==============================] - 0s 705us/step - loss: 3947.1245 - r_squared: 0.9615 - rmse: 61.5797 - val_loss: 4774.9727 - val_r_squared: -inf - val_rmse: 73.6268
# Epoch 461/500
# 25/25 [==============================] - 0s 773us/step - loss: 4010.1550 - r_squared: 0.9621 - rmse: 61.9432 - val_loss: 6345.1567 - val_r_squared: -inf - val_rmse: 85.6374
# Epoch 462/500
# 25/25 [==============================] - 0s 712us/step - loss: 4157.6294 - r_squared: 0.9582 - rmse: 63.5127 - val_loss: 4037.3611 - val_r_squared: -inf - val_rmse: 67.8292
# Epoch 463/500
# 25/25 [==============================] - 0s 747us/step - loss: 3857.4773 - r_squared: 0.9626 - rmse: 62.4630 - val_loss: 3996.8528 - val_r_squared: -inf - val_rmse: 67.1502
# Epoch 464/500
# 25/25 [==============================] - 0s 700us/step - loss: 4001.5007 - r_squared: 0.9621 - rmse: 62.9537 - val_loss: 4085.1052 - val_r_squared: -inf - val_rmse: 68.1106
# Epoch 465/500
# 25/25 [==============================] - 0s 804us/step - loss: 3913.4080 - r_squared: 0.9620 - rmse: 62.7127 - val_loss: 4364.5386 - val_r_squared: -inf - val_rmse: 70.4892
# Epoch 466/500
# 25/25 [==============================] - 0s 743us/step - loss: 3880.6428 - r_squared: 0.9633 - rmse: 61.6903 - val_loss: 4205.0093 - val_r_squared: -inf - val_rmse: 69.3378
# Epoch 467/500
# 25/25 [==============================] - 0s 777us/step - loss: 3948.6724 - r_squared: 0.9615 - rmse: 62.4299 - val_loss: 3932.1812 - val_r_squared: -inf - val_rmse: 66.6510
# Epoch 468/500
# 25/25 [==============================] - 0s 769us/step - loss: 3920.5115 - r_squared: 0.9604 - rmse: 62.5633 - val_loss: 4048.1357 - val_r_squared: -inf - val_rmse: 67.8040
# Epoch 469/500
# 25/25 [==============================] - 0s 709us/step - loss: 4128.9463 - r_squared: 0.9612 - rmse: 63.3779 - val_loss: 3969.1482 - val_r_squared: -inf - val_rmse: 66.9179
# Epoch 470/500
# 25/25 [==============================] - 0s 776us/step - loss: 3863.2278 - r_squared: 0.9639 - rmse: 60.2821 - val_loss: 5025.4121 - val_r_squared: -inf - val_rmse: 75.7084
# Epoch 471/500
# 25/25 [==============================] - 0s 685us/step - loss: 3994.2021 - r_squared: 0.9623 - rmse: 62.2695 - val_loss: 4071.9661 - val_r_squared: -inf - val_rmse: 67.7789
# Epoch 472/500
# 25/25 [==============================] - 0s 778us/step - loss: 4073.4050 - r_squared: 0.9612 - rmse: 62.7604 - val_loss: 4126.6406 - val_r_squared: -inf - val_rmse: 68.5206
# Epoch 473/500
# 25/25 [==============================] - 0s 722us/step - loss: 3873.5537 - r_squared: 0.9637 - rmse: 61.5021 - val_loss: 4276.1846 - val_r_squared: -inf - val_rmse: 69.8630
# Epoch 474/500
# 25/25 [==============================] - 0s 723us/step - loss: 3961.4126 - r_squared: 0.9630 - rmse: 61.4991 - val_loss: 4066.4832 - val_r_squared: -inf - val_rmse: 67.6837
# Epoch 475/500
# 25/25 [==============================] - 0s 707us/step - loss: 4330.4204 - r_squared: 0.9598 - rmse: 65.0205 - val_loss: 4020.6963 - val_r_squared: -inf - val_rmse: 67.2482
# Epoch 476/500
# 25/25 [==============================] - 0s 758us/step - loss: 4007.6497 - r_squared: 0.9616 - rmse: 62.3144 - val_loss: 4167.9106 - val_r_squared: -inf - val_rmse: 68.6763
# Epoch 477/500
# 25/25 [==============================] - 0s 741us/step - loss: 3905.8135 - r_squared: 0.9623 - rmse: 61.4892 - val_loss: 4808.1899 - val_r_squared: -inf - val_rmse: 74.3440
# Epoch 478/500
# 25/25 [==============================] - 0s 719us/step - loss: 3974.0706 - r_squared: 0.9629 - rmse: 61.7703 - val_loss: 4241.9766 - val_r_squared: -inf - val_rmse: 69.1285
# Epoch 479/500
# 25/25 [==============================] - 0s 718us/step - loss: 3923.8049 - r_squared: 0.9620 - rmse: 62.0951 - val_loss: 3924.4150 - val_r_squared: -inf - val_rmse: 66.6957
# Epoch 480/500
# 25/25 [==============================] - 0s 809us/step - loss: 4004.4670 - r_squared: 0.9628 - rmse: 62.2261 - val_loss: 4247.8691 - val_r_squared: -inf - val_rmse: 69.2594
# Epoch 481/500
# 25/25 [==============================] - 0s 771us/step - loss: 4026.7344 - r_squared: 0.9628 - rmse: 62.3588 - val_loss: 3963.9612 - val_r_squared: -inf - val_rmse: 66.8957
# Epoch 482/500
# 25/25 [==============================] - 0s 742us/step - loss: 4025.4336 - r_squared: 0.9615 - rmse: 63.5998 - val_loss: 3969.1992 - val_r_squared: -inf - val_rmse: 66.9591
# Epoch 483/500
# 25/25 [==============================] - 0s 740us/step - loss: 4415.5044 - r_squared: 0.9590 - rmse: 64.4364 - val_loss: 4567.4033 - val_r_squared: -inf - val_rmse: 72.0697
# Epoch 484/500
# 25/25 [==============================] - 0s 739us/step - loss: 4124.8203 - r_squared: 0.9606 - rmse: 63.2328 - val_loss: 4620.8750 - val_r_squared: -inf - val_rmse: 72.4537
# Epoch 485/500
# 25/25 [==============================] - 0s 748us/step - loss: 3871.2756 - r_squared: 0.9626 - rmse: 61.7479 - val_loss: 4050.0112 - val_r_squared: -inf - val_rmse: 67.5857
# Epoch 486/500
# 25/25 [==============================] - 0s 714us/step - loss: 4015.5059 - r_squared: 0.9618 - rmse: 63.1748 - val_loss: 3996.1453 - val_r_squared: -inf - val_rmse: 67.2850
# Epoch 487/500
# 25/25 [==============================] - 0s 722us/step - loss: 3913.2546 - r_squared: 0.9617 - rmse: 62.2113 - val_loss: 4065.1597 - val_r_squared: -inf - val_rmse: 67.8260
# Epoch 488/500
# 25/25 [==============================] - 0s 1ms/step - loss: 3926.5166 - r_squared: 0.9612 - rmse: 63.0809 - val_loss: 4133.5781 - val_r_squared: -inf - val_rmse: 68.0546
# Epoch 489/500
# 25/25 [==============================] - 0s 792us/step - loss: 4170.5767 - r_squared: 0.9603 - rmse: 62.6070 - val_loss: 3929.1643 - val_r_squared: -inf - val_rmse: 66.5871
# Epoch 490/500
# 25/25 [==============================] - 0s 787us/step - loss: 3882.6763 - r_squared: 0.9627 - rmse: 61.4854 - val_loss: 4504.4448 - val_r_squared: -inf - val_rmse: 71.3334
# Epoch 491/500
# 25/25 [==============================] - 0s 759us/step - loss: 4163.1958 - r_squared: 0.9608 - rmse: 63.6648 - val_loss: 3945.6992 - val_r_squared: -inf - val_rmse: 66.7987
# Epoch 492/500
# 25/25 [==============================] - 0s 775us/step - loss: 3813.9468 - r_squared: 0.9638 - rmse: 61.0678 - val_loss: 3913.8193 - val_r_squared: -inf - val_rmse: 66.6012
# Epoch 493/500
# 25/25 [==============================] - 0s 808us/step - loss: 3974.1262 - r_squared: 0.9627 - rmse: 61.8916 - val_loss: 3934.7954 - val_r_squared: -inf - val_rmse: 66.8647
# Epoch 494/500
# 25/25 [==============================] - 0s 743us/step - loss: 3994.2075 - r_squared: 0.9617 - rmse: 63.0977 - val_loss: 5427.5977 - val_r_squared: -inf - val_rmse: 78.8113
# Epoch 495/500
# 25/25 [==============================] - 0s 735us/step - loss: 3988.5999 - r_squared: 0.9583 - rmse: 62.7357 - val_loss: 4774.7524 - val_r_squared: -inf - val_rmse: 73.5447
# Epoch 496/500
# 25/25 [==============================] - 0s 784us/step - loss: 4147.2627 - r_squared: 0.9610 - rmse: 63.5665 - val_loss: 5657.6919 - val_r_squared: -inf - val_rmse: 80.7540
# Epoch 497/500
# 25/25 [==============================] - 0s 702us/step - loss: 3938.2344 - r_squared: 0.9634 - rmse: 61.7324 - val_loss: 4222.2134 - val_r_squared: -inf - val_rmse: 69.0476
# Epoch 498/500
# 25/25 [==============================] - 0s 694us/step - loss: 3901.7471 - r_squared: 0.9627 - rmse: 61.5299 - val_loss: 3991.2063 - val_r_squared: -inf - val_rmse: 67.2271
# Epoch 499/500
# 25/25 [==============================] - 0s 726us/step - loss: 4036.3284 - r_squared: 0.9622 - rmse: 61.8815 - val_loss: 4230.6685 - val_r_squared: -inf - val_rmse: 69.3714
# Epoch 500/500
# 25/25 [==============================] - 0s 723us/step - loss: 3867.6584 - r_squared: 0.9633 - rmse: 61.2901 - val_loss: 4032.3667 - val_r_squared: -inf - val_rmse: 67.5863
# Early stopping did not occur.
# 4/4 [==============================] - 0s 684us/step - loss: 3617.5818 - r_squared: 0.9533 - rmse: 63.3574
# Test Loss (MSE): 3617.581787109375
# Test Accuracy: 95.3319787979126
# Test RMSE: 63.357391357421875
# Num GPUs Available:  0

# %%
# Used to save the model
# model.compile(optimizer='adam', loss='mse')
# model.save('BestMethaneModel292-968-4nodes.h5')
# Out:
# /Users/benfunk/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

# Generate predictions on the test data
with tf.device('/GPU:0'):  # Optional
    y_pred = model.predict(x_test)

# Flatten y_test and y_pred for plotting
y_test_flat = y_test.numpy().flatten()
y_pred_flat = y_pred.flatten()

# Create scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(y_test_flat, y_pred_flat, alpha=0.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')

# Plot a 45-degree line for reference
plt.plot([-100, 1200], [-100, 1200], '--', color='gray')

plt.show()
# Out:
# 4/4 [==============================] - 0s 543us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = modelFinal.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 179us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = model.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 196us/step

# %%
try:
        # Try loading the model without compiling
    loadedModel = tf.keras.models.load_model(
            "/Users/benfunk/DataspellProjects/MethaneDataScience/Ben's Analysis/BestMethaneModel292-968-4nodes.keras",custom_objects={"mse_loss": mse_loss},compile=False)
        # Then, compile the model manually
    loadedModel.compile(optimizer='adam', loss=mse_loss)
except Exception as e2:
    print(f"Failed again due to: {e2}")

# %%
testData = pd.read_csv('../Raw Data/CorrectedLog.csv')
def placeholder_function(vout, vref):
    return (vref*(5-vout))/(vout*(5-vref))  # Example placeholder function

# Calculate the time difference in days since the first row (assuming each row is 5 seconds)
df1 = pd.DataFrame()
df2 = pd.DataFrame()
# Iterate through the Vout and Vref columns to create rr columns
for i in range(8):
    vout_col = f'Vout_{i}'
    vref_col = f'Vref_{i}'
    rr_col = f'rr_{i}'

    df1[rr_col] = testData.apply(lambda row: placeholder_function(row[vout_col], row[vref_col]), axis=1)
    df2[rr_col] = df1[rr_col].rolling(window=5000).mean()  # Apply rolling average


calculatedResistance = df2.mean(axis=1)


T = 23
H = 40

# New DataFrame to store calculated values
fixed_temp = pd.Series([T]*len(calculatedResistance), name='FixedTemp')
fixed_humid = pd.Series([H]*len(calculatedResistance), name='FixedHumid')

final_test_data = pd.concat([calculatedResistance.reset_index(drop=True), fixed_temp, fixed_humid], axis=1)

# Perform prediction
predictions = loadedModel.predict(final_test_data)
if len(predictions.shape) == 2 and predictions.shape[1] == 1:
    predictions = predictions.flatten()

# Create an index list
index_list = list(range(len(predictions)))
df2['Days'] = df['Days']
first_4_days_df = df2[df2['Days'] < 1]

# Calculate the mean of all columns for each of the first days
daily_averages = first_4_days_df[rr_col].mean(axis=1)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(index_list, predictions+45, linestyle='-')
plt.xlabel('Index')
plt.ylabel('Predicted PPM')
plt.title('Line Plot of Predicted PPM using Neural Network')
plt.grid(True)
plt.show()
# Out:
# 17271/17271 [==============================] - 3s 182us/step
