# %%
import pandas as pd
rootpath = r'/Users/benfunk/DataspellProjects/MethaneDataScience'
files = pd.read_csv("metafiletrue.csv")
summary = pd.DataFrame()  # empty dataframe to hold summary results


for idx, row in files.iterrows():

    print(row.Metafile)
    meta = pd.read_csv(str(row.Metafile))
    data = pd.read_csv(str(row.Datafile))

# %%
import pandas as pd
from matplotlib import pyplot as plt


file2 = pd.read_csv("Output/BenSummaryOdd.csv")
#Extract useful data
#file2 = file2[file2['Target PPM'] < 100]
xDataResistance = file2.loc[:, 'Resistance']
xDataRatio = file2.loc[:, 'Ratio']
xDataRH = file2.loc[:, 'RelativeHumidity']
xDataTemp = file2.loc[:, 'Temperature']
yDataTargetPPM = file2.loc[:, 'Target PPM']

for i in range(16):
    df = file2[file2['SensorID']==i]
    plt.scatter(df.loc[:, 'Resistance'], df.loc[:, "Target PPM"])
    plt.xlabel("Resistance"+str(i))
    plt.ylabel('Predicted PPM')
    plt.show()
