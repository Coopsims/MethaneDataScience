# %%
import tensorflow as tf
from keras import regularizers
from keras.callbacks import EarlyStopping
import tensorflow_model_optimization as tfmot
import keras
import keras as sparsity
from sklearn.model_selection import GridSearchCV
import pandas as pd
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras

# %%
# Setting the random seed so there is consistent data splitting between runs
tf.random.set_seed(42)
# importing the lowPPM matrix
allData = r"../../Output/LowPPMMatrix.csv"

# Reading in the data to csv and removing any data at 150 ppm as this was incorrect data from testing
# NOTE: the 150 ppm is not in all outputs. but it is left in as a safeguard
df = pd.read_csv(allData)
df=df[df['Target PPM']!=150]
# Dropping all unneeded columns from the output
xDataRH = df.loc[:, 'RelativeHumidity']
xDataTemp = df.loc[:, 'Temperature']
e_sat_standard = 6.112 * np.exp((17.67 * xDataTemp) / (xDataTemp + 243.5))
actual_pressure = xDataRH * e_sat_standard
xDataAH = (18.02*actual_pressure)/(100*(xDataTemp+ 273.15)*0.08314)
df['ActualHumidity'] = xDataAH

df = df.drop('RelativeHumidity', axis='columns')
df = df.drop(columns=['Unnamed: 0','lowInterval','highInterval','Ratio'])
print(df.head())

# Declaring what sensor is used for the test set
test_sensor_id = 0  # Replace with the ID of the sensor you want in the test set
train_data = df[df['SensorID'] != test_sensor_id]
test_data = df[df['SensorID'] == test_sensor_id]

# Drop the SensorID column as we don't need it anymore
train_data = train_data.drop(columns=['SensorID'])
test_data = test_data.drop(columns=['SensorID'])
# Convert to TensorFlow tensors
train_data_tf = tf.convert_to_tensor(train_data, dtype=tf.float32)
test_data_tf = tf.convert_to_tensor(test_data, dtype=tf.float32)
# Out:
#    SensorID  Target PPM  Resistance  Temperature  ActualHumidity
# 0       0.0         0.0   30.009404     0.795619        0.319002
# 1       3.0         0.0   28.086765     0.795619        0.319002
# 2       5.0         0.0   30.475486     0.795619        0.319002
# 3       7.0         0.0   31.911561     0.795619        0.319002
# 4       8.0         0.0   26.515605     0.795619        0.319002

# %%
# Randomizes the data for training to minimize fitting to false trends
train_data_shuffled = tf.random.shuffle(train_data_tf, seed=42)

# Separate features and labels
x_train, y_train = train_data_shuffled[:, 1:], train_data_shuffled[:, 0]
x_test, y_test = test_data_tf[:, 1:], test_data_tf[:, 0]

# %%
@keras.saving.register_keras_serializable()
def mse_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_pred - y_true))

@keras.saving.register_keras_serializable()
def rmse(y_true, y_pred):
    return tf.sqrt(mse_loss(y_pred, y_true))

@keras.saving.register_keras_serializable()
def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# Used to trace history of RMSE as the neural network gets trained
class RMSEHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE = []
        self.validationRMSE = []

    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE.append(logs.get('rmse'))
        self.validationRMSE.append(logs.get('val_rmse'))

# %%
rmse_history = RMSEHistory()
# Compile and train the model
input_shape = (x_train.shape[1],)

# %%
# Initialize a CSV file to store the results
csvfile = open('experiment_results.csv', 'w', newline='')
csvwriter = csv.writer(csvfile)
csvwriter.writerow(['BaseNum', 'Run', 'Test_RMSE', 'Test_Accuracy'])

for baseNum in tqdm(range(1, 16), desc='BaseNum Loop'):  # Wrap outer loop with tqdm
    for run in tqdm(range(1, 101), desc=f'Run Loop for BaseNum {baseNum}', leave=False):  # Wrap inner loop with tqdm

# Define your original model with regularization
        def build_model(input_shape, regularization_factor=0.01):
            model = tf.keras.Sequential([
                tf.keras.layers.Dense(baseNum*2, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
                tf.keras.layers.Dense(baseNum*4, activation='mish', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(1)
            ])
            return model

        with tf.device('/GPU:0'):
            model = build_model(input_shape)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.1, callbacks=[rmse_history],verbose=0)
            test_metrics = model.evaluate(x_test, y_test,verbose=0)
            test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
        # Save the results
        csvwriter.writerow([baseNum, run, test_rmse, test_accuracy])
        csvfile.flush()
csvfile.close()

# %%
df1 = pd.read_csv("./experiment_results.csv")

# Create a figure and axis object for the boxplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Create a boxplot for Test_RMSE grouped by BaseNum
df1.boxplot(column='Test_RMSE', by='BaseNum', ax=ax[0])
ax[0].set_title('Boxplot of Test_RMSE Grouped by BaseNum')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Test_RMSE')

# Create a boxplot for Test_Accuracy grouped by BaseNum
df1.boxplot(column='Test_Accuracy', by='BaseNum', ax=ax[1])
ax[1].set_title('Boxplot of Test_Accuracy Grouped by BaseNum')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Test_Accuracy')

# Show the plots
plt.suptitle('Boxplots Grouped by BaseNum')
plt.show()

# Group by BaseNum and calculate the mean
grouped_means = df1.groupby('BaseNum').mean()

# Create a figure and axis objects
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the mean of Test_RMSE
ax[0].plot(grouped_means.index, grouped_means['Test_RMSE'], label='Test_RMSE', marker='o')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Mean of Test_RMSE')
ax[0].set_title('Mean of Test_RMSE Grouped by BaseNum')
ax[0].legend()

# Plot the mean of Test_Accuracy
ax[1].plot(grouped_means.index, grouped_means['Test_Accuracy'], label='Test_Accuracy', marker='x')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Mean of Test_Accuracy')
ax[1].set_title('Mean of Test_Accuracy Grouped by BaseNum')
ax[1].legend()

# Show the plot
plt.show()

# %%
import random
from keras.src.losses import mean_squared_error

activation_functions = ['relu', 'sigmoid', 'elu', 'selu', 'swish', 'linear']

best_activation = None
lowest_mse = float('inf')
baseNum = 4
n=100
def build_model(input_shape, activations, regularization_factor=0.01,):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation=activations[0], kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation=activations[1], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation=activations[2], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation=activations[3], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model
for _ in tqdm(range(n), desc='BaseNum Loop'):
    # Randomly select activation functions for each layer
    activation = [random.choice(activation_functions) for _ in range(4)]
    rmse_list = []

    early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
    for _ in range(int(n/4)):
        # Create and train the model
        with tf.device('/GPU:0'):
    #regular model training
            model = build_model(input_shape,activation)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.1, callbacks=[early_stopping,rmse_history],verbose=0)

        # Evaluate on validation data
            y_val_pred = model.predict(x_test,verbose=0)
            rmse1 = rmse(y_test, y_val_pred)
            rmse_list.append(rmse1)

    # Average RMSE for this sequence of activations
    avg_rmse = np.mean(rmse_list)
    print(f"Average RMSE with activations {activation}: {avg_rmse}")

    # Update the best activation function if needed
    if avg_rmse < lowest_mse:
        best_activation = activation
        lowest_mse = avg_rmse

print(f"Best activation function is {best_activation} with RMSE {lowest_mse}")
# Out:
# BaseNum Loop:   1%|          | 1/100 [02:00<3:19:09, 120.70s/it]
# Average RMSE with activations ['swish', 'selu', 'relu', 'relu']: 23.442481994628906
# BaseNum Loop:   1%|          | 1/100 [02:28<4:04:41, 148.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 31
#      29     model = build_model(input_shape,activation)
#      30     model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
# ---> 31     model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)
#      33 # Evaluate on validation data
#      34     y_val_pred = model.predict(x_test,verbose=0)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:2189, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2187 self._test_counter.assign(0)
#    2188 callbacks.on_test_begin()
# -> 2189 for (
#    2190     _,
#    2191     dataset_or_iterator,
#    2192 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2193     self.reset_metrics()
#    2194     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
# NOTE: with =2 (Or any small int) it is hit or miss whether the model will go down the best optimized path. rerun a few times to determine what the best value is
#Used to quickly change size of neural net
baseNum = 16

# Define your original model with regularization
def build_model(input_shape, regularization_factor=0.01):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

best_loss = np.inf  # Initialize the best loss to infinity
with tf.device('/GPU:0'):
    #regular model training
    model = build_model(input_shape)
    model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
    model.fit(x_train, y_train, epochs=5000, batch_size=150, validation_split=0.2, callbacks=[rmse_history])
    # if no improvement has been made in 100 generations (epochs) stop the model
    if early_stopping.stopped_epoch > 0:
        print(f"Early stopping occurred at epoch {early_stopping.stopped_epoch}")
        print(f"Restoring model weights from the end of the best epoch.")
        # Load the best model after training
        model.load_weights('best_model.h5')
    else:
        print("Early stopping did not occur.")

    test_metrics = model.evaluate(x_test, y_test)
    test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
    print(f"Test Loss (MSE): {test_loss}")
    print(f"Test Accuracy: {test_accuracy*100}")
    print(f"Test RMSE: {test_rmse}")
    # Plotting RMSE values
    plt.figure(figsize=(10, 5))
    plt.plot(rmse_history.modelRMSE, label='Train RMSE')
    plt.plot(rmse_history.validationRMSE, label='Validation RMSE')
    plt.xlabel('Generation')
    plt.ylabel('RMSE')
    plt.title('RMSE During Training')
    plt.legend()
    plt.show()
# model.save('MethaneModel.keras')
# Out:
# Epoch 1/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 624.9243 - r_squared: -0.9082 - rmse: 24.9548
# Epoch 1: val_loss improved from inf to 368.95956, saving model to best_model.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 562.3336 - r_squared: -0.7562 - rmse: 23.4794 - val_loss: 368.9596 - val_r_squared: -0.4188 - val_rmse: 19.1523
# Epoch 2/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 500.2385 - r_squared: -0.4812 - rmse: 22.3179
# Epoch 2: val_loss improved from 368.95956 to 344.96179, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 417.8988 - r_squared: -0.3210 - rmse: 20.2839 - val_loss: 344.9618 - val_r_squared: -0.3261 - val_rmse: 18.5160
# Epoch 3/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 353.9288 - r_squared: -0.1712 - rmse: 18.7566
# Epoch 3: val_loss did not improve from 344.96179
# 4/4 [==============================] - 0s 3ms/step - loss: 387.3192 - r_squared: -0.2366 - rmse: 19.4159 - val_loss: 398.3033 - val_r_squared: -0.5326 - val_rmse: 19.9051
# Epoch 4/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 353.4664 - r_squared: -0.2040 - rmse: 18.7451
# Epoch 4: val_loss did not improve from 344.96179
# 4/4 [==============================] - 0s 3ms/step - loss: 392.0201 - r_squared: -0.2514 - rmse: 19.8106 - val_loss: 364.7851 - val_r_squared: -0.4030 - val_rmse: 19.0454
# Epoch 5/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 327.7733 - r_squared: -0.0761 - rmse: 18.0476
# Epoch 5: val_loss improved from 344.96179 to 333.77115, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 369.2231 - r_squared: -0.1778 - rmse: 19.2071 - val_loss: 333.7711 - val_r_squared: -0.2832 - val_rmse: 18.2139
# Epoch 6/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 316.8687 - r_squared: -0.0989 - rmse: 17.7438
# Epoch 6: val_loss improved from 333.77115 to 323.39453, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 363.2407 - r_squared: -0.1555 - rmse: 18.9123 - val_loss: 323.3945 - val_r_squared: -0.2432 - val_rmse: 17.9275
# Epoch 7/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 368.8205 - r_squared: -0.1100 - rmse: 19.1526
# Epoch 7: val_loss improved from 323.39453 to 320.91269, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 359.4247 - r_squared: -0.1494 - rmse: 19.0304 - val_loss: 320.9127 - val_r_squared: -0.2337 - val_rmse: 17.8589
# Epoch 8/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 462.6604 - r_squared: -0.2500 - rmse: 21.4636
# Epoch 8: val_loss did not improve from 320.91269
# 4/4 [==============================] - 0s 4ms/step - loss: 351.2249 - r_squared: -0.1178 - rmse: 18.5952 - val_loss: 324.2001 - val_r_squared: -0.2465 - val_rmse: 17.9513
# Epoch 9/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 339.2361 - r_squared: -0.1648 - rmse: 18.3653
# Epoch 9: val_loss did not improve from 320.91269
# 4/4 [==============================] - 0s 4ms/step - loss: 342.6387 - r_squared: -0.1103 - rmse: 18.7772 - val_loss: 326.3578 - val_r_squared: -0.2549 - val_rmse: 18.0119
# Epoch 10/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 350.2884 - r_squared: -0.0229 - rmse: 18.6643
# Epoch 10: val_loss did not improve from 320.91269
# 4/4 [==============================] - 0s 4ms/step - loss: 338.1941 - r_squared: -0.0843 - rmse: 18.3919 - val_loss: 323.2199 - val_r_squared: -0.2428 - val_rmse: 17.9251
# Epoch 11/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 351.1981 - r_squared: -0.0555 - rmse: 18.6892
# Epoch 11: val_loss improved from 320.91269 to 312.31113, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 330.7755 - r_squared: -0.0526 - rmse: 18.2144 - val_loss: 312.3111 - val_r_squared: -0.2007 - val_rmse: 17.6187
# Epoch 12/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 303.3015 - r_squared: 1.0300e-04 - rmse: 17.3611
# /Users/benfunk/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 12: val_loss improved from 312.31113 to 302.30447, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 323.7123 - r_squared: -0.0355 - rmse: 17.9895 - val_loss: 302.3045 - val_r_squared: -0.1621 - val_rmse: 17.3328
# Epoch 13/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 281.1718 - r_squared: 0.1039 - rmse: 16.7121
# Epoch 13: val_loss improved from 302.30447 to 300.56467, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 317.3395 - r_squared: -0.0261 - rmse: 17.9247 - val_loss: 300.5647 - val_r_squared: -0.1554 - val_rmse: 17.2830
# Epoch 14/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 352.9521 - r_squared: 0.0208 - rmse: 18.7374
# Epoch 14: val_loss did not improve from 300.56467
# 4/4 [==============================] - 0s 4ms/step - loss: 310.3321 - r_squared: 0.0171 - rmse: 17.4954 - val_loss: 301.3696 - val_r_squared: -0.1585 - val_rmse: 17.3066
# Epoch 15/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 288.4982 - r_squared: 0.0931 - rmse: 16.9307
# Epoch 15: val_loss improved from 300.56467 to 289.01749, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 302.8712 - r_squared: 0.0470 - rmse: 17.0464 - val_loss: 289.0175 - val_r_squared: -0.1108 - val_rmse: 16.9463
# Epoch 16/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 353.1918 - r_squared: -0.0063 - rmse: 18.7444
# Epoch 16: val_loss improved from 289.01749 to 279.41879, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 294.8654 - r_squared: 0.0545 - rmse: 17.1843 - val_loss: 279.4188 - val_r_squared: -0.0737 - val_rmse: 16.6611
# Epoch 17/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 286.7585 - r_squared: 0.1360 - rmse: 16.8799
# Epoch 17: val_loss did not improve from 279.41879
# 4/4 [==============================] - 0s 4ms/step - loss: 288.8404 - r_squared: 0.0954 - rmse: 16.7075 - val_loss: 283.1118 - val_r_squared: -0.0880 - val_rmse: 16.7718
# Epoch 18/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 287.7256 - r_squared: 0.1085 - rmse: 16.9088
# Epoch 18: val_loss improved from 279.41879 to 269.81442, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 279.0887 - r_squared: 0.0985 - rmse: 16.5705 - val_loss: 269.8144 - val_r_squared: -0.0366 - val_rmse: 16.3708
# Epoch 19/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 242.4441 - r_squared: 0.1993 - rmse: 15.5123
# Epoch 19: val_loss improved from 269.81442 to 259.73456, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 270.8804 - r_squared: 0.1418 - rmse: 16.4301 - val_loss: 259.7346 - val_r_squared: 0.0023 - val_rmse: 16.0602
# Epoch 20/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 266.7318 - r_squared: 0.1415 - rmse: 16.2766
# Epoch 20: val_loss improved from 259.73456 to 259.48911, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 261.8705 - r_squared: 0.1705 - rmse: 16.1874 - val_loss: 259.4891 - val_r_squared: 0.0033 - val_rmse: 16.0527
# Epoch 21/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 270.9691 - r_squared: 0.1631 - rmse: 16.4064
# Epoch 21: val_loss improved from 259.48911 to 245.21780, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 253.9314 - r_squared: 0.1993 - rmse: 15.8913 - val_loss: 245.2178 - val_r_squared: 0.0584 - val_rmse: 15.6020
# Epoch 22/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 242.6003 - r_squared: 0.2755 - rmse: 15.5179
# Epoch 22: val_loss improved from 245.21780 to 237.64859, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 243.6706 - r_squared: 0.2217 - rmse: 15.5439 - val_loss: 237.6486 - val_r_squared: 0.0877 - val_rmse: 15.3576
# Epoch 23/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 230.3848 - r_squared: 0.2790 - rmse: 15.1193
# Epoch 23: val_loss improved from 237.64859 to 234.23152, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 234.8615 - r_squared: 0.2664 - rmse: 15.1357 - val_loss: 234.2315 - val_r_squared: 0.1009 - val_rmse: 15.2460
# Epoch 24/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 230.6163 - r_squared: 0.3057 - rmse: 15.1270
# Epoch 24: val_loss improved from 234.23152 to 213.14113, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 228.3105 - r_squared: 0.2917 - rmse: 14.8450 - val_loss: 213.1411 - val_r_squared: 0.1825 - val_rmse: 14.5380
# Epoch 25/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 233.3002 - r_squared: 0.2961 - rmse: 15.2155
# Epoch 25: val_loss did not improve from 213.14113
# 4/4 [==============================] - 0s 4ms/step - loss: 218.5914 - r_squared: 0.3094 - rmse: 14.6127 - val_loss: 217.1369 - val_r_squared: 0.1670 - val_rmse: 14.6748
# Epoch 26/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 242.4202 - r_squared: 0.3317 - rmse: 15.5123
# Epoch 26: val_loss improved from 213.14113 to 192.49030, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 207.1942 - r_squared: 0.3488 - rmse: 14.2749 - val_loss: 192.4903 - val_r_squared: 0.2624 - val_rmse: 13.8095
# Epoch 27/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 165.3870 - r_squared: 0.4683 - rmse: 12.7906
# Epoch 27: val_loss improved from 192.49030 to 191.06105, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 191.8922 - r_squared: 0.3827 - rmse: 13.9935 - val_loss: 191.0611 - val_r_squared: 0.2679 - val_rmse: 13.7576
# Epoch 28/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 182.4241 - r_squared: 0.4042 - rmse: 13.4401
# Epoch 28: val_loss improved from 191.06105 to 178.37390, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 183.1301 - r_squared: 0.4236 - rmse: 13.3987 - val_loss: 178.3739 - val_r_squared: 0.3170 - val_rmse: 13.2885
# Epoch 29/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 157.7059 - r_squared: 0.4663 - rmse: 12.4866
# Epoch 29: val_loss improved from 178.37390 to 156.37677, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 167.8336 - r_squared: 0.4768 - rmse: 12.7374 - val_loss: 156.3768 - val_r_squared: 0.4021 - val_rmse: 12.4331
# Epoch 30/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 136.8397 - r_squared: 0.5317 - rmse: 11.6209
# Epoch 30: val_loss improved from 156.37677 to 148.89729, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 155.3678 - r_squared: 0.5153 - rmse: 12.3110 - val_loss: 148.8973 - val_r_squared: 0.4310 - val_rmse: 12.1284
# Epoch 31/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 127.6497 - r_squared: 0.6026 - rmse: 11.2183
# Epoch 31: val_loss improved from 148.89729 to 125.76583, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 138.7844 - r_squared: 0.5576 - rmse: 11.6120 - val_loss: 125.7658 - val_r_squared: 0.5205 - val_rmse: 11.1338
# Epoch 32/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 147.6742 - r_squared: 0.5622 - rmse: 12.0777
# Epoch 32: val_loss did not improve from 125.76583
# 4/4 [==============================] - 0s 4ms/step - loss: 130.8881 - r_squared: 0.5849 - rmse: 11.5130 - val_loss: 135.8829 - val_r_squared: 0.4814 - val_rmse: 11.5790
# Epoch 33/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 121.7613 - r_squared: 0.6370 - rmse: 10.9523
# Epoch 33: val_loss improved from 125.76583 to 101.21038, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 115.8280 - r_squared: 0.6356 - rmse: 10.5155 - val_loss: 101.2104 - val_r_squared: 0.6155 - val_rmse: 9.9698
# Epoch 34/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 82.5360 - r_squared: 0.6913 - rmse: 8.9846
# Epoch 34: val_loss improved from 101.21038 to 90.22535, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 104.0214 - r_squared: 0.6709 - rmse: 10.1548 - val_loss: 90.2253 - val_r_squared: 0.6580 - val_rmse: 9.4025
# Epoch 35/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 119.0714 - r_squared: 0.6422 - rmse: 10.8283
# Epoch 35: val_loss improved from 90.22535 to 82.32986, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 94.5274 - r_squared: 0.6946 - rmse: 9.5304 - val_loss: 82.3299 - val_r_squared: 0.6886 - val_rmse: 8.9725
# Epoch 36/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 110.6320 - r_squared: 0.6658 - rmse: 10.4311
# Epoch 36: val_loss improved from 82.32986 to 76.72541, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 90.5468 - r_squared: 0.7210 - rmse: 9.3083 - val_loss: 76.7254 - val_r_squared: 0.7103 - val_rmse: 8.6543
# Epoch 37/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 90.4624 - r_squared: 0.7335 - rmse: 9.4146
# Epoch 37: val_loss improved from 76.72541 to 63.08521, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 80.0815 - r_squared: 0.7336 - rmse: 8.9848 - val_loss: 63.0852 - val_r_squared: 0.7631 - val_rmse: 7.8264
# Epoch 38/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 69.2965 - r_squared: 0.7985 - rmse: 8.2136
# Epoch 38: val_loss did not improve from 63.08521
# 4/4 [==============================] - 0s 4ms/step - loss: 75.2019 - r_squared: 0.7637 - rmse: 8.6161 - val_loss: 81.6832 - val_r_squared: 0.6912 - val_rmse: 8.9357
# Epoch 39/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 81.9744 - r_squared: 0.7351 - rmse: 8.9519
# Epoch 39: val_loss did not improve from 63.08521
# 4/4 [==============================] - 0s 4ms/step - loss: 76.2526 - r_squared: 0.7699 - rmse: 8.4406 - val_loss: 68.4136 - val_r_squared: 0.7425 - val_rmse: 8.1593
# Epoch 40/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 70.1021 - r_squared: 0.7951 - rmse: 8.2621
# Epoch 40: val_loss improved from 63.08521 to 51.84819, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 67.2878 - r_squared: 0.7840 - rmse: 8.2089 - val_loss: 51.8482 - val_r_squared: 0.8066 - val_rmse: 7.0716
# Epoch 41/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 62.5592 - r_squared: 0.8141 - rmse: 7.7922
# Epoch 41: val_loss did not improve from 51.84819
# 4/4 [==============================] - 0s 4ms/step - loss: 69.1892 - r_squared: 0.7867 - rmse: 8.1463 - val_loss: 60.9689 - val_r_squared: 0.7713 - val_rmse: 7.6894
# Epoch 42/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 66.2090 - r_squared: 0.7776 - rmse: 8.0229
# Epoch 42: val_loss did not improve from 51.84819
# 4/4 [==============================] - 0s 4ms/step - loss: 67.5696 - r_squared: 0.7821 - rmse: 8.1830 - val_loss: 54.1473 - val_r_squared: 0.7977 - val_rmse: 7.2322
# Epoch 43/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 50.7973 - r_squared: 0.8564 - rmse: 6.9967
# Epoch 43: val_loss did not improve from 51.84819
# 4/4 [==============================] - 0s 4ms/step - loss: 66.5405 - r_squared: 0.7984 - rmse: 7.8531 - val_loss: 62.7686 - val_r_squared: 0.7643 - val_rmse: 7.8054
# Epoch 44/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 63.8780 - r_squared: 0.7880 - rmse: 7.8762
# Epoch 44: val_loss improved from 51.84819 to 43.82143, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 59.4836 - r_squared: 0.8174 - rmse: 7.6018 - val_loss: 43.8214 - val_r_squared: 0.8376 - val_rmse: 6.4791
# Epoch 45/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 60.1519 - r_squared: 0.8192 - rmse: 7.6360
# Epoch 45: val_loss did not improve from 43.82143
# 4/4 [==============================] - 0s 4ms/step - loss: 51.8855 - r_squared: 0.8414 - rmse: 6.9776 - val_loss: 48.7347 - val_r_squared: 0.8186 - val_rmse: 6.8478
# Epoch 46/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 59.1564 - r_squared: 0.8036 - rmse: 7.5706
# Epoch 46: val_loss did not improve from 43.82143
# 4/4 [==============================] - 0s 4ms/step - loss: 51.5007 - r_squared: 0.8400 - rmse: 6.9786 - val_loss: 44.4407 - val_r_squared: 0.8352 - val_rmse: 6.5267
# Epoch 47/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 46.3116 - r_squared: 0.8602 - rmse: 6.6685
# Epoch 47: val_loss did not improve from 43.82143
# 4/4 [==============================] - 0s 4ms/step - loss: 47.4293 - r_squared: 0.8585 - rmse: 6.6243 - val_loss: 48.1937 - val_r_squared: 0.8207 - val_rmse: 6.8082
# Epoch 48/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 47.4089 - r_squared: 0.8556 - rmse: 6.7503
# Epoch 48: val_loss improved from 43.82143 to 42.11409, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 46.3408 - r_squared: 0.8594 - rmse: 6.6105 - val_loss: 42.1141 - val_r_squared: 0.8442 - val_rmse: 6.3460
# Epoch 49/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 38.1722 - r_squared: 0.8787 - rmse: 6.0275
# Epoch 49: val_loss improved from 42.11409 to 39.95221, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 44.4579 - r_squared: 0.8526 - rmse: 6.6013 - val_loss: 39.9522 - val_r_squared: 0.8526 - val_rmse: 6.1734
# Epoch 50/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 48.9248 - r_squared: 0.8709 - rmse: 6.8617
# Epoch 50: val_loss did not improve from 39.95221
# 4/4 [==============================] - 0s 4ms/step - loss: 42.7304 - r_squared: 0.8655 - rmse: 6.4162 - val_loss: 40.7186 - val_r_squared: 0.8496 - val_rmse: 6.2351
# Epoch 51/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 31.7952 - r_squared: 0.8973 - rmse: 5.4730
# Epoch 51: val_loss improved from 39.95221 to 38.47312, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 41.9890 - r_squared: 0.8699 - rmse: 6.3473 - val_loss: 38.4731 - val_r_squared: 0.8583 - val_rmse: 6.0524
# Epoch 52/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 52.8986 - r_squared: 0.8513 - rmse: 7.1454
# Epoch 52: val_loss did not improve from 38.47312
# 4/4 [==============================] - 0s 4ms/step - loss: 40.6585 - r_squared: 0.8769 - rmse: 6.1324 - val_loss: 38.5592 - val_r_squared: 0.8580 - val_rmse: 6.0595
# Epoch 53/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 38.7152 - r_squared: 0.8791 - rmse: 6.0724
# Epoch 53: val_loss did not improve from 38.47312
# 4/4 [==============================] - 0s 4ms/step - loss: 41.0563 - r_squared: 0.8731 - rmse: 6.2437 - val_loss: 38.5755 - val_r_squared: 0.8579 - val_rmse: 6.0609
# Epoch 54/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 38.3679 - r_squared: 0.8509 - rmse: 6.0437
# Epoch 54: val_loss did not improve from 38.47312
# 4/4 [==============================] - 0s 4ms/step - loss: 38.5597 - r_squared: 0.8808 - rmse: 6.0927 - val_loss: 44.2190 - val_r_squared: 0.8361 - val_rmse: 6.5098
# Epoch 55/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 43.9659 - r_squared: 0.8798 - rmse: 6.4903
# Epoch 55: val_loss improved from 38.47312 to 37.35474, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 41.0159 - r_squared: 0.8700 - rmse: 6.3061 - val_loss: 37.3547 - val_r_squared: 0.8626 - val_rmse: 5.9593
# Epoch 56/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 37.1399 - r_squared: 0.8952 - rmse: 5.9413
# Epoch 56: val_loss improved from 37.35474 to 36.88758, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 36.8192 - r_squared: 0.8904 - rmse: 5.8586 - val_loss: 36.8876 - val_r_squared: 0.8644 - val_rmse: 5.9200
# Epoch 57/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 33.6084 - r_squared: 0.9010 - rmse: 5.6362
# Epoch 57: val_loss improved from 36.88758 to 34.77459, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 36.6514 - r_squared: 0.8908 - rmse: 5.7876 - val_loss: 34.7746 - val_r_squared: 0.8726 - val_rmse: 5.7388
# Epoch 58/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 32.3047 - r_squared: 0.9060 - rmse: 5.5194
# Epoch 58: val_loss did not improve from 34.77459
# 4/4 [==============================] - 0s 4ms/step - loss: 35.4385 - r_squared: 0.8891 - rmse: 5.8975 - val_loss: 37.5001 - val_r_squared: 0.8621 - val_rmse: 5.9715
# Epoch 59/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 34.8299 - r_squared: 0.8901 - rmse: 5.7435
# Epoch 59: val_loss improved from 34.77459 to 32.49118, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 34.7459 - r_squared: 0.8931 - rmse: 5.7813 - val_loss: 32.4912 - val_r_squared: 0.8814 - val_rmse: 5.5361
# Epoch 60/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 32.6793 - r_squared: 0.9117 - rmse: 5.5531
# Epoch 60: val_loss did not improve from 32.49118
# 4/4 [==============================] - 0s 4ms/step - loss: 34.3415 - r_squared: 0.8952 - rmse: 5.6757 - val_loss: 33.1808 - val_r_squared: 0.8788 - val_rmse: 5.5980
# Epoch 61/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 30.0729 - r_squared: 0.9051 - rmse: 5.3132
# Epoch 61: val_loss improved from 32.49118 to 31.86984, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 32.4873 - r_squared: 0.8984 - rmse: 5.5279 - val_loss: 31.8698 - val_r_squared: 0.8839 - val_rmse: 5.4796
# Epoch 62/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.7838 - r_squared: 0.9268 - rmse: 4.7896
# Epoch 62: val_loss did not improve from 31.86984
# 4/4 [==============================] - 0s 4ms/step - loss: 31.6887 - r_squared: 0.9047 - rmse: 5.4403 - val_loss: 37.4770 - val_r_squared: 0.8622 - val_rmse: 5.9693
# Epoch 63/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 33.8137 - r_squared: 0.9059 - rmse: 5.6541
# Epoch 63: val_loss improved from 31.86984 to 30.81969, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 32.3884 - r_squared: 0.9003 - rmse: 5.5046 - val_loss: 30.8197 - val_r_squared: 0.8879 - val_rmse: 5.3828
# Epoch 64/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 40.0980 - r_squared: 0.8840 - rmse: 6.1849
# Epoch 64: val_loss improved from 30.81969 to 29.88418, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 32.5878 - r_squared: 0.9057 - rmse: 5.4396 - val_loss: 29.8842 - val_r_squared: 0.8915 - val_rmse: 5.2951
# Epoch 65/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 35.9870 - r_squared: 0.8890 - rmse: 5.8430
# Epoch 65: val_loss did not improve from 29.88418
# 4/4 [==============================] - 0s 4ms/step - loss: 31.9840 - r_squared: 0.9061 - rmse: 5.4030 - val_loss: 30.4960 - val_r_squared: 0.8892 - val_rmse: 5.3525
# Epoch 66/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 29.4721 - r_squared: 0.9182 - rmse: 5.2560
# Epoch 66: val_loss did not improve from 29.88418
# 4/4 [==============================] - 0s 4ms/step - loss: 33.8741 - r_squared: 0.8933 - rmse: 5.7564 - val_loss: 31.5264 - val_r_squared: 0.8852 - val_rmse: 5.4478
# Epoch 67/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 39.8756 - r_squared: 0.8832 - rmse: 6.1667
# Epoch 67: val_loss did not improve from 29.88418
# 4/4 [==============================] - 0s 4ms/step - loss: 35.1555 - r_squared: 0.8887 - rmse: 5.8379 - val_loss: 36.4995 - val_r_squared: 0.8660 - val_rmse: 5.8865
# Epoch 68/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 34.7302 - r_squared: 0.8999 - rmse: 5.7342
# Epoch 68: val_loss did not improve from 29.88418
# 4/4 [==============================] - 0s 4ms/step - loss: 33.4426 - r_squared: 0.8971 - rmse: 5.6443 - val_loss: 43.8524 - val_r_squared: 0.8375 - val_rmse: 6.4809
# Epoch 69/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 35.1048 - r_squared: 0.9035 - rmse: 5.7667
# Epoch 69: val_loss did not improve from 29.88418
# 4/4 [==============================] - 0s 4ms/step - loss: 34.8295 - r_squared: 0.8869 - rmse: 5.8205 - val_loss: 35.8035 - val_r_squared: 0.8687 - val_rmse: 5.8270
# Epoch 70/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 45.1968 - r_squared: 0.8732 - rmse: 6.5839
# Epoch 70: val_loss improved from 29.88418 to 29.35359, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 35.1731 - r_squared: 0.8958 - rmse: 5.6930 - val_loss: 29.3536 - val_r_squared: 0.8936 - val_rmse: 5.2444
# Epoch 71/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 29.9524 - r_squared: 0.9002 - rmse: 5.3012
# Epoch 71: val_loss did not improve from 29.35359
# 4/4 [==============================] - 0s 4ms/step - loss: 32.9071 - r_squared: 0.9014 - rmse: 5.5820 - val_loss: 32.8233 - val_r_squared: 0.8802 - val_rmse: 5.5653
# Epoch 72/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.0628 - r_squared: 0.9308 - rmse: 4.7130
# Epoch 72: val_loss improved from 29.35359 to 26.63763, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 29.3709 - r_squared: 0.9125 - rmse: 5.2294 - val_loss: 26.6376 - val_r_squared: 0.9041 - val_rmse: 4.9787
# Epoch 73/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.7319 - r_squared: 0.9380 - rmse: 4.1087
# Epoch 73: val_loss did not improve from 26.63763
# 4/4 [==============================] - 0s 4ms/step - loss: 27.4079 - r_squared: 0.9179 - rmse: 5.0866 - val_loss: 29.1957 - val_r_squared: 0.8942 - val_rmse: 5.2292
# Epoch 74/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 23.5418 - r_squared: 0.9372 - rmse: 4.6573
# Epoch 74: val_loss did not improve from 26.63763
# 4/4 [==============================] - 0s 4ms/step - loss: 26.5237 - r_squared: 0.9182 - rmse: 4.9989 - val_loss: 31.1537 - val_r_squared: 0.8867 - val_rmse: 5.4131
# Epoch 75/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 27.3664 - r_squared: 0.9218 - rmse: 5.0512
# Epoch 75: val_loss improved from 26.63763 to 25.45441, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 25.8481 - r_squared: 0.9229 - rmse: 4.9270 - val_loss: 25.4544 - val_r_squared: 0.9087 - val_rmse: 4.8581
# Epoch 76/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 23.2064 - r_squared: 0.9293 - rmse: 4.6210
# Epoch 76: val_loss did not improve from 25.45441
# 4/4 [==============================] - 0s 4ms/step - loss: 26.8275 - r_squared: 0.9193 - rmse: 4.9716 - val_loss: 32.9426 - val_r_squared: 0.8797 - val_rmse: 5.5757
# Epoch 77/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 29.8806 - r_squared: 0.9088 - rmse: 5.2940
# Epoch 77: val_loss did not improve from 25.45441
# 4/4 [==============================] - 0s 4ms/step - loss: 26.0028 - r_squared: 0.9226 - rmse: 4.8772 - val_loss: 25.9120 - val_r_squared: 0.9069 - val_rmse: 4.9047
# Epoch 78/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.6834 - r_squared: 0.9299 - rmse: 4.8814
# Epoch 78: val_loss improved from 25.45441 to 23.78450, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 25.9741 - r_squared: 0.9204 - rmse: 4.9704 - val_loss: 23.7845 - val_r_squared: 0.9152 - val_rmse: 4.6827
# Epoch 79/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.0677 - r_squared: 0.9450 - rmse: 4.3831
# Epoch 79: val_loss did not improve from 23.78450
# 4/4 [==============================] - 0s 4ms/step - loss: 26.1465 - r_squared: 0.9208 - rmse: 4.9191 - val_loss: 27.8765 - val_r_squared: 0.8994 - val_rmse: 5.1009
# Epoch 80/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 29.4170 - r_squared: 0.9097 - rmse: 5.2498
# Epoch 80: val_loss did not improve from 23.78450
# 4/4 [==============================] - 0s 4ms/step - loss: 28.4594 - r_squared: 0.9143 - rmse: 5.1768 - val_loss: 25.9598 - val_r_squared: 0.9068 - val_rmse: 4.9093
# Epoch 81/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 27.2795 - r_squared: 0.9189 - rmse: 5.0420
# Epoch 81: val_loss did not improve from 23.78450
# 4/4 [==============================] - 0s 4ms/step - loss: 26.5699 - r_squared: 0.9231 - rmse: 4.9156 - val_loss: 35.9267 - val_r_squared: 0.8682 - val_rmse: 5.8367
# Epoch 82/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 31.2583 - r_squared: 0.8956 - rmse: 5.4220
# Epoch 82: val_loss did not improve from 23.78450
# 4/4 [==============================] - 0s 4ms/step - loss: 26.0251 - r_squared: 0.9228 - rmse: 4.8414 - val_loss: 24.1080 - val_r_squared: 0.9139 - val_rmse: 4.7167
# Epoch 83/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.3137 - r_squared: 0.9324 - rmse: 4.5225
# Epoch 83: val_loss did not improve from 23.78450
# 4/4 [==============================] - 0s 4ms/step - loss: 22.6597 - r_squared: 0.9326 - rmse: 4.5762 - val_loss: 24.1527 - val_r_squared: 0.9138 - val_rmse: 4.7213
# Epoch 84/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.4827 - r_squared: 0.9228 - rmse: 4.8601
# Epoch 84: val_loss improved from 23.78450 to 20.85596, saving model to best_model.h5
# 4/4 [==============================] - 0s 8ms/step - loss: 22.7453 - r_squared: 0.9346 - rmse: 4.4995 - val_loss: 20.8560 - val_r_squared: 0.9265 - val_rmse: 4.3580
# Epoch 85/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.3075 - r_squared: 0.9389 - rmse: 4.4095
# Epoch 85: val_loss did not improve from 20.85596
# 4/4 [==============================] - 0s 4ms/step - loss: 21.8661 - r_squared: 0.9360 - rmse: 4.4575 - val_loss: 21.4063 - val_r_squared: 0.9244 - val_rmse: 4.4205
# Epoch 86/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.5594 - r_squared: 0.9363 - rmse: 4.4378
# Epoch 86: val_loss did not improve from 20.85596
# 4/4 [==============================] - 0s 4ms/step - loss: 21.0043 - r_squared: 0.9383 - rmse: 4.4234 - val_loss: 23.1119 - val_r_squared: 0.9178 - val_rmse: 4.6092
# Epoch 87/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.2093 - r_squared: 0.9495 - rmse: 4.1644
# Epoch 87: val_loss improved from 20.85596 to 20.36737, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 20.4724 - r_squared: 0.9402 - rmse: 4.2732 - val_loss: 20.3674 - val_r_squared: 0.9284 - val_rmse: 4.3010
# Epoch 88/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.2193 - r_squared: 0.9194 - rmse: 4.8323
# Epoch 88: val_loss did not improve from 20.36737
# 4/4 [==============================] - 0s 4ms/step - loss: 20.3001 - r_squared: 0.9420 - rmse: 4.2238 - val_loss: 21.3280 - val_r_squared: 0.9247 - val_rmse: 4.4111
# Epoch 89/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.3465 - r_squared: 0.9459 - rmse: 4.0591
# Epoch 89: val_loss did not improve from 20.36737
# 4/4 [==============================] - 0s 4ms/step - loss: 19.9874 - r_squared: 0.9405 - rmse: 4.2720 - val_loss: 20.3765 - val_r_squared: 0.9284 - val_rmse: 4.3018
# Epoch 90/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 14.2622 - r_squared: 0.9575 - rmse: 3.5201
# Epoch 90: val_loss did not improve from 20.36737
# 4/4 [==============================] - 0s 4ms/step - loss: 20.9760 - r_squared: 0.9376 - rmse: 4.3587 - val_loss: 22.2508 - val_r_squared: 0.9212 - val_rmse: 4.5143
# Epoch 91/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.5660 - r_squared: 0.9470 - rmse: 4.2064
# Epoch 91: val_loss improved from 20.36737 to 19.65482, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 19.2823 - r_squared: 0.9448 - rmse: 4.1155 - val_loss: 19.6548 - val_r_squared: 0.9312 - val_rmse: 4.2169
# Epoch 92/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 23.9092 - r_squared: 0.9312 - rmse: 4.6943
# Epoch 92: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.5278 - r_squared: 0.9446 - rmse: 4.1118 - val_loss: 19.8686 - val_r_squared: 0.9304 - val_rmse: 4.2421
# Epoch 93/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.0013 - r_squared: 0.9399 - rmse: 4.1386
# Epoch 93: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 20.4030 - r_squared: 0.9392 - rmse: 4.3362 - val_loss: 21.0278 - val_r_squared: 0.9259 - val_rmse: 4.3764
# Epoch 94/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.4065 - r_squared: 0.9446 - rmse: 4.1871
# Epoch 94: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.3321 - r_squared: 0.9439 - rmse: 4.1863 - val_loss: 20.6300 - val_r_squared: 0.9275 - val_rmse: 4.3307
# Epoch 95/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.2139 - r_squared: 0.9436 - rmse: 4.2824
# Epoch 95: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.4052 - r_squared: 0.9450 - rmse: 4.1424 - val_loss: 22.5448 - val_r_squared: 0.9201 - val_rmse: 4.5463
# Epoch 96/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 28.2167 - r_squared: 0.9230 - rmse: 5.1323
# Epoch 96: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 23.4558 - r_squared: 0.9317 - rmse: 4.5940 - val_loss: 21.7575 - val_r_squared: 0.9231 - val_rmse: 4.4588
# Epoch 97/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.7153 - r_squared: 0.9381 - rmse: 4.7790
# Epoch 97: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 22.4461 - r_squared: 0.9326 - rmse: 4.5329 - val_loss: 21.5719 - val_r_squared: 0.9238 - val_rmse: 4.4379
# Epoch 98/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.6710 - r_squared: 0.9441 - rmse: 4.4490
# Epoch 98: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 3ms/step - loss: 19.9721 - r_squared: 0.9412 - rmse: 4.2361 - val_loss: 25.5745 - val_r_squared: 0.9083 - val_rmse: 4.8680
# Epoch 99/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.9483 - r_squared: 0.9207 - rmse: 4.8032
# Epoch 99: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 20.5045 - r_squared: 0.9383 - rmse: 4.3135 - val_loss: 22.8415 - val_r_squared: 0.9189 - val_rmse: 4.5786
# Epoch 100/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.8710 - r_squared: 0.9365 - rmse: 4.1222
# Epoch 100: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 21.6499 - r_squared: 0.9349 - rmse: 4.5275 - val_loss: 21.1781 - val_r_squared: 0.9253 - val_rmse: 4.3932
# Epoch 101/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.0993 - r_squared: 0.9490 - rmse: 4.0276
# Epoch 101: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 20.0610 - r_squared: 0.9424 - rmse: 4.2302 - val_loss: 20.6627 - val_r_squared: 0.9273 - val_rmse: 4.3340
# Epoch 102/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.5279 - r_squared: 0.9462 - rmse: 4.0803
# Epoch 102: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.2071 - r_squared: 0.9457 - rmse: 4.1446 - val_loss: 24.1935 - val_r_squared: 0.9137 - val_rmse: 4.7238
# Epoch 103/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.8638 - r_squared: 0.9423 - rmse: 3.9980
# Epoch 103: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 20.0254 - r_squared: 0.9419 - rmse: 4.1833 - val_loss: 23.9936 - val_r_squared: 0.9145 - val_rmse: 4.7025
# Epoch 104/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.4449 - r_squared: 0.9285 - rmse: 4.5349
# Epoch 104: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.4327 - r_squared: 0.9439 - rmse: 4.1567 - val_loss: 24.3572 - val_r_squared: 0.9131 - val_rmse: 4.7410
# Epoch 105/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.5591 - r_squared: 0.9402 - rmse: 4.2046
# Epoch 105: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.3902 - r_squared: 0.9447 - rmse: 4.1446 - val_loss: 20.6855 - val_r_squared: 0.9273 - val_rmse: 4.3365
# Epoch 106/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.1659 - r_squared: 0.9470 - rmse: 4.3915
# Epoch 106: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 3ms/step - loss: 18.3915 - r_squared: 0.9477 - rmse: 4.0371 - val_loss: 19.7623 - val_r_squared: 0.9308 - val_rmse: 4.2287
# Epoch 107/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.6819 - r_squared: 0.9345 - rmse: 4.5608
# Epoch 107: val_loss did not improve from 19.65482
# 4/4 [==============================] - 0s 4ms/step - loss: 19.1656 - r_squared: 0.9472 - rmse: 3.9969 - val_loss: 20.1504 - val_r_squared: 0.9293 - val_rmse: 4.2743
# Epoch 108/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.2246 - r_squared: 0.9454 - rmse: 4.1646
# Epoch 108: val_loss improved from 19.65482 to 19.20054, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 19.1587 - r_squared: 0.9431 - rmse: 4.1952 - val_loss: 19.2005 - val_r_squared: 0.9330 - val_rmse: 4.1617
# Epoch 109/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.5627 - r_squared: 0.9281 - rmse: 4.8664
# Epoch 109: val_loss did not improve from 19.20054
# 4/4 [==============================] - 0s 4ms/step - loss: 19.2399 - r_squared: 0.9470 - rmse: 4.0076 - val_loss: 22.8589 - val_r_squared: 0.9189 - val_rmse: 4.5801
# Epoch 110/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.0245 - r_squared: 0.9475 - rmse: 3.8914
# Epoch 110: val_loss did not improve from 19.20054
# 4/4 [==============================] - 0s 4ms/step - loss: 19.0795 - r_squared: 0.9444 - rmse: 4.1133 - val_loss: 19.6636 - val_r_squared: 0.9312 - val_rmse: 4.2168
# Epoch 111/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.1456 - r_squared: 0.9501 - rmse: 3.9069
# Epoch 111: val_loss did not improve from 19.20054
# 4/4 [==============================] - 0s 4ms/step - loss: 19.0720 - r_squared: 0.9453 - rmse: 4.0808 - val_loss: 29.4398 - val_r_squared: 0.8934 - val_rmse: 5.2495
# Epoch 112/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.6285 - r_squared: 0.9287 - rmse: 4.5548
# Epoch 112: val_loss improved from 19.20054 to 18.67146, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 21.4610 - r_squared: 0.9352 - rmse: 4.3789 - val_loss: 18.6715 - val_r_squared: 0.9351 - val_rmse: 4.0975
# Epoch 113/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.9189 - r_squared: 0.9460 - rmse: 4.3631
# Epoch 113: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 20.6166 - r_squared: 0.9406 - rmse: 4.3002 - val_loss: 22.8126 - val_r_squared: 0.9190 - val_rmse: 4.5750
# Epoch 114/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.8160 - r_squared: 0.9289 - rmse: 4.7889
# Epoch 114: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 23.2817 - r_squared: 0.9346 - rmse: 4.4344 - val_loss: 19.3094 - val_r_squared: 0.9326 - val_rmse: 4.1745
# Epoch 115/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 21.5557 - r_squared: 0.9452 - rmse: 4.4354
# Epoch 115: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 18.1640 - r_squared: 0.9467 - rmse: 4.0548 - val_loss: 24.7691 - val_r_squared: 0.9115 - val_rmse: 4.7839
# Epoch 116/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.9439 - r_squared: 0.9277 - rmse: 4.9051
# Epoch 116: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 18.7043 - r_squared: 0.9485 - rmse: 3.9908 - val_loss: 23.0006 - val_r_squared: 0.9183 - val_rmse: 4.5953
# Epoch 117/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.7171 - r_squared: 0.9374 - rmse: 4.2229
# Epoch 117: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 18.0696 - r_squared: 0.9496 - rmse: 3.9520 - val_loss: 20.8117 - val_r_squared: 0.9268 - val_rmse: 4.3506
# Epoch 118/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.0569 - r_squared: 0.9364 - rmse: 4.7088
# Epoch 118: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 22.1232 - r_squared: 0.9378 - rmse: 4.3792 - val_loss: 20.8561 - val_r_squared: 0.9266 - val_rmse: 4.3556
# Epoch 119/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.1897 - r_squared: 0.9491 - rmse: 4.2785
# Epoch 119: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 19.2184 - r_squared: 0.9429 - rmse: 4.1758 - val_loss: 18.8107 - val_r_squared: 0.9345 - val_rmse: 4.1141
# Epoch 120/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 19.5933 - r_squared: 0.9461 - rmse: 4.2081
# Epoch 120: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 18.4121 - r_squared: 0.9476 - rmse: 4.0224 - val_loss: 30.5572 - val_r_squared: 0.8891 - val_rmse: 5.3545
# Epoch 121/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 25.6089 - r_squared: 0.9210 - rmse: 4.8706
# Epoch 121: val_loss did not improve from 18.67146
# 4/4 [==============================] - 0s 4ms/step - loss: 21.5432 - r_squared: 0.9368 - rmse: 4.4571 - val_loss: 27.5144 - val_r_squared: 0.9009 - val_rmse: 5.0624
# Epoch 122/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 23.3405 - r_squared: 0.9254 - rmse: 4.6319
# Epoch 122: val_loss improved from 18.67146 to 18.57114, saving model to best_model.h5
# 4/4 [==============================] - 0s 7ms/step - loss: 20.1547 - r_squared: 0.9404 - rmse: 4.2394 - val_loss: 18.5711 - val_r_squared: 0.9355 - val_rmse: 4.0847
# Epoch 123/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.3390 - r_squared: 0.9389 - rmse: 3.9310
# Epoch 123: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 17.7581 - r_squared: 0.9469 - rmse: 4.0376 - val_loss: 19.2739 - val_r_squared: 0.9327 - val_rmse: 4.1698
# Epoch 124/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.9737 - r_squared: 0.9498 - rmse: 4.0108
# Epoch 124: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 17.4590 - r_squared: 0.9519 - rmse: 3.8741 - val_loss: 19.2383 - val_r_squared: 0.9329 - val_rmse: 4.1655
# Epoch 125/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.7052 - r_squared: 0.9570 - rmse: 3.9772
# Epoch 125: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 17.5091 - r_squared: 0.9483 - rmse: 3.9682 - val_loss: 19.9376 - val_r_squared: 0.9302 - val_rmse: 4.2485
# Epoch 126/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.6660 - r_squared: 0.9522 - rmse: 3.9722
# Epoch 126: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 17.4688 - r_squared: 0.9514 - rmse: 3.8794 - val_loss: 21.4824 - val_r_squared: 0.9242 - val_rmse: 4.4265
# Epoch 127/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 16.3561 - r_squared: 0.9555 - rmse: 3.8036
# Epoch 127: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 18.9517 - r_squared: 0.9456 - rmse: 4.0627 - val_loss: 19.4834 - val_r_squared: 0.9319 - val_rmse: 4.1946
# Epoch 128/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.4957 - r_squared: 0.9479 - rmse: 4.0751
# Epoch 128: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 17.8446 - r_squared: 0.9503 - rmse: 3.9330 - val_loss: 19.7288 - val_r_squared: 0.9310 - val_rmse: 4.2237
# Epoch 129/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.0407 - r_squared: 0.9340 - rmse: 4.4891
# Epoch 129: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 24.8841 - r_squared: 0.9293 - rmse: 4.6097 - val_loss: 26.6907 - val_r_squared: 0.9041 - val_rmse: 4.9801
# Epoch 130/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 38.5400 - r_squared: 0.8890 - rmse: 6.0540
# Epoch 130: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 29.2522 - r_squared: 0.9156 - rmse: 5.1075 - val_loss: 24.8666 - val_r_squared: 0.9111 - val_rmse: 4.7934
# Epoch 131/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.1722 - r_squared: 0.9419 - rmse: 4.2758
# Epoch 131: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 3ms/step - loss: 24.6107 - r_squared: 0.9290 - rmse: 4.6583 - val_loss: 35.8453 - val_r_squared: 0.8687 - val_rmse: 5.8271
# Epoch 132/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 24.8666 - r_squared: 0.9184 - rmse: 4.7934
# Epoch 132: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 24.4589 - r_squared: 0.9242 - rmse: 4.8741 - val_loss: 18.9920 - val_r_squared: 0.9338 - val_rmse: 4.1355
# Epoch 133/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 15.5788 - r_squared: 0.9548 - rmse: 3.6999
# Epoch 133: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 20.9413 - r_squared: 0.9403 - rmse: 4.3058 - val_loss: 22.9413 - val_r_squared: 0.9186 - val_rmse: 4.5883
# Epoch 134/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.0956 - r_squared: 0.9341 - rmse: 4.2670
# Epoch 134: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 23.6528 - r_squared: 0.9242 - rmse: 4.7467 - val_loss: 19.5313 - val_r_squared: 0.9318 - val_rmse: 4.2003
# Epoch 135/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 20.0959 - r_squared: 0.9440 - rmse: 4.2669
# Epoch 135: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 25.7560 - r_squared: 0.9238 - rmse: 4.8956 - val_loss: 37.6092 - val_r_squared: 0.8618 - val_rmse: 5.9765
# Epoch 136/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 32.5213 - r_squared: 0.9048 - rmse: 5.5345
# Epoch 136: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 23.9586 - r_squared: 0.9293 - rmse: 4.6539 - val_loss: 18.7688 - val_r_squared: 0.9347 - val_rmse: 4.1084
# Epoch 137/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.0438 - r_squared: 0.9427 - rmse: 4.0192
# Epoch 137: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 3ms/step - loss: 20.2998 - r_squared: 0.9422 - rmse: 4.2481 - val_loss: 23.3971 - val_r_squared: 0.9168 - val_rmse: 4.6376
# Epoch 138/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 22.6272 - r_squared: 0.9368 - rmse: 4.5539
# Epoch 138: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 20.8595 - r_squared: 0.9389 - rmse: 4.3847 - val_loss: 19.3314 - val_r_squared: 0.9325 - val_rmse: 4.1762
# Epoch 139/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 16.1741 - r_squared: 0.9517 - rmse: 3.7793
# Epoch 139: val_loss did not improve from 18.57114
# 4/4 [==============================] - 0s 4ms/step - loss: 19.8745 - r_squared: 0.9442 - rmse: 4.1788 - val_loss: 23.3529 - val_r_squared: 0.9170 - val_rmse: 4.6326
# Epoch 140/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 18.1763 - r_squared: 0.9476 - rmse: 4.0354
# Epoch 140: val_loss improved from 18.57114 to 17.97701, saving model to best_model.h5
# ...
# Epoch 4953: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.2690 - r_squared: 0.9720 - rmse: 2.9180 - val_loss: 15.0559 - val_r_squared: 0.9470 - val_rmse: 3.7015
# Epoch 4954/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.9493 - r_squared: 0.9717 - rmse: 2.9316
# Epoch 4954: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.7963 - r_squared: 0.9709 - rmse: 3.0122 - val_loss: 24.2232 - val_r_squared: 0.9115 - val_rmse: 4.7820
# Epoch 4955/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 14.9247 - r_squared: 0.9612 - rmse: 3.6836
# Epoch 4955: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7535 - r_squared: 0.9667 - rmse: 3.1851 - val_loss: 16.3067 - val_r_squared: 0.9422 - val_rmse: 3.8668
# Epoch 4956/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.8132 - r_squared: 0.9660 - rmse: 3.0755
# Epoch 4956: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.1489 - r_squared: 0.9683 - rmse: 3.1425 - val_loss: 20.2163 - val_r_squared: 0.9270 - val_rmse: 4.3430
# Epoch 4957/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 11.7427 - r_squared: 0.9659 - rmse: 3.2230
# Epoch 4957: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 11.0241 - r_squared: 0.9679 - rmse: 3.1394 - val_loss: 18.1507 - val_r_squared: 0.9350 - val_rmse: 4.0984
# Epoch 4958/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 7.5525 - r_squared: 0.9798 - rmse: 2.4897
# Epoch 4958: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.8465 - r_squared: 0.9695 - rmse: 3.0765 - val_loss: 15.2512 - val_r_squared: 0.9462 - val_rmse: 3.7278
# Epoch 4959/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.4717 - r_squared: 0.9755 - rmse: 2.8490
# Epoch 4959: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.5439 - r_squared: 0.9709 - rmse: 2.9789 - val_loss: 23.8403 - val_r_squared: 0.9130 - val_rmse: 4.7418
# Epoch 4960/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 13.2638 - r_squared: 0.9637 - rmse: 3.4509
# Epoch 4960: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.4447 - r_squared: 0.9713 - rmse: 2.9954 - val_loss: 14.8317 - val_r_squared: 0.9479 - val_rmse: 3.6711
# Epoch 4961/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 17.0109 - r_squared: 0.9496 - rmse: 3.9568
# Epoch 4961: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 12.2307 - r_squared: 0.9650 - rmse: 3.2009 - val_loss: 23.7715 - val_r_squared: 0.9133 - val_rmse: 4.7346
# Epoch 4962/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 14.6965 - r_squared: 0.9576 - rmse: 3.6525
# Epoch 4962: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.5842 - r_squared: 0.9664 - rmse: 3.2260 - val_loss: 16.0650 - val_r_squared: 0.9431 - val_rmse: 3.8354
# Epoch 4963/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.6729 - r_squared: 0.9740 - rmse: 2.8841
# Epoch 4963: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.6066 - r_squared: 0.9699 - rmse: 3.0683 - val_loss: 15.6035 - val_r_squared: 0.9449 - val_rmse: 3.7748
# Epoch 4964/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.0930 - r_squared: 0.9756 - rmse: 2.7818
# Epoch 4964: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.5982 - r_squared: 0.9700 - rmse: 3.0191 - val_loss: 19.9099 - val_r_squared: 0.9282 - val_rmse: 4.3076
# Epoch 4965/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.4859 - r_squared: 0.9760 - rmse: 2.6704
# Epoch 4965: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.5168 - r_squared: 0.9703 - rmse: 3.0770 - val_loss: 15.7428 - val_r_squared: 0.9443 - val_rmse: 3.7932
# Epoch 4966/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.7033 - r_squared: 0.9768 - rmse: 2.8894
# Epoch 4966: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 9.9959 - r_squared: 0.9719 - rmse: 2.9444 - val_loss: 16.3536 - val_r_squared: 0.9420 - val_rmse: 3.8728
# Epoch 4967/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.2352 - r_squared: 0.9733 - rmse: 2.8072
# Epoch 4967: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.4022 - r_squared: 0.9676 - rmse: 3.0950 - val_loss: 18.0039 - val_r_squared: 0.9356 - val_rmse: 4.0803
# Epoch 4968/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 7.1755 - r_squared: 0.9792 - rmse: 2.4125
# Epoch 4968: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.2074 - r_squared: 0.9704 - rmse: 2.9358 - val_loss: 16.8096 - val_r_squared: 0.9402 - val_rmse: 3.9313
# Epoch 4969/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 7.8674 - r_squared: 0.9800 - rmse: 2.5520
# Epoch 4969: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.1533 - r_squared: 0.9723 - rmse: 2.9173 - val_loss: 21.8243 - val_r_squared: 0.9208 - val_rmse: 4.5243
# Epoch 4970/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 12.9279 - r_squared: 0.9644 - rmse: 3.4019
# Epoch 4970: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.2565 - r_squared: 0.9665 - rmse: 3.1645 - val_loss: 15.9106 - val_r_squared: 0.9437 - val_rmse: 3.8153
# Epoch 4971/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.3035 - r_squared: 0.9680 - rmse: 2.9915
# Epoch 4971: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.2723 - r_squared: 0.9717 - rmse: 2.9898 - val_loss: 18.1873 - val_r_squared: 0.9349 - val_rmse: 4.1028
# Epoch 4972/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.5478 - r_squared: 0.9723 - rmse: 3.0321
# Epoch 4972: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1349 - r_squared: 0.9719 - rmse: 2.9534 - val_loss: 17.0994 - val_r_squared: 0.9391 - val_rmse: 3.9680
# Epoch 4973/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.6022 - r_squared: 0.9766 - rmse: 2.6922
# Epoch 4973: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.2576 - r_squared: 0.9729 - rmse: 2.8948 - val_loss: 15.7169 - val_r_squared: 0.9444 - val_rmse: 3.7898
# Epoch 4974/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.8003 - r_squared: 0.9700 - rmse: 3.0735
# Epoch 4974: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 9.9909 - r_squared: 0.9722 - rmse: 2.9438 - val_loss: 18.9779 - val_r_squared: 0.9318 - val_rmse: 4.1981
# Epoch 4975/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.7990 - r_squared: 0.9696 - rmse: 2.9060
# Epoch 4975: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.0378 - r_squared: 0.9723 - rmse: 2.9434 - val_loss: 17.1755 - val_r_squared: 0.9388 - val_rmse: 3.9777
# Epoch 4976/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.6560 - r_squared: 0.9729 - rmse: 2.8814
# Epoch 4976: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.0608 - r_squared: 0.9704 - rmse: 3.0121 - val_loss: 17.3012 - val_r_squared: 0.9383 - val_rmse: 3.9934
# Epoch 4977/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.5136 - r_squared: 0.9708 - rmse: 3.0265
# Epoch 4977: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.0713 - r_squared: 0.9731 - rmse: 2.8877 - val_loss: 19.4489 - val_r_squared: 0.9300 - val_rmse: 4.2538
# Epoch 4978/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.9711 - r_squared: 0.9773 - rmse: 2.7599
# Epoch 4978: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 9.9898 - r_squared: 0.9710 - rmse: 2.9833 - val_loss: 16.3804 - val_r_squared: 0.9419 - val_rmse: 3.8765
# Epoch 4979/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 13.2547 - r_squared: 0.9623 - rmse: 3.4498
# Epoch 4979: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 9.9017 - r_squared: 0.9725 - rmse: 2.8953 - val_loss: 19.2274 - val_r_squared: 0.9309 - val_rmse: 4.2277
# Epoch 4980/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 11.0639 - r_squared: 0.9659 - rmse: 3.1161
# Epoch 4980: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.4850 - r_squared: 0.9722 - rmse: 2.9278 - val_loss: 17.9244 - val_r_squared: 0.9359 - val_rmse: 4.0707
# Epoch 4981/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 6.3460 - r_squared: 0.9855 - rmse: 2.2344
# Epoch 4981: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.3315 - r_squared: 0.9692 - rmse: 3.0379 - val_loss: 14.7411 - val_r_squared: 0.9482 - val_rmse: 3.6590
# Epoch 4982/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 12.3157 - r_squared: 0.9613 - rmse: 3.3110
# Epoch 4982: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.9112 - r_squared: 0.9705 - rmse: 3.0031 - val_loss: 21.6527 - val_r_squared: 0.9215 - val_rmse: 4.5055
# Epoch 4983/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.8287 - r_squared: 0.9726 - rmse: 2.9112
# Epoch 4983: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.4289 - r_squared: 0.9688 - rmse: 3.1148 - val_loss: 15.6847 - val_r_squared: 0.9446 - val_rmse: 3.7858
# Epoch 4984/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.9278 - r_squared: 0.9713 - rmse: 3.0944
# Epoch 4984: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.2195 - r_squared: 0.9671 - rmse: 3.1888 - val_loss: 16.7906 - val_r_squared: 0.9403 - val_rmse: 3.9290
# Epoch 4985/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 11.4943 - r_squared: 0.9701 - rmse: 3.1845
# Epoch 4985: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.5056 - r_squared: 0.9718 - rmse: 2.9551 - val_loss: 21.0278 - val_r_squared: 0.9239 - val_rmse: 4.4356
# Epoch 4986/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.8528 - r_squared: 0.9774 - rmse: 2.7386
# Epoch 4986: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1471 - r_squared: 0.9727 - rmse: 2.8995 - val_loss: 15.0674 - val_r_squared: 0.9470 - val_rmse: 3.7033
# Epoch 4987/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.8822 - r_squared: 0.9731 - rmse: 2.9205
# Epoch 4987: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.1369 - r_squared: 0.9728 - rmse: 2.9162 - val_loss: 19.1995 - val_r_squared: 0.9310 - val_rmse: 4.2245
# Epoch 4988/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.6476 - r_squared: 0.9769 - rmse: 2.7008
# Epoch 4988: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.6534 - r_squared: 0.9706 - rmse: 2.9976 - val_loss: 19.1977 - val_r_squared: 0.9310 - val_rmse: 4.2242
# Epoch 4989/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 12.9058 - r_squared: 0.9650 - rmse: 3.3988
# Epoch 4989: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.3465 - r_squared: 0.9717 - rmse: 2.9530 - val_loss: 18.2121 - val_r_squared: 0.9348 - val_rmse: 4.1060
# Epoch 4990/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.0479 - r_squared: 0.9756 - rmse: 2.7739
# Epoch 4990: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 9.9301 - r_squared: 0.9713 - rmse: 2.9715 - val_loss: 15.7461 - val_r_squared: 0.9443 - val_rmse: 3.7938
# Epoch 4991/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 11.1148 - r_squared: 0.9713 - rmse: 3.1244
# Epoch 4991: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1949 - r_squared: 0.9704 - rmse: 2.9903 - val_loss: 15.4791 - val_r_squared: 0.9454 - val_rmse: 3.7585
# Epoch 4992/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 7.2119 - r_squared: 0.9784 - rmse: 2.4206
# Epoch 4992: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 3ms/step - loss: 10.4197 - r_squared: 0.9710 - rmse: 3.0046 - val_loss: 20.9661 - val_r_squared: 0.9241 - val_rmse: 4.4287
# Epoch 4993/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.3085 - r_squared: 0.9730 - rmse: 2.9926
# Epoch 4993: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.1145 - r_squared: 0.9721 - rmse: 2.9293 - val_loss: 16.2294 - val_r_squared: 0.9425 - val_rmse: 3.8571
# Epoch 4994/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 8.9676 - r_squared: 0.9761 - rmse: 2.7596
# Epoch 4994: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.3215 - r_squared: 0.9685 - rmse: 3.0323 - val_loss: 20.8837 - val_r_squared: 0.9245 - val_rmse: 4.4193
# Epoch 4995/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 11.6317 - r_squared: 0.9709 - rmse: 3.2060
# Epoch 4995: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 11.2252 - r_squared: 0.9671 - rmse: 3.2065 - val_loss: 17.0713 - val_r_squared: 0.9392 - val_rmse: 3.9647
# Epoch 4996/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.2451 - r_squared: 0.9726 - rmse: 2.8093
# Epoch 4996: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.6629 - r_squared: 0.9708 - rmse: 2.9576 - val_loss: 16.3724 - val_r_squared: 0.9419 - val_rmse: 3.8755
# Epoch 4997/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.2562 - r_squared: 0.9763 - rmse: 2.8113
# Epoch 4997: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.2979 - r_squared: 0.9707 - rmse: 2.9876 - val_loss: 21.3829 - val_r_squared: 0.9225 - val_rmse: 4.4754
# Epoch 4998/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 10.9789 - r_squared: 0.9701 - rmse: 3.1025
# Epoch 4998: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.9801 - r_squared: 0.9690 - rmse: 3.1321 - val_loss: 16.5917 - val_r_squared: 0.9411 - val_rmse: 3.9037
# Epoch 4999/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.3466 - r_squared: 0.9735 - rmse: 2.8273
# Epoch 4999: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 10.7173 - r_squared: 0.9690 - rmse: 3.1377 - val_loss: 15.5046 - val_r_squared: 0.9453 - val_rmse: 3.7619
# Epoch 5000/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 9.1212 - r_squared: 0.9733 - rmse: 2.7872
# Epoch 5000: val_loss did not improve from 13.71884
# 4/4 [==============================] - 0s 4ms/step - loss: 14.0099 - r_squared: 0.9609 - rmse: 3.4889 - val_loss: 25.1047 - val_r_squared: 0.9081 - val_rmse: 4.8734
# Early stopping did not occur.
# 3/3 [==============================] - 0s 789us/step - loss: 5.7386 - r_squared: 0.9854 - rmse: 2.0028
# Test Loss (MSE): 5.738622665405273
# Test Accuracy: 98.54328036308289
# Test RMSE: 2.002793312072754

# %%
# Used to save the model
#model.compile(optimizer='adam', loss='mse')
model.save('BestModel278nodes.keras')

# %%
import matplotlib.pyplot as plt

# Generate predictions on the test data
with tf.device('/GPU:0'):  # Optional
    y_pred = model.predict(x_test)

# Flatten y_test and y_pred for plotting
y_test_flat = y_test.numpy().flatten()
y_pred_flat = y_pred.flatten()

# Create scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(y_test_flat, y_pred_flat, alpha=0.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')

# Plot a 45-degree line for reference
plt.plot([-100, 1200], [-100, 1200], '--', color='gray')

plt.show()
# Out:
# 4/4 [==============================] - 0s 543us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = modelFinal.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 179us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = model.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 196us/step

# %%
try:
        # Try loading the model without compiling
    loadedModel = tf.keras.models.load_model(
            "/Users/benfunk/DataspellProjects/MethaneDataScience/Ben's Analysis/BestMethaneModel292-968-4nodes.keras",custom_objects={"mse_loss": mse_loss},compile=False)
        # Then, compile the model manually
    loadedModel.compile(optimizer='adam', loss=mse_loss)
except Exception as e2:
    print(f"Failed again due to: {e2}")

# %%
testData = pd.read_csv('../Raw Data/CorrectedLog.csv')
def placeholder_function(vout, vref):
    return (vref*(5-vout))/(vout*(5-vref))  # Example placeholder function

# Calculate the time difference in days since the first row (assuming each row is 5 seconds)
df1 = pd.DataFrame()
df2 = pd.DataFrame()
# Iterate through the Vout and Vref columns to create rr columns
for i in range(8):
    vout_col = f'Vout_{i}'
    vref_col = f'Vref_{i}'
    rr_col = f'rr_{i}'

    df1[rr_col] = testData.apply(lambda row: placeholder_function(row[vout_col], row[vref_col]), axis=1)
    df2[rr_col] = df1[rr_col].rolling(window=5000).mean()  # Apply rolling average


calculatedResistance = df2.mean(axis=1)


T = 23
H = 40

# New DataFrame to store calculated values
fixed_temp = pd.Series([T]*len(calculatedResistance), name='FixedTemp')
fixed_humid = pd.Series([H]*len(calculatedResistance), name='FixedHumid')

final_test_data = pd.concat([calculatedResistance.reset_index(drop=True), fixed_temp, fixed_humid], axis=1)

# Perform prediction
predictions = loadedModel.predict(final_test_data)
if len(predictions.shape) == 2 and predictions.shape[1] == 1:
    predictions = predictions.flatten()

# Create an index list
index_list = list(range(len(predictions)))
df2['Days'] = df['Days']
first_4_days_df = df2[df2['Days'] < 1]

# Calculate the mean of all columns for each of the first days
daily_averages = first_4_days_df[rr_col].mean(axis=1)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(index_list, predictions+45, linestyle='-')
plt.xlabel('Index')
plt.ylabel('Predicted PPM')
plt.title('Line Plot of Predicted PPM using Neural Network')
plt.grid(True)
plt.show()
# Out:
# 17271/17271 [==============================] - 3s 182us/step
