# %%
import tensorflow as tf
from keras import regularizers
from keras.callbacks import EarlyStopping
import tensorflow_model_optimization as tfmot
import keras
import keras as sparsity
from sklearn.model_selection import GridSearchCV
import pandas as pd
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras

# %%
# Setting the random seed so there is consistent data splitting between runs
tf.random.set_seed(42)
# importing the lowPPM matrix
allData = r"/Users/benfunk/DataspellProjects/MethaneDataScience/Output/FullVOMatrix.csv"

# Reading in the data to csv and removing any data at 150 ppm as this was incorrect data from testing
# NOTE: the 150 ppm is not in all outputs. but it is left in as a safeguard
df = pd.read_csv(allData)
df=df[df['Target PPM']!=150]
# Dropping all unneeded columns from the output
xDataRH = df.loc[:, 'RelativeHumidity']
xDataTemp = df.loc[:, 'Temperature']
e_sat_standard = 6.112 * np.exp((17.67 * xDataTemp) / (xDataTemp + 243.5))
actual_pressure = xDataRH * e_sat_standard
xDataAH = (18.02*actual_pressure)/(100*(xDataTemp+ 273.15)*0.08314)
df['ActualHumidity'] = xDataAH

df = df.drop('RelativeHumidity', axis='columns')
df = df.drop(columns=['Unnamed: 0','lowInterval','highInterval','Ratio'])
print(df.head())
df['Target PPM'] = df['Target PPM'] + 4.16
# Declaring what sensor is used for the test set
test_sensor_id = 0  # Replace with the ID of the sensor you want in the test set
train_data = df[df['SensorID'] != test_sensor_id]
test_data = df[df['SensorID'] == test_sensor_id]

# Drop the SensorID column as we don't need it anymore
train_data = train_data.drop(columns=['SensorID'])
test_data = test_data.drop(columns=['SensorID'])
# Convert to TensorFlow tensors
train_data_tf = tf.convert_to_tensor(train_data, dtype=tf.float32)
test_data_tf = tf.convert_to_tensor(test_data, dtype=tf.float32)
# Out:
#    SensorID  Target PPM  Resistance  Temperature  ActualHumidity
# 0       0.0         0.0    1.001223     0.718053        0.831727
# 1       3.0         0.0    1.000915     0.718053        0.831727
# 2       5.0         0.0    1.001116     0.718053        0.831727
# 3       7.0         0.0    1.001661     0.718053        0.831727
# 4       8.0         0.0    1.002529     0.718053        0.831727

# %%
# Randomizes the data for training to minimize fitting to false trends
train_data_shuffled = tf.random.shuffle(train_data_tf, seed=42)

# Separate features and labels
x_train, y_train = train_data_shuffled[:, 1:], train_data_shuffled[:, 0]
x_test, y_test = test_data_tf[:, 1:], test_data_tf[:, 0]

# %%
@keras.saving.register_keras_serializable()
def mse_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_pred - y_true))

@keras.saving.register_keras_serializable()
def rmse(y_true, y_pred):
    return tf.sqrt(mse_loss(y_pred, y_true))

@keras.saving.register_keras_serializable()
def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# Used to trace history of RMSE as the neural network gets trained
class RMSEHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE = []
        self.validationRMSE = []

    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE.append(logs.get('rmse'))
        self.validationRMSE.append(logs.get('val_rmse'))

# %%
rmse_history = RMSEHistory()
# Compile and train the model
input_shape = (x_train.shape[1],)

# %%
# # Initialize a CSV file to store the results
# csvfile = open('experiment_results.csv', 'w', newline='')
# csvwriter = csv.writer(csvfile)
# csvwriter.writerow(['BaseNum', 'Run', 'Test_RMSE', 'Test_Accuracy'])
#
# for baseNum in tqdm(range(1, 16), desc='BaseNum Loop'):  # Wrap outer loop with tqdm
#     for run in tqdm(range(1, 101), desc=f'Run Loop for BaseNum {baseNum}', leave=False):  # Wrap inner loop with tqdm
#
# # Define your original model with regularization
#         def build_model(input_shape, regularization_factor=0.01):
#             model = tf.keras.Sequential([
#                 tf.keras.layers.Dense(baseNum*2, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
#                 tf.keras.layers.Dense(baseNum*4, activation='mish', kernel_regularizer=regularizers.l2(regularization_factor)),
#                 tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
#                 tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
#         # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
#                 tf.keras.layers.Dense(1)
#             ])
#             return model
#
#         with tf.device('/GPU:0'):
#             model = build_model(input_shape)
#             model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
#             model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.1, callbacks=[rmse_history],verbose=0)
#             test_metrics = model.evaluate(x_test, y_test,verbose=0)
#             test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
#         # Save the results
#         csvwriter.writerow([baseNum, run, test_rmse, test_accuracy])
#         csvfile.flush()
# csvfile.close()

# %%
# df1 = pd.read_csv("./experiment_results.csv")
#
# # Create a figure and axis object for the boxplots
# fig, ax = plt.subplots(1, 2, figsize=(14, 6))
#
# # Create a boxplot for Test_RMSE grouped by BaseNum
# df1.boxplot(column='Test_RMSE', by='BaseNum', ax=ax[0])
# ax[0].set_title('Boxplot of Test_RMSE Grouped by BaseNum')
# ax[0].set_xlabel('BaseNum')
# ax[0].set_ylabel('Test_RMSE')
#
# # Create a boxplot for Test_Accuracy grouped by BaseNum
# df1.boxplot(column='Test_Accuracy', by='BaseNum', ax=ax[1])
# ax[1].set_title('Boxplot of Test_Accuracy Grouped by BaseNum')
# ax[1].set_xlabel('BaseNum')
# ax[1].set_ylabel('Test_Accuracy')
#
# # Show the plots
# plt.suptitle('Boxplots Grouped by BaseNum')
# plt.show()
#
# # Group by BaseNum and calculate the mean
# grouped_means = df1.groupby('BaseNum').mean()
#
# # Create a figure and axis objects
# fig, ax = plt.subplots(1, 2, figsize=(14, 6))
#
# # Plot the mean of Test_RMSE
# ax[0].plot(grouped_means.index, grouped_means['Test_RMSE'], label='Test_RMSE', marker='o')
# ax[0].set_xlabel('BaseNum')
# ax[0].set_ylabel('Mean of Test_RMSE')
# ax[0].set_title('Mean of Test_RMSE Grouped by BaseNum')
# ax[0].legend()
#
# # Plot the mean of Test_Accuracy
# ax[1].plot(grouped_means.index, grouped_means['Test_Accuracy'], label='Test_Accuracy', marker='x')
# ax[1].set_xlabel('BaseNum')
# ax[1].set_ylabel('Mean of Test_Accuracy')
# ax[1].set_title('Mean of Test_Accuracy Grouped by BaseNum')
# ax[1].legend()
#
# # Show the plot
# plt.show()

# %%
import random
from keras.src.losses import mean_squared_error

activation_functions = ['relu', 'sigmoid', 'elu', 'selu', 'swish', 'linear']

best_activation = None
lowest_mse = float('inf')
baseNum = 4
n=100
def build_model(input_shape, activations, regularization_factor=0.01,):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation=activations[0], kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation=activations[1], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation=activations[2], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation=activations[3], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model
for _ in tqdm(range(n), desc='BaseNum Loop'):
    # Randomly select activation functions for each layer
    activation = [random.choice(activation_functions) for _ in range(4)]
    rmse_list = []

    early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
    for _ in range(int(n/4)):
        # Create and train the model
        with tf.device('/GPU:0'):
    #regular model training
            model = build_model(input_shape,activation)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.1, callbacks=[early_stopping,rmse_history],verbose=0)

        # Evaluate on validation data
            y_val_pred = model.predict(x_test,verbose=0)
            rmse1 = rmse(y_test, y_val_pred)
            rmse_list.append(rmse1)

    # Average RMSE for this sequence of activations
    avg_rmse = np.mean(rmse_list)
    print(f"Average RMSE with activations {activation}: {avg_rmse}")

    # Update the best activation function if needed
    if avg_rmse < lowest_mse:
        best_activation = activation
        lowest_mse = avg_rmse

print(f"Best activation function is {best_activation} with RMSE {lowest_mse}")
# Out:
# BaseNum Loop:   1%|          | 1/100 [02:00<3:19:09, 120.70s/it]
# Average RMSE with activations ['swish', 'selu', 'relu', 'relu']: 23.442481994628906
# BaseNum Loop:   1%|          | 1/100 [02:28<4:04:41, 148.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 31
#      29     model = build_model(input_shape,activation)
#      30     model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
# ---> 31     model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)
#      33 # Evaluate on validation data
#      34     y_val_pred = model.predict(x_test,verbose=0)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:2189, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2187 self._test_counter.assign(0)
#    2188 callbacks.on_test_begin()
# -> 2189 for (
#    2190     _,
#    2191     dataset_or_iterator,
#    2192 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2193     self.reset_metrics()
#    2194     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
# NOTE: with =2 (Or any small int) it is hit or miss whether the model will go down the best optimized path. rerun a few times to determine what the best value is
#Used to quickly change size of neural net
baseNum = 16

# Define your original model with regularization
def build_model(input_shape, regularization_factor=0.01):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

best_loss = np.inf  # Initialize the best loss to infinity
with tf.device('/GPU:0'):
    #regular model training
    model = build_model(input_shape)
    model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
    model.fit(x_train, y_train, epochs=1000, batch_size=150, validation_split=0.1, callbacks=[rmse_history])
    # if no improvement has been made in 100 generations (epochs) stop the model
    if early_stopping.stopped_epoch > 0:
        print(f"Early stopping occurred at epoch {early_stopping.stopped_epoch}")
        print(f"Restoring model weights from the end of the best epoch.")
        # Load the best model after training
        model.load_weights('best_model.h5')
    else:
        print("Early stopping did not occur.")

    test_metrics = model.evaluate(x_test, y_test)
    test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
    print(f"Test Loss (MSE): {test_loss}")
    print(f"Test Accuracy: {test_accuracy*100}")
    print(f"Test RMSE: {test_rmse}")
    # Plotting RMSE values
    plt.figure(figsize=(10, 5))
    plt.plot(rmse_history.modelRMSE, label='Train RMSE')
    plt.plot(rmse_history.validationRMSE, label='Validation RMSE')
    plt.xlabel('Generation')
    plt.ylabel('RMSE')
    plt.title('RMSE During Training')
    plt.legend()
    plt.show()
# model.save('MethaneModel.keras')
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 570.6279 - r_squared: -0.8357 - rmse: 23.6829 - val_loss: 498.2296 - val_r_squared: -0.8924 - val_rmse: 22.2723
# Epoch 2/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 470.5585 - r_squared: -0.5325 - rmse: 21.6851 - val_loss: 467.3683 - val_r_squared: -0.7747 - val_rmse: 21.5689
# Epoch 3/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 441.9726 - r_squared: -0.4372 - rmse: 20.9260 - val_loss: 427.1868 - val_r_squared: -0.6215 - val_rmse: 20.6170
# Epoch 4/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 409.4185 - r_squared: -0.3288 - rmse: 20.1695 - val_loss: 410.7640 - val_r_squared: -0.5589 - val_rmse: 20.2152
# Epoch 5/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 395.4572 - r_squared: -0.2780 - rmse: 19.7511 - val_loss: 403.1809 - val_r_squared: -0.5301 - val_rmse: 20.0271
# Epoch 6/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 382.2312 - r_squared: -0.2394 - rmse: 19.4018 - val_loss: 382.0650 - val_r_squared: -0.4496 - val_rmse: 19.4931
# Epoch 7/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 364.9754 - r_squared: -0.1791 - rmse: 19.0449 - val_loss: 362.3126 - val_r_squared: -0.3742 - val_rmse: 18.9799
# Epoch 8/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 349.5685 - r_squared: -0.1425 - rmse: 18.6900 - val_loss: 340.1543 - val_r_squared: -0.2897 - val_rmse: 18.3870
# Epoch 9/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 330.8587 - r_squared: -0.0749 - rmse: 18.1529 - val_loss: 318.1112 - val_r_squared: -0.2056 - val_rmse: 17.7775
# Epoch 10/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 319.3251 - r_squared: -0.0379 - rmse: 17.8439 - val_loss: 300.8816 - val_r_squared: -0.1399 - val_rmse: 17.2861
# Epoch 11/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 317.0574 - r_squared: -0.0399 - rmse: 17.7806 - val_loss: 294.3454 - val_r_squared: -0.1150 - val_rmse: 17.0961
# Epoch 12/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 314.8403 - r_squared: -0.0200 - rmse: 17.6859 - val_loss: 288.8573 - val_r_squared: -0.0941 - val_rmse: 16.9351
# Epoch 13/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 310.5850 - r_squared: -0.0082 - rmse: 17.5554 - val_loss: 286.1778 - val_r_squared: -0.0839 - val_rmse: 16.8562
# Epoch 14/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 308.1071 - r_squared: -0.0070 - rmse: 17.4313 - val_loss: 286.3902 - val_r_squared: -0.0848 - val_rmse: 16.8628
# Epoch 15/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 304.9785 - r_squared: 0.0130 - rmse: 17.3698 - val_loss: 287.3954 - val_r_squared: -0.0886 - val_rmse: 16.8929
# Epoch 16/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 303.9797 - r_squared: 0.0105 - rmse: 17.3935 - val_loss: 283.4073 - val_r_squared: -0.0735 - val_rmse: 16.7747
# Epoch 17/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 304.5649 - r_squared: 0.0124 - rmse: 17.4198 - val_loss: 283.3614 - val_r_squared: -0.0733 - val_rmse: 16.7735
# Epoch 18/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 300.5916 - r_squared: 0.0214 - rmse: 17.2981 - val_loss: 280.0833 - val_r_squared: -0.0608 - val_rmse: 16.6757
# Epoch 19/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 298.6133 - r_squared: 0.0274 - rmse: 17.1545 - val_loss: 276.7788 - val_r_squared: -0.0482 - val_rmse: 16.5764
# Epoch 20/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 297.5047 - r_squared: 0.0365 - rmse: 17.0905 - val_loss: 274.6617 - val_r_squared: -0.0402 - val_rmse: 16.5125
# Epoch 21/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 296.2309 - r_squared: 0.0365 - rmse: 17.2178 - val_loss: 272.4407 - val_r_squared: -0.0317 - val_rmse: 16.4452
# Epoch 22/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 299.1468 - r_squared: 0.0223 - rmse: 17.2058 - val_loss: 272.6483 - val_r_squared: -0.0325 - val_rmse: 16.4516
# Epoch 23/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 294.2057 - r_squared: 0.0412 - rmse: 17.1388 - val_loss: 271.1560 - val_r_squared: -0.0268 - val_rmse: 16.4063
# Epoch 24/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 289.5019 - r_squared: 0.0620 - rmse: 16.9545 - val_loss: 269.4568 - val_r_squared: -0.0203 - val_rmse: 16.3544
# Epoch 25/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 286.4362 - r_squared: 0.0718 - rmse: 16.8113 - val_loss: 265.8197 - val_r_squared: -0.0065 - val_rmse: 16.2428
# Epoch 26/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 285.7211 - r_squared: 0.0691 - rmse: 16.8628 - val_loss: 262.6742 - val_r_squared: 0.0055 - val_rmse: 16.1456
# Epoch 27/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 282.4031 - r_squared: 0.0861 - rmse: 16.6701 - val_loss: 257.2203 - val_r_squared: 0.0264 - val_rmse: 15.9757
# Epoch 28/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 278.8041 - r_squared: 0.0977 - rmse: 16.6318 - val_loss: 256.0414 - val_r_squared: 0.0309 - val_rmse: 15.9387
# Epoch 29/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 273.9092 - r_squared: 0.1099 - rmse: 16.4952 - val_loss: 250.4653 - val_r_squared: 0.0522 - val_rmse: 15.7626
# Epoch 30/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 268.2198 - r_squared: 0.1353 - rmse: 16.3183 - val_loss: 246.3061 - val_r_squared: 0.0681 - val_rmse: 15.6300
# Epoch 31/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 262.4852 - r_squared: 0.1508 - rmse: 16.1172 - val_loss: 235.6872 - val_r_squared: 0.1086 - val_rmse: 15.2861
# Epoch 32/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 255.7648 - r_squared: 0.1685 - rmse: 15.9098 - val_loss: 229.7373 - val_r_squared: 0.1313 - val_rmse: 15.0899
# Epoch 33/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 250.9007 - r_squared: 0.1883 - rmse: 15.7801 - val_loss: 231.1334 - val_r_squared: 0.1261 - val_rmse: 15.1357
# Epoch 34/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 247.2146 - r_squared: 0.2015 - rmse: 15.6458 - val_loss: 233.3164 - val_r_squared: 0.1178 - val_rmse: 15.2072
# Epoch 35/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 238.6803 - r_squared: 0.2327 - rmse: 15.3266 - val_loss: 204.6091 - val_r_squared: 0.2274 - val_rmse: 14.2316
# Epoch 36/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 224.6779 - r_squared: 0.2755 - rmse: 14.9720 - val_loss: 198.1077 - val_r_squared: 0.2522 - val_rmse: 14.0008
# Epoch 37/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 199.0900 - r_squared: 0.3536 - rmse: 14.0618 - val_loss: 174.0800 - val_r_squared: 0.3439 - val_rmse: 13.1140
# Epoch 38/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 182.9998 - r_squared: 0.4097 - rmse: 13.4446 - val_loss: 149.0826 - val_r_squared: 0.4394 - val_rmse: 12.1228
# Epoch 39/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 155.6590 - r_squared: 0.4994 - rmse: 12.4031 - val_loss: 161.0427 - val_r_squared: 0.3938 - val_rmse: 12.6055
# Epoch 40/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 146.1322 - r_squared: 0.5374 - rmse: 11.8739 - val_loss: 131.1755 - val_r_squared: 0.5078 - val_rmse: 11.3583
# Epoch 41/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 131.1568 - r_squared: 0.5801 - rmse: 11.2525 - val_loss: 104.6177 - val_r_squared: 0.6092 - val_rmse: 10.1209
# Epoch 42/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 107.3878 - r_squared: 0.6513 - rmse: 10.3175 - val_loss: 99.4398 - val_r_squared: 0.6291 - val_rmse: 9.8608
# Epoch 43/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 98.9203 - r_squared: 0.6870 - rmse: 9.7589 - val_loss: 62.1641 - val_r_squared: 0.7713 - val_rmse: 7.7424
# Epoch 44/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 78.8506 - r_squared: 0.7508 - rmse: 8.6793 - val_loss: 93.4295 - val_r_squared: 0.6521 - val_rmse: 9.5497
# Epoch 45/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 78.7573 - r_squared: 0.7531 - rmse: 8.6472 - val_loss: 57.0519 - val_r_squared: 0.7909 - val_rmse: 7.4034
# Epoch 46/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 66.8543 - r_squared: 0.7887 - rmse: 8.0228 - val_loss: 43.3110 - val_r_squared: 0.8434 - val_rmse: 6.4080
# Epoch 47/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 49.4252 - r_squared: 0.8465 - rmse: 6.8564 - val_loss: 37.9384 - val_r_squared: 0.8639 - val_rmse: 5.9734
# Epoch 48/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 43.0301 - r_squared: 0.8644 - rmse: 6.3947 - val_loss: 54.6915 - val_r_squared: 0.8000 - val_rmse: 7.2407
# Epoch 49/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 56.8181 - r_squared: 0.8187 - rmse: 7.3809 - val_loss: 127.8792 - val_r_squared: 0.5208 - val_rmse: 11.2076
# Epoch 50/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 70.6196 - r_squared: 0.7823 - rmse: 7.9784 - val_loss: 70.6207 - val_r_squared: 0.7393 - val_rmse: 8.2675
# Epoch 51/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 54.9666 - r_squared: 0.8307 - rmse: 7.1269 - val_loss: 44.1152 - val_r_squared: 0.8404 - val_rmse: 6.4686
# Epoch 52/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 40.8019 - r_squared: 0.8739 - rmse: 6.1694 - val_loss: 35.1251 - val_r_squared: 0.8747 - val_rmse: 5.7314
# Epoch 53/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 36.8578 - r_squared: 0.8860 - rmse: 5.8755 - val_loss: 37.8523 - val_r_squared: 0.8643 - val_rmse: 5.9642
# Epoch 54/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 39.3658 - r_squared: 0.8776 - rmse: 6.0821 - val_loss: 30.8598 - val_r_squared: 0.8910 - val_rmse: 5.3454
# Epoch 55/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 30.4863 - r_squared: 0.9077 - rmse: 5.2686 - val_loss: 36.2174 - val_r_squared: 0.8706 - val_rmse: 5.8246
# Epoch 56/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 30.8146 - r_squared: 0.9073 - rmse: 5.2772 - val_loss: 27.2076 - val_r_squared: 0.9050 - val_rmse: 4.9911
# Epoch 57/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 27.2864 - r_squared: 0.9196 - rmse: 4.9513 - val_loss: 22.6523 - val_r_squared: 0.9224 - val_rmse: 4.5110
# Epoch 58/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 22.2139 - r_squared: 0.9336 - rmse: 4.4830 - val_loss: 21.8460 - val_r_squared: 0.9255 - val_rmse: 4.4201
# Epoch 59/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 23.0209 - r_squared: 0.9307 - rmse: 4.5411 - val_loss: 22.1948 - val_r_squared: 0.9242 - val_rmse: 4.4587
# Epoch 60/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 19.7054 - r_squared: 0.9426 - rmse: 4.1628 - val_loss: 24.3786 - val_r_squared: 0.9159 - val_rmse: 4.6965
# Epoch 61/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 22.3136 - r_squared: 0.9328 - rmse: 4.4886 - val_loss: 19.4825 - val_r_squared: 0.9345 - val_rmse: 4.1421
# Epoch 62/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 24.3048 - r_squared: 0.9284 - rmse: 4.6684 - val_loss: 28.4798 - val_r_squared: 0.9002 - val_rmse: 5.1138
# Epoch 63/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 20.0683 - r_squared: 0.9421 - rmse: 4.1561 - val_loss: 21.0376 - val_r_squared: 0.9286 - val_rmse: 4.3248
# Epoch 64/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.8873 - r_squared: 0.9526 - rmse: 3.7995 - val_loss: 28.8449 - val_r_squared: 0.8989 - val_rmse: 5.1486
# Epoch 65/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 18.8578 - r_squared: 0.9462 - rmse: 3.9984 - val_loss: 16.1283 - val_r_squared: 0.9474 - val_rmse: 3.7131
# Epoch 66/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 23.7378 - r_squared: 0.9264 - rmse: 4.6288 - val_loss: 52.2815 - val_r_squared: 0.8095 - val_rmse: 7.0667
# Epoch 67/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 40.5421 - r_squared: 0.8799 - rmse: 5.8071 - val_loss: 63.5722 - val_r_squared: 0.7664 - val_rmse: 7.8248
# Epoch 68/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 34.7191 - r_squared: 0.8976 - rmse: 5.4100 - val_loss: 41.9194 - val_r_squared: 0.8490 - val_rmse: 6.2909
# Epoch 69/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 29.1640 - r_squared: 0.9162 - rmse: 4.9607 - val_loss: 34.9056 - val_r_squared: 0.8758 - val_rmse: 5.7063
# Epoch 70/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 30.2478 - r_squared: 0.9082 - rmse: 5.0798 - val_loss: 29.9722 - val_r_squared: 0.8946 - val_rmse: 5.2562
# Epoch 71/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 25.4835 - r_squared: 0.9266 - rmse: 4.7271 - val_loss: 29.2272 - val_r_squared: 0.8975 - val_rmse: 5.1847
# Epoch 72/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 21.9480 - r_squared: 0.9365 - rmse: 4.2920 - val_loss: 34.3180 - val_r_squared: 0.8780 - val_rmse: 5.6543
# Epoch 73/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 30.7480 - r_squared: 0.9110 - rmse: 5.0689 - val_loss: 28.9861 - val_r_squared: 0.8984 - val_rmse: 5.1613
# Epoch 74/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 17.2669 - r_squared: 0.9526 - rmse: 3.7641 - val_loss: 17.8679 - val_r_squared: 0.9408 - val_rmse: 3.9396
# Epoch 75/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.9845 - r_squared: 0.9525 - rmse: 3.7753 - val_loss: 20.3623 - val_r_squared: 0.9313 - val_rmse: 4.2443
# Epoch 76/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.8039 - r_squared: 0.9627 - rmse: 3.3675 - val_loss: 14.5148 - val_r_squared: 0.9536 - val_rmse: 3.4879
# Epoch 77/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.4726 - r_squared: 0.9599 - rmse: 3.4754 - val_loss: 16.1810 - val_r_squared: 0.9472 - val_rmse: 3.7190
# Epoch 78/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.9800 - r_squared: 0.9577 - rmse: 3.5633 - val_loss: 13.4317 - val_r_squared: 0.9577 - val_rmse: 3.3288
# Epoch 79/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.5782 - r_squared: 0.9668 - rmse: 3.1675 - val_loss: 18.6209 - val_r_squared: 0.9379 - val_rmse: 4.0335
# Epoch 80/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.0290 - r_squared: 0.9618 - rmse: 3.3907 - val_loss: 17.9686 - val_r_squared: 0.9404 - val_rmse: 3.9517
# Epoch 81/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 17.1900 - r_squared: 0.9480 - rmse: 3.8288 - val_loss: 20.6056 - val_r_squared: 0.9304 - val_rmse: 4.2723
# Epoch 82/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.7950 - r_squared: 0.9532 - rmse: 3.7873 - val_loss: 11.9781 - val_r_squared: 0.9633 - val_rmse: 3.1023
# Epoch 83/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 17.2420 - r_squared: 0.9471 - rmse: 3.7972 - val_loss: 12.6417 - val_r_squared: 0.9608 - val_rmse: 3.2074
# Epoch 84/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 15.5957 - r_squared: 0.9559 - rmse: 3.6044 - val_loss: 13.8764 - val_r_squared: 0.9560 - val_rmse: 3.3944
# Epoch 85/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 13.4917 - r_squared: 0.9633 - rmse: 3.3376 - val_loss: 20.9068 - val_r_squared: 0.9292 - val_rmse: 4.3073
# Epoch 86/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.0750 - r_squared: 0.9624 - rmse: 3.3233 - val_loss: 14.4731 - val_r_squared: 0.9538 - val_rmse: 3.4812
# Epoch 87/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.8895 - r_squared: 0.9712 - rmse: 2.9314 - val_loss: 13.3867 - val_r_squared: 0.9579 - val_rmse: 3.3216
# Epoch 88/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.6318 - r_squared: 0.9691 - rmse: 3.0655 - val_loss: 13.2803 - val_r_squared: 0.9583 - val_rmse: 3.3054
# Epoch 89/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.8272 - r_squared: 0.9693 - rmse: 3.0324 - val_loss: 12.5661 - val_r_squared: 0.9610 - val_rmse: 3.1956
# Epoch 90/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.7438 - r_squared: 0.9724 - rmse: 2.9036 - val_loss: 13.3666 - val_r_squared: 0.9580 - val_rmse: 3.3184
# Epoch 91/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 12.2379 - r_squared: 0.9668 - rmse: 3.1244 - val_loss: 13.6337 - val_r_squared: 0.9570 - val_rmse: 3.3584
# Epoch 92/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.9864 - r_squared: 0.9683 - rmse: 3.0913 - val_loss: 12.0047 - val_r_squared: 0.9632 - val_rmse: 3.1066
# Epoch 93/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.3338 - r_squared: 0.9707 - rmse: 2.9916 - val_loss: 25.9547 - val_r_squared: 0.9100 - val_rmse: 4.8581
# Epoch 94/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.3257 - r_squared: 0.9540 - rmse: 3.6924 - val_loss: 10.7477 - val_r_squared: 0.9680 - val_rmse: 2.8972
# Epoch 95/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.7291 - r_squared: 0.9667 - rmse: 3.1486 - val_loss: 11.0219 - val_r_squared: 0.9669 - val_rmse: 2.9442
# Epoch 96/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.4681 - r_squared: 0.9661 - rmse: 3.1833 - val_loss: 14.1011 - val_r_squared: 0.9552 - val_rmse: 3.4276
# Epoch 97/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 20.9899 - r_squared: 0.9383 - rmse: 4.2510 - val_loss: 16.7141 - val_r_squared: 0.9452 - val_rmse: 3.7897
# Epoch 98/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.5897 - r_squared: 0.9528 - rmse: 3.7576 - val_loss: 20.3375 - val_r_squared: 0.9314 - val_rmse: 4.2411
# Epoch 99/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.3715 - r_squared: 0.9648 - rmse: 3.2480 - val_loss: 11.1964 - val_r_squared: 0.9663 - val_rmse: 2.9744
# Epoch 100/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.9258 - r_squared: 0.9752 - rmse: 2.7515 - val_loss: 12.6246 - val_r_squared: 0.9608 - val_rmse: 3.2055
# Epoch 101/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.2803 - r_squared: 0.9770 - rmse: 2.6387 - val_loss: 10.9990 - val_r_squared: 0.9670 - val_rmse: 2.9411
# Epoch 102/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.1312 - r_squared: 0.9778 - rmse: 2.6112 - val_loss: 10.4640 - val_r_squared: 0.9690 - val_rmse: 2.8484
# Epoch 103/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.8645 - r_squared: 0.9789 - rmse: 2.5439 - val_loss: 15.4680 - val_r_squared: 0.9500 - val_rmse: 3.6219
# Epoch 104/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.9398 - r_squared: 0.9713 - rmse: 2.9427 - val_loss: 12.5271 - val_r_squared: 0.9612 - val_rmse: 3.1903
# Epoch 105/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.9149 - r_squared: 0.9712 - rmse: 2.9370 - val_loss: 13.5823 - val_r_squared: 0.9571 - val_rmse: 3.3517
# Epoch 106/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.8534 - r_squared: 0.9756 - rmse: 2.7168 - val_loss: 11.8460 - val_r_squared: 0.9638 - val_rmse: 3.0819
# Epoch 107/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.2237 - r_squared: 0.9735 - rmse: 2.7981 - val_loss: 13.5432 - val_r_squared: 0.9573 - val_rmse: 3.3460
# Epoch 108/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 19.6185 - r_squared: 0.9407 - rmse: 4.0543 - val_loss: 13.3081 - val_r_squared: 0.9582 - val_rmse: 3.3107
# Epoch 109/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.8412 - r_squared: 0.9541 - rmse: 3.7066 - val_loss: 23.2430 - val_r_squared: 0.9203 - val_rmse: 4.5712
# Epoch 110/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.0808 - r_squared: 0.9643 - rmse: 3.2707 - val_loss: 13.4607 - val_r_squared: 0.9576 - val_rmse: 3.3341
# Epoch 111/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.7721 - r_squared: 0.9757 - rmse: 2.7210 - val_loss: 12.5447 - val_r_squared: 0.9611 - val_rmse: 3.1938
# Epoch 112/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.7756 - r_squared: 0.9761 - rmse: 2.7013 - val_loss: 10.8241 - val_r_squared: 0.9677 - val_rmse: 2.9121
# Epoch 113/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.4534 - r_squared: 0.9800 - rmse: 2.4644 - val_loss: 15.1477 - val_r_squared: 0.9512 - val_rmse: 3.5783
# Epoch 114/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.0510 - r_squared: 0.9747 - rmse: 2.7791 - val_loss: 10.3309 - val_r_squared: 0.9695 - val_rmse: 2.8263
# Epoch 115/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9917 - r_squared: 0.9819 - rmse: 2.3427 - val_loss: 11.8788 - val_r_squared: 0.9636 - val_rmse: 3.0881
# Epoch 116/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.1765 - r_squared: 0.9773 - rmse: 2.6117 - val_loss: 12.5895 - val_r_squared: 0.9609 - val_rmse: 3.2012
# Epoch 117/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.6905 - r_squared: 0.9764 - rmse: 2.6769 - val_loss: 14.4010 - val_r_squared: 0.9540 - val_rmse: 3.4727
# Epoch 118/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9546 - r_squared: 0.9787 - rmse: 2.5600 - val_loss: 10.7121 - val_r_squared: 0.9681 - val_rmse: 2.8934
# Epoch 119/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.3734 - r_squared: 0.9804 - rmse: 2.4436 - val_loss: 10.5168 - val_r_squared: 0.9688 - val_rmse: 2.8595
# Epoch 120/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5562 - r_squared: 0.9794 - rmse: 2.5026 - val_loss: 11.5789 - val_r_squared: 0.9648 - val_rmse: 3.0396
# Epoch 121/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.6921 - r_squared: 0.9783 - rmse: 2.4955 - val_loss: 10.2147 - val_r_squared: 0.9700 - val_rmse: 2.8063
# Epoch 122/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.4564 - r_squared: 0.9800 - rmse: 2.4737 - val_loss: 14.5844 - val_r_squared: 0.9533 - val_rmse: 3.4993
# Epoch 123/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.7650 - r_squared: 0.9799 - rmse: 2.4218 - val_loss: 10.3459 - val_r_squared: 0.9695 - val_rmse: 2.8298
# Epoch 124/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9670 - r_squared: 0.9815 - rmse: 2.3516 - val_loss: 10.8889 - val_r_squared: 0.9674 - val_rmse: 2.9242
# Epoch 125/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.5740 - r_squared: 0.9711 - rmse: 2.9211 - val_loss: 18.1320 - val_r_squared: 0.9397 - val_rmse: 3.9743
# Epoch 126/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9660 - r_squared: 0.9783 - rmse: 2.5168 - val_loss: 11.2944 - val_r_squared: 0.9658 - val_rmse: 2.9931
# Epoch 127/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.8027 - r_squared: 0.9755 - rmse: 2.6995 - val_loss: 10.6475 - val_r_squared: 0.9683 - val_rmse: 2.8832
# Epoch 128/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.6127 - r_squared: 0.9770 - rmse: 2.6236 - val_loss: 16.1707 - val_r_squared: 0.9472 - val_rmse: 3.7198
# Epoch 129/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.0065 - r_squared: 0.9675 - rmse: 3.1060 - val_loss: 16.2893 - val_r_squared: 0.9468 - val_rmse: 3.7357
# Epoch 130/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.7328 - r_squared: 0.9631 - rmse: 3.3113 - val_loss: 24.7558 - val_r_squared: 0.9145 - val_rmse: 4.7353
# Epoch 131/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 21.1169 - r_squared: 0.9364 - rmse: 4.2819 - val_loss: 11.2904 - val_r_squared: 0.9658 - val_rmse: 2.9932
# Epoch 132/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 21.1592 - r_squared: 0.9383 - rmse: 4.1843 - val_loss: 45.1706 - val_r_squared: 0.8366 - val_rmse: 6.5453
# Epoch 133/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 41.0476 - r_squared: 0.8754 - rmse: 6.0832 - val_loss: 71.5619 - val_r_squared: 0.7359 - val_rmse: 8.3208
# Epoch 134/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 56.7570 - r_squared: 0.8196 - rmse: 7.1984 - val_loss: 20.9046 - val_r_squared: 0.9291 - val_rmse: 4.3106
# Epoch 135/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 35.6023 - r_squared: 0.8902 - rmse: 5.3982 - val_loss: 61.3936 - val_r_squared: 0.7746 - val_rmse: 7.6859
# Epoch 136/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 25.2566 - r_squared: 0.9235 - rmse: 4.6012 - val_loss: 15.2489 - val_r_squared: 0.9507 - val_rmse: 3.5959
# Epoch 137/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.0133 - r_squared: 0.9619 - rmse: 3.3102 - val_loss: 12.8023 - val_r_squared: 0.9600 - val_rmse: 3.2381
# Epoch 138/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.7820 - r_squared: 0.9662 - rmse: 3.1718 - val_loss: 16.2646 - val_r_squared: 0.9468 - val_rmse: 3.7347
# Epoch 139/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.5634 - r_squared: 0.9696 - rmse: 3.0256 - val_loss: 11.5567 - val_r_squared: 0.9648 - val_rmse: 3.0397
# Epoch 140/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.6029 - r_squared: 0.9764 - rmse: 2.6839 - val_loss: 10.9400 - val_r_squared: 0.9671 - val_rmse: 2.9363
# Epoch 141/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.0003 - r_squared: 0.9780 - rmse: 2.5889 - val_loss: 10.8683 - val_r_squared: 0.9674 - val_rmse: 2.9241
# Epoch 142/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.9742 - r_squared: 0.9752 - rmse: 2.7534 - val_loss: 12.2268 - val_r_squared: 0.9622 - val_rmse: 3.1479
# Epoch 143/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.1993 - r_squared: 0.9773 - rmse: 2.6289 - val_loss: 13.6474 - val_r_squared: 0.9568 - val_rmse: 3.3661
# Epoch 144/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.9824 - r_squared: 0.9712 - rmse: 2.9390 - val_loss: 11.7658 - val_r_squared: 0.9639 - val_rmse: 3.0741
# Epoch 145/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.8037 - r_squared: 0.9683 - rmse: 3.0737 - val_loss: 10.8695 - val_r_squared: 0.9674 - val_rmse: 2.9247
# Epoch 146/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.3976 - r_squared: 0.9768 - rmse: 2.6577 - val_loss: 11.8616 - val_r_squared: 0.9636 - val_rmse: 3.0897
# Epoch 147/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.7945 - r_squared: 0.9731 - rmse: 2.8203 - val_loss: 22.6580 - val_r_squared: 0.9224 - val_rmse: 4.5103
# Epoch 148/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.9906 - r_squared: 0.9754 - rmse: 2.7066 - val_loss: 11.0520 - val_r_squared: 0.9667 - val_rmse: 2.9560
# Epoch 149/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9242 - r_squared: 0.9778 - rmse: 2.5680 - val_loss: 11.1003 - val_r_squared: 0.9665 - val_rmse: 2.9642
# Epoch 150/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5097 - r_squared: 0.9792 - rmse: 2.4983 - val_loss: 9.6507 - val_r_squared: 0.9720 - val_rmse: 2.7088
# Epoch 151/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.6660 - r_squared: 0.9754 - rmse: 2.7137 - val_loss: 12.6507 - val_r_squared: 0.9606 - val_rmse: 3.2152
# Epoch 152/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.5219 - r_squared: 0.9765 - rmse: 2.6331 - val_loss: 11.3489 - val_r_squared: 0.9655 - val_rmse: 3.0062
# Epoch 153/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.1564 - r_squared: 0.9736 - rmse: 2.8086 - val_loss: 14.2655 - val_r_squared: 0.9544 - val_rmse: 3.4575
# Epoch 154/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.4858 - r_squared: 0.9668 - rmse: 3.1678 - val_loss: 15.1187 - val_r_squared: 0.9511 - val_rmse: 3.5788
# Epoch 155/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.2821 - r_squared: 0.9546 - rmse: 3.5262 - val_loss: 27.4229 - val_r_squared: 0.9042 - val_rmse: 5.0113
# Epoch 156/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.3202 - r_squared: 0.9647 - rmse: 3.2604 - val_loss: 11.3952 - val_r_squared: 0.9653 - val_rmse: 3.0145
# Epoch 157/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.2748 - r_squared: 0.9735 - rmse: 2.8010 - val_loss: 30.4397 - val_r_squared: 0.8927 - val_rmse: 5.3040
# Epoch 158/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.4917 - r_squared: 0.9596 - rmse: 3.3019 - val_loss: 14.6334 - val_r_squared: 0.9530 - val_rmse: 3.5110
# Epoch 159/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.8561 - r_squared: 0.9723 - rmse: 2.8787 - val_loss: 11.8586 - val_r_squared: 0.9636 - val_rmse: 3.0909
# Epoch 160/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.6665 - r_squared: 0.9761 - rmse: 2.6748 - val_loss: 9.9342 - val_r_squared: 0.9709 - val_rmse: 2.7622
# Epoch 161/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.8242 - r_squared: 0.9823 - rmse: 2.3225 - val_loss: 12.5237 - val_r_squared: 0.9610 - val_rmse: 3.1969
# Epoch 162/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.3763 - r_squared: 0.9769 - rmse: 2.6280 - val_loss: 10.3790 - val_r_squared: 0.9692 - val_rmse: 2.8419
# Epoch 163/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.0700 - r_squared: 0.9698 - rmse: 2.9116 - val_loss: 9.8002 - val_r_squared: 0.9714 - val_rmse: 2.7382
# Epoch 164/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.6540 - r_squared: 0.9789 - rmse: 2.5035 - val_loss: 9.4404 - val_r_squared: 0.9728 - val_rmse: 2.6719
# Epoch 165/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9506 - r_squared: 0.9816 - rmse: 2.3758 - val_loss: 11.9242 - val_r_squared: 0.9633 - val_rmse: 3.1021
# Epoch 166/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.0499 - r_squared: 0.9750 - rmse: 2.7471 - val_loss: 17.2035 - val_r_squared: 0.9431 - val_rmse: 3.8605
# Epoch 167/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.8024 - r_squared: 0.9723 - rmse: 2.9111 - val_loss: 11.1440 - val_r_squared: 0.9663 - val_rmse: 2.9741
# Epoch 168/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.1853 - r_squared: 0.9807 - rmse: 2.4321 - val_loss: 16.0540 - val_r_squared: 0.9475 - val_rmse: 3.7089
# Epoch 169/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.5296 - r_squared: 0.9699 - rmse: 2.9785 - val_loss: 18.5685 - val_r_squared: 0.9379 - val_rmse: 4.0339
# Epoch 170/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.0713 - r_squared: 0.9546 - rmse: 3.6736 - val_loss: 21.6241 - val_r_squared: 0.9263 - val_rmse: 4.3964
# Epoch 171/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.0880 - r_squared: 0.9721 - rmse: 2.8756 - val_loss: 10.8007 - val_r_squared: 0.9675 - val_rmse: 2.9168
# Epoch 172/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5542 - r_squared: 0.9799 - rmse: 2.4851 - val_loss: 13.5542 - val_r_squared: 0.9570 - val_rmse: 3.3559
# Epoch 173/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5784 - r_squared: 0.9797 - rmse: 2.4755 - val_loss: 11.9881 - val_r_squared: 0.9630 - val_rmse: 3.1139
# Epoch 174/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.8651 - r_squared: 0.9786 - rmse: 2.5429 - val_loss: 12.8764 - val_r_squared: 0.9596 - val_rmse: 3.2533
# Epoch 175/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.8012 - r_squared: 0.9822 - rmse: 2.3103 - val_loss: 9.5662 - val_r_squared: 0.9722 - val_rmse: 2.6971
# Epoch 176/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.4029 - r_squared: 0.9833 - rmse: 2.2606 - val_loss: 9.1502 - val_r_squared: 0.9738 - val_rmse: 2.6190
# Epoch 177/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7540 - r_squared: 0.9823 - rmse: 2.3341 - val_loss: 11.8728 - val_r_squared: 0.9634 - val_rmse: 3.0957
# Epoch 178/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.4033 - r_squared: 0.9833 - rmse: 2.2632 - val_loss: 9.2672 - val_r_squared: 0.9734 - val_rmse: 2.6416
# Epoch 179/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.7839 - r_squared: 0.9791 - rmse: 2.4957 - val_loss: 9.8558 - val_r_squared: 0.9711 - val_rmse: 2.7508
# Epoch 180/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 7.4800 - r_squared: 0.9833 - rmse: 2.2418 - val_loss: 9.2568 - val_r_squared: 0.9734 - val_rmse: 2.6399
# Epoch 181/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 7.0682 - r_squared: 0.9844 - rmse: 2.1798 - val_loss: 17.5482 - val_r_squared: 0.9418 - val_rmse: 3.9066
# Epoch 182/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.2065 - r_squared: 0.9642 - rmse: 3.2355 - val_loss: 18.5362 - val_r_squared: 0.9380 - val_rmse: 4.0312
# Epoch 183/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 18.2714 - r_squared: 0.9500 - rmse: 3.8416 - val_loss: 9.3211 - val_r_squared: 0.9732 - val_rmse: 2.6527
# Epoch 184/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.5362 - r_squared: 0.9719 - rmse: 2.8644 - val_loss: 12.4676 - val_r_squared: 0.9611 - val_rmse: 3.1914
# Epoch 185/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.6917 - r_squared: 0.9686 - rmse: 3.0501 - val_loss: 10.5588 - val_r_squared: 0.9684 - val_rmse: 2.8772
# Epoch 186/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.8052 - r_squared: 0.9718 - rmse: 2.8843 - val_loss: 11.1693 - val_r_squared: 0.9661 - val_rmse: 2.9813
# Epoch 187/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.5097 - r_squared: 0.9769 - rmse: 2.6218 - val_loss: 12.2722 - val_r_squared: 0.9619 - val_rmse: 3.1610
# Epoch 188/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.1205 - r_squared: 0.9634 - rmse: 3.2875 - val_loss: 8.9289 - val_r_squared: 0.9746 - val_rmse: 2.5787
# Epoch 189/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.7819 - r_squared: 0.9691 - rmse: 2.9877 - val_loss: 13.0378 - val_r_squared: 0.9590 - val_rmse: 3.2803
# Epoch 190/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.7848 - r_squared: 0.9787 - rmse: 2.5472 - val_loss: 9.3234 - val_r_squared: 0.9731 - val_rmse: 2.6546
# Epoch 191/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.6414 - r_squared: 0.9827 - rmse: 2.3015 - val_loss: 13.2220 - val_r_squared: 0.9582 - val_rmse: 3.3084
# Epoch 192/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.2080 - r_squared: 0.9742 - rmse: 2.7801 - val_loss: 11.5239 - val_r_squared: 0.9647 - val_rmse: 3.0411
# Epoch 193/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.1793 - r_squared: 0.9811 - rmse: 2.3874 - val_loss: 8.6073 - val_r_squared: 0.9758 - val_rmse: 2.5162
# Epoch 194/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3248 - r_squared: 0.9835 - rmse: 2.2357 - val_loss: 10.1143 - val_r_squared: 0.9701 - val_rmse: 2.7999
# Epoch 195/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.4670 - r_squared: 0.9799 - rmse: 2.4590 - val_loss: 10.0191 - val_r_squared: 0.9705 - val_rmse: 2.7830
# Epoch 196/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 7.3583 - r_squared: 0.9835 - rmse: 2.2362 - val_loss: 9.8232 - val_r_squared: 0.9712 - val_rmse: 2.7478
# Epoch 197/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0438 - r_squared: 0.9844 - rmse: 2.1737 - val_loss: 9.0400 - val_r_squared: 0.9742 - val_rmse: 2.6013
# Epoch 198/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.6949 - r_squared: 0.9823 - rmse: 2.3306 - val_loss: 12.1655 - val_r_squared: 0.9623 - val_rmse: 3.1454
# Epoch 199/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.4641 - r_squared: 0.9769 - rmse: 2.5958 - val_loss: 10.7322 - val_r_squared: 0.9677 - val_rmse: 2.9087
# Epoch 200/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9098 - r_squared: 0.9778 - rmse: 2.5590 - val_loss: 9.0797 - val_r_squared: 0.9740 - val_rmse: 2.6094
# Epoch 201/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9665 - r_squared: 0.9816 - rmse: 2.3806 - val_loss: 13.8961 - val_r_squared: 0.9556 - val_rmse: 3.4097
# Epoch 202/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9558 - r_squared: 0.9780 - rmse: 2.5991 - val_loss: 9.4319 - val_r_squared: 0.9727 - val_rmse: 2.6764
# Epoch 203/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7849 - r_squared: 0.9824 - rmse: 2.2915 - val_loss: 10.0913 - val_r_squared: 0.9702 - val_rmse: 2.7969
# Epoch 204/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9046 - r_squared: 0.9810 - rmse: 2.3867 - val_loss: 13.4255 - val_r_squared: 0.9574 - val_rmse: 3.3403
# Epoch 205/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.0306 - r_squared: 0.9811 - rmse: 2.3801 - val_loss: 10.7692 - val_r_squared: 0.9676 - val_rmse: 2.9158
# Epoch 206/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5389 - r_squared: 0.9788 - rmse: 2.5213 - val_loss: 12.8200 - val_r_squared: 0.9597 - val_rmse: 3.2487
# Epoch 207/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.0372 - r_squared: 0.9782 - rmse: 2.5075 - val_loss: 10.1894 - val_r_squared: 0.9698 - val_rmse: 2.8151
# Epoch 208/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7849 - r_squared: 0.9819 - rmse: 2.3464 - val_loss: 11.9253 - val_r_squared: 0.9631 - val_rmse: 3.1084
# Epoch 209/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.3111 - r_squared: 0.9802 - rmse: 2.4402 - val_loss: 11.9602 - val_r_squared: 0.9630 - val_rmse: 3.1141
# Epoch 210/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.2446 - r_squared: 0.9698 - rmse: 2.9909 - val_loss: 13.3456 - val_r_squared: 0.9577 - val_rmse: 3.3293
# Epoch 211/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.1842 - r_squared: 0.9709 - rmse: 2.9444 - val_loss: 14.4056 - val_r_squared: 0.9537 - val_rmse: 3.4849
# Epoch 212/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.2259 - r_squared: 0.9804 - rmse: 2.4339 - val_loss: 9.6915 - val_r_squared: 0.9716 - val_rmse: 2.7261
# Epoch 213/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7128 - r_squared: 0.9820 - rmse: 2.3325 - val_loss: 11.0023 - val_r_squared: 0.9666 - val_rmse: 2.9568
# Epoch 214/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.2699 - r_squared: 0.9837 - rmse: 2.2102 - val_loss: 8.3301 - val_r_squared: 0.9768 - val_rmse: 2.4639
# Epoch 215/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.5005 - r_squared: 0.9824 - rmse: 2.2899 - val_loss: 10.1436 - val_r_squared: 0.9699 - val_rmse: 2.8081
# Epoch 216/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9810 - r_squared: 0.9775 - rmse: 2.5643 - val_loss: 8.6235 - val_r_squared: 0.9757 - val_rmse: 2.5231
# Epoch 217/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0466 - r_squared: 0.9847 - rmse: 2.1555 - val_loss: 9.6983 - val_r_squared: 0.9716 - val_rmse: 2.7280
# Epoch 218/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.5915 - r_squared: 0.9827 - rmse: 2.2927 - val_loss: 10.1404 - val_r_squared: 0.9699 - val_rmse: 2.8081
# Epoch 219/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.8400 - r_squared: 0.9756 - rmse: 2.6615 - val_loss: 9.3418 - val_r_squared: 0.9730 - val_rmse: 2.6622
# Epoch 220/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.1102 - r_squared: 0.9808 - rmse: 2.3972 - val_loss: 8.9651 - val_r_squared: 0.9744 - val_rmse: 2.5907
# Epoch 221/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.1772 - r_squared: 0.9839 - rmse: 2.2059 - val_loss: 9.9857 - val_r_squared: 0.9705 - val_rmse: 2.7807
# Epoch 222/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7689 - r_squared: 0.9821 - rmse: 2.3278 - val_loss: 9.0847 - val_r_squared: 0.9739 - val_rmse: 2.6138
# Epoch 223/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 7.0040 - r_squared: 0.9842 - rmse: 2.1825 - val_loss: 8.4757 - val_r_squared: 0.9763 - val_rmse: 2.4948
# Epoch 224/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.2927 - r_squared: 0.9747 - rmse: 2.6632 - val_loss: 24.5245 - val_r_squared: 0.9150 - val_rmse: 4.7195
# Epoch 225/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 15.5319 - r_squared: 0.9552 - rmse: 3.6194 - val_loss: 15.8163 - val_r_squared: 0.9482 - val_rmse: 3.6833
# Epoch 226/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 20.2502 - r_squared: 0.9420 - rmse: 4.0433 - val_loss: 8.6523 - val_r_squared: 0.9756 - val_rmse: 2.5309
# Epoch 227/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.7474 - r_squared: 0.9676 - rmse: 3.0679 - val_loss: 18.4858 - val_r_squared: 0.9380 - val_rmse: 4.0300
# Epoch 228/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.2940 - r_squared: 0.9703 - rmse: 2.9885 - val_loss: 10.1932 - val_r_squared: 0.9697 - val_rmse: 2.8196
# Epoch 229/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 15.4696 - r_squared: 0.9559 - rmse: 3.5649 - val_loss: 14.3317 - val_r_squared: 0.9539 - val_rmse: 3.4769
# Epoch 230/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.7206 - r_squared: 0.9670 - rmse: 3.1519 - val_loss: 12.5386 - val_r_squared: 0.9607 - val_rmse: 3.2087
# Epoch 231/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.8736 - r_squared: 0.9781 - rmse: 2.5183 - val_loss: 10.9739 - val_r_squared: 0.9667 - val_rmse: 2.9549
# Epoch 232/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.4656 - r_squared: 0.9606 - rmse: 3.3496 - val_loss: 12.0629 - val_r_squared: 0.9625 - val_rmse: 3.1340
# Epoch 233/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.2718 - r_squared: 0.9650 - rmse: 3.2320 - val_loss: 14.3275 - val_r_squared: 0.9539 - val_rmse: 3.4766
# Epoch 234/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.7026 - r_squared: 0.9778 - rmse: 2.5327 - val_loss: 13.2607 - val_r_squared: 0.9580 - val_rmse: 3.3199
# Epoch 235/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.6031 - r_squared: 0.9787 - rmse: 2.5339 - val_loss: 15.2378 - val_r_squared: 0.9504 - val_rmse: 3.6053
# Epoch 236/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.6339 - r_squared: 0.9797 - rmse: 2.4377 - val_loss: 9.2404 - val_r_squared: 0.9733 - val_rmse: 2.6459
# Epoch 237/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.1031 - r_squared: 0.9812 - rmse: 2.3758 - val_loss: 10.9805 - val_r_squared: 0.9667 - val_rmse: 2.9565
# Epoch 238/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5751 - r_squared: 0.9792 - rmse: 2.4926 - val_loss: 8.8527 - val_r_squared: 0.9748 - val_rmse: 2.5718
# Epoch 239/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0421 - r_squared: 0.9840 - rmse: 2.1781 - val_loss: 10.7233 - val_r_squared: 0.9676 - val_rmse: 2.9131
# Epoch 240/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.7324 - r_squared: 0.9820 - rmse: 2.3173 - val_loss: 10.7429 - val_r_squared: 0.9676 - val_rmse: 2.9165
# Epoch 241/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.1627 - r_squared: 0.9839 - rmse: 2.1919 - val_loss: 10.8682 - val_r_squared: 0.9671 - val_rmse: 2.9380
# Epoch 242/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5543 - r_squared: 0.9791 - rmse: 2.5139 - val_loss: 8.7698 - val_r_squared: 0.9751 - val_rmse: 2.5560
# Epoch 243/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.1088 - r_squared: 0.9801 - rmse: 2.4348 - val_loss: 13.9307 - val_r_squared: 0.9554 - val_rmse: 3.4198
# Epoch 244/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 16.0966 - r_squared: 0.9549 - rmse: 3.4854 - val_loss: 24.5475 - val_r_squared: 0.9149 - val_rmse: 4.7237
# Epoch 245/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 19.3540 - r_squared: 0.9436 - rmse: 4.0259 - val_loss: 25.2684 - val_r_squared: 0.9121 - val_rmse: 4.7995
# Epoch 246/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 17.4271 - r_squared: 0.9493 - rmse: 3.9100 - val_loss: 10.2644 - val_r_squared: 0.9694 - val_rmse: 2.8345
# Epoch 247/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.9031 - r_squared: 0.9604 - rmse: 3.3352 - val_loss: 11.1029 - val_r_squared: 0.9661 - val_rmse: 2.9791
# Epoch 248/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.4688 - r_squared: 0.9732 - rmse: 2.8454 - val_loss: 15.7810 - val_r_squared: 0.9483 - val_rmse: 3.6815
# Epoch 249/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.4516 - r_squared: 0.9799 - rmse: 2.4529 - val_loss: 8.2573 - val_r_squared: 0.9770 - val_rmse: 2.4558
# Epoch 250/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.5549 - r_squared: 0.9793 - rmse: 2.5024 - val_loss: 26.5174 - val_r_squared: 0.9073 - val_rmse: 4.9286
# Epoch 251/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 18.3468 - r_squared: 0.9468 - rmse: 3.8290 - val_loss: 19.5515 - val_r_squared: 0.9339 - val_rmse: 4.1625
# Epoch 252/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.0750 - r_squared: 0.9632 - rmse: 3.2532 - val_loss: 12.7355 - val_r_squared: 0.9599 - val_rmse: 3.2423
# Epoch 253/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.7897 - r_squared: 0.9746 - rmse: 2.7493 - val_loss: 8.9526 - val_r_squared: 0.9743 - val_rmse: 2.5946
# Epoch 254/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.6841 - r_squared: 0.9720 - rmse: 2.9043 - val_loss: 20.2693 - val_r_squared: 0.9311 - val_rmse: 4.2484
# Epoch 255/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.1578 - r_squared: 0.9714 - rmse: 2.8852 - val_loss: 12.0453 - val_r_squared: 0.9625 - val_rmse: 3.1345
# Epoch 256/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.6808 - r_squared: 0.9684 - rmse: 3.0461 - val_loss: 28.3447 - val_r_squared: 0.9003 - val_rmse: 5.1112
# Epoch 257/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 13.8646 - r_squared: 0.9634 - rmse: 3.1404 - val_loss: 14.9847 - val_r_squared: 0.9513 - val_rmse: 3.5728
# Epoch 258/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.9335 - r_squared: 0.9725 - rmse: 2.8409 - val_loss: 18.8505 - val_r_squared: 0.9366 - val_rmse: 4.0782
# Epoch 259/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.3534 - r_squared: 0.9730 - rmse: 2.8201 - val_loss: 11.5208 - val_r_squared: 0.9645 - val_rmse: 3.0500
# Epoch 260/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.3845 - r_squared: 0.9737 - rmse: 2.7954 - val_loss: 9.1561 - val_r_squared: 0.9735 - val_rmse: 2.6341
# Epoch 261/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3764 - r_squared: 0.9830 - rmse: 2.2340 - val_loss: 9.1343 - val_r_squared: 0.9736 - val_rmse: 2.6301
# Epoch 262/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.7528 - r_squared: 0.9852 - rmse: 2.1069 - val_loss: 8.2818 - val_r_squared: 0.9769 - val_rmse: 2.4627
# Epoch 263/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5392 - r_squared: 0.9857 - rmse: 2.0828 - val_loss: 8.2857 - val_r_squared: 0.9768 - val_rmse: 2.4636
# Epoch 264/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8104 - r_squared: 0.9844 - rmse: 2.1513 - val_loss: 7.9754 - val_r_squared: 0.9780 - val_rmse: 2.3998
# Epoch 265/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5196 - r_squared: 0.9861 - rmse: 2.0253 - val_loss: 8.1047 - val_r_squared: 0.9775 - val_rmse: 2.4266
# Epoch 266/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0054 - r_squared: 0.9841 - rmse: 2.1638 - val_loss: 10.8044 - val_r_squared: 0.9672 - val_rmse: 2.9306
# Epoch 267/1000
# ...
# Epoch 913/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.3012 - r_squared: 0.9890 - rmse: 1.8343 - val_loss: 6.4974 - val_r_squared: 0.9827 - val_rmse: 2.1324
# Epoch 914/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.0060 - r_squared: 0.9866 - rmse: 1.9807 - val_loss: 8.2210 - val_r_squared: 0.9761 - val_rmse: 2.5041
# Epoch 915/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.2052 - r_squared: 0.9860 - rmse: 2.0373 - val_loss: 7.2486 - val_r_squared: 0.9798 - val_rmse: 2.3019
# Epoch 916/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.5461 - r_squared: 0.9878 - rmse: 1.8887 - val_loss: 6.7727 - val_r_squared: 0.9816 - val_rmse: 2.1961
# Epoch 917/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.4460 - r_squared: 0.9883 - rmse: 1.8836 - val_loss: 7.8072 - val_r_squared: 0.9777 - val_rmse: 2.4203
# Epoch 918/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.4310 - r_squared: 0.9884 - rmse: 1.8782 - val_loss: 6.6960 - val_r_squared: 0.9819 - val_rmse: 2.1787
# Epoch 919/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.9303 - r_squared: 0.9904 - rmse: 1.7160 - val_loss: 6.6474 - val_r_squared: 0.9821 - val_rmse: 2.1676
# Epoch 920/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.9978 - r_squared: 0.9899 - rmse: 1.7378 - val_loss: 10.1111 - val_r_squared: 0.9689 - val_rmse: 2.8570
# Epoch 921/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.3302 - r_squared: 0.9890 - rmse: 1.8202 - val_loss: 7.1538 - val_r_squared: 0.9801 - val_rmse: 2.2815
# Epoch 922/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.3769 - r_squared: 0.9885 - rmse: 1.8452 - val_loss: 7.3292 - val_r_squared: 0.9795 - val_rmse: 2.3196
# Epoch 923/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.9463 - r_squared: 0.9869 - rmse: 1.9723 - val_loss: 7.1518 - val_r_squared: 0.9801 - val_rmse: 2.2811
# Epoch 924/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.7300 - r_squared: 0.9878 - rmse: 1.9251 - val_loss: 8.0134 - val_r_squared: 0.9769 - val_rmse: 2.4628
# Epoch 925/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.1632 - r_squared: 0.9897 - rmse: 1.7665 - val_loss: 7.8641 - val_r_squared: 0.9774 - val_rmse: 2.4323
# Epoch 926/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3387 - r_squared: 0.9820 - rmse: 2.2975 - val_loss: 6.4448 - val_r_squared: 0.9828 - val_rmse: 2.1208
# Epoch 927/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.2964 - r_squared: 0.9848 - rmse: 2.0908 - val_loss: 7.9894 - val_r_squared: 0.9769 - val_rmse: 2.4582
# Epoch 928/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.8472 - r_squared: 0.9807 - rmse: 2.3436 - val_loss: 7.1547 - val_r_squared: 0.9801 - val_rmse: 2.2822
# Epoch 929/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.5934 - r_squared: 0.9883 - rmse: 1.8752 - val_loss: 7.1895 - val_r_squared: 0.9800 - val_rmse: 2.2898
# Epoch 930/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.7915 - r_squared: 0.9908 - rmse: 1.6764 - val_loss: 6.4087 - val_r_squared: 0.9830 - val_rmse: 2.1126
# Epoch 931/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.0435 - r_squared: 0.9901 - rmse: 1.7304 - val_loss: 6.2617 - val_r_squared: 0.9835 - val_rmse: 2.0775
# Epoch 932/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.8898 - r_squared: 0.9901 - rmse: 1.7202 - val_loss: 6.3365 - val_r_squared: 0.9833 - val_rmse: 2.0954
# Epoch 933/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.0335 - r_squared: 0.9900 - rmse: 1.7251 - val_loss: 6.7241 - val_r_squared: 0.9818 - val_rmse: 2.1860
# Epoch 934/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.7838 - r_squared: 0.9907 - rmse: 1.6903 - val_loss: 8.5576 - val_r_squared: 0.9748 - val_rmse: 2.5715
# Epoch 935/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.1436 - r_squared: 0.9891 - rmse: 1.8029 - val_loss: 6.4235 - val_r_squared: 0.9829 - val_rmse: 2.1162
# Epoch 936/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.1777 - r_squared: 0.9857 - rmse: 2.0646 - val_loss: 9.6569 - val_r_squared: 0.9706 - val_rmse: 2.7771
# Epoch 937/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8115 - r_squared: 0.9848 - rmse: 2.1407 - val_loss: 7.4145 - val_r_squared: 0.9791 - val_rmse: 2.3390
# Epoch 938/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 5.1984 - r_squared: 0.9895 - rmse: 1.7744 - val_loss: 7.1584 - val_r_squared: 0.9801 - val_rmse: 2.2836
# Epoch 939/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.6123 - r_squared: 0.9836 - rmse: 2.1751 - val_loss: 6.1249 - val_r_squared: 0.9840 - val_rmse: 2.0450
# Epoch 940/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.8600 - r_squared: 0.9873 - rmse: 1.9634 - val_loss: 6.4330 - val_r_squared: 0.9829 - val_rmse: 2.1190
# Epoch 941/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.5251 - r_squared: 0.9877 - rmse: 1.8950 - val_loss: 7.5621 - val_r_squared: 0.9786 - val_rmse: 2.3706
# Epoch 942/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3648 - r_squared: 0.9801 - rmse: 2.2962 - val_loss: 9.3712 - val_r_squared: 0.9717 - val_rmse: 2.7258
# Epoch 943/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 12.2335 - r_squared: 0.9652 - rmse: 3.2087 - val_loss: 36.9970 - val_r_squared: 0.8663 - val_rmse: 5.9208
# Epoch 944/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 18.8854 - r_squared: 0.9460 - rmse: 3.9221 - val_loss: 18.9738 - val_r_squared: 0.9350 - val_rmse: 4.1274
# Epoch 945/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.9837 - r_squared: 0.9559 - rmse: 3.5392 - val_loss: 31.7206 - val_r_squared: 0.8864 - val_rmse: 5.4573
# Epoch 946/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.9367 - r_squared: 0.9708 - rmse: 2.8400 - val_loss: 11.0760 - val_r_squared: 0.9651 - val_rmse: 3.0232
# Epoch 947/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 11.7355 - r_squared: 0.9675 - rmse: 3.0977 - val_loss: 17.4460 - val_r_squared: 0.9408 - val_rmse: 3.9382
# Epoch 948/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.6542 - r_squared: 0.9726 - rmse: 2.8574 - val_loss: 9.1727 - val_r_squared: 0.9724 - val_rmse: 2.6903
# Epoch 949/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.8951 - r_squared: 0.9805 - rmse: 2.4116 - val_loss: 12.9076 - val_r_squared: 0.9581 - val_rmse: 3.3124
# Epoch 950/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.0542 - r_squared: 0.9805 - rmse: 2.4281 - val_loss: 8.9716 - val_r_squared: 0.9732 - val_rmse: 2.6526
# Epoch 951/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.8660 - r_squared: 0.9767 - rmse: 2.6165 - val_loss: 21.3311 - val_r_squared: 0.9260 - val_rmse: 4.4040
# Epoch 952/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.2314 - r_squared: 0.9693 - rmse: 2.9422 - val_loss: 9.6644 - val_r_squared: 0.9705 - val_rmse: 2.7803
# Epoch 953/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 14.0665 - r_squared: 0.9598 - rmse: 3.3937 - val_loss: 26.5245 - val_r_squared: 0.9062 - val_rmse: 4.9589
# Epoch 954/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 17.6018 - r_squared: 0.9477 - rmse: 3.9587 - val_loss: 11.5465 - val_r_squared: 0.9633 - val_rmse: 3.1006
# Epoch 955/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 17.6155 - r_squared: 0.9487 - rmse: 3.7179 - val_loss: 9.9208 - val_r_squared: 0.9695 - val_rmse: 2.8266
# Epoch 956/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 10.3143 - r_squared: 0.9721 - rmse: 2.8661 - val_loss: 11.8272 - val_r_squared: 0.9622 - val_rmse: 3.1458
# Epoch 957/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.9249 - r_squared: 0.9806 - rmse: 2.4109 - val_loss: 8.1190 - val_r_squared: 0.9764 - val_rmse: 2.4876
# Epoch 958/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.2168 - r_squared: 0.9861 - rmse: 2.0478 - val_loss: 7.8844 - val_r_squared: 0.9773 - val_rmse: 2.4398
# Epoch 959/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.9051 - r_squared: 0.9868 - rmse: 1.9894 - val_loss: 6.3742 - val_r_squared: 0.9831 - val_rmse: 2.1075
# Epoch 960/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.2208 - r_squared: 0.9858 - rmse: 2.0682 - val_loss: 7.8359 - val_r_squared: 0.9775 - val_rmse: 2.4297
# Epoch 961/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.7039 - r_squared: 0.9846 - rmse: 2.1410 - val_loss: 8.6624 - val_r_squared: 0.9743 - val_rmse: 2.5942
# Epoch 962/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.3642 - r_squared: 0.9852 - rmse: 2.1026 - val_loss: 10.6131 - val_r_squared: 0.9669 - val_rmse: 2.9464
# Epoch 963/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.0470 - r_squared: 0.9866 - rmse: 2.0100 - val_loss: 7.4688 - val_r_squared: 0.9789 - val_rmse: 2.3531
# Epoch 964/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.5010 - r_squared: 0.9887 - rmse: 1.8483 - val_loss: 6.9489 - val_r_squared: 0.9809 - val_rmse: 2.2398
# Epoch 965/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5808 - r_squared: 0.9849 - rmse: 2.1413 - val_loss: 12.2451 - val_r_squared: 0.9607 - val_rmse: 3.2114
# Epoch 966/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.1679 - r_squared: 0.9834 - rmse: 2.2306 - val_loss: 7.4770 - val_r_squared: 0.9788 - val_rmse: 2.3547
# Epoch 967/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.2475 - r_squared: 0.9860 - rmse: 2.0567 - val_loss: 9.2198 - val_r_squared: 0.9722 - val_rmse: 2.6997
# Epoch 968/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.1728 - r_squared: 0.9861 - rmse: 2.0387 - val_loss: 6.7191 - val_r_squared: 0.9817 - val_rmse: 2.1879
# Epoch 969/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.7591 - r_squared: 0.9837 - rmse: 2.1908 - val_loss: 7.3523 - val_r_squared: 0.9793 - val_rmse: 2.3282
# Epoch 970/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.2287 - r_squared: 0.9793 - rmse: 2.4762 - val_loss: 6.7207 - val_r_squared: 0.9817 - val_rmse: 2.1886
# Epoch 971/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.2441 - r_squared: 0.9785 - rmse: 2.4563 - val_loss: 6.4674 - val_r_squared: 0.9827 - val_rmse: 2.1300
# Epoch 972/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.5417 - r_squared: 0.9747 - rmse: 2.6472 - val_loss: 7.4039 - val_r_squared: 0.9791 - val_rmse: 2.3396
# Epoch 973/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8868 - r_squared: 0.9841 - rmse: 2.1661 - val_loss: 12.6309 - val_r_squared: 0.9592 - val_rmse: 3.2712
# Epoch 974/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.6622 - r_squared: 0.9847 - rmse: 2.1158 - val_loss: 6.6150 - val_r_squared: 0.9821 - val_rmse: 2.1646
# Epoch 975/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.5254 - r_squared: 0.9884 - rmse: 1.8809 - val_loss: 7.8167 - val_r_squared: 0.9775 - val_rmse: 2.4263
# Epoch 976/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.7567 - r_squared: 0.9879 - rmse: 1.8970 - val_loss: 7.6806 - val_r_squared: 0.9781 - val_rmse: 2.3981
# Epoch 977/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.6846 - r_squared: 0.9876 - rmse: 1.9417 - val_loss: 9.4586 - val_r_squared: 0.9713 - val_rmse: 2.7440
# Epoch 978/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5551 - r_squared: 0.9852 - rmse: 2.0835 - val_loss: 7.7031 - val_r_squared: 0.9780 - val_rmse: 2.4028
# Epoch 979/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0764 - r_squared: 0.9832 - rmse: 2.2339 - val_loss: 10.2238 - val_r_squared: 0.9684 - val_rmse: 2.8800
# Epoch 980/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5952 - r_squared: 0.9846 - rmse: 2.1433 - val_loss: 7.7809 - val_r_squared: 0.9777 - val_rmse: 2.4191
# Epoch 981/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.9925 - r_squared: 0.9834 - rmse: 2.2379 - val_loss: 12.0381 - val_r_squared: 0.9614 - val_rmse: 3.1795
# Epoch 982/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.9927 - r_squared: 0.9833 - rmse: 2.2455 - val_loss: 11.5097 - val_r_squared: 0.9634 - val_rmse: 3.0955
# Epoch 983/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.3543 - r_squared: 0.9824 - rmse: 2.3017 - val_loss: 6.2567 - val_r_squared: 0.9835 - val_rmse: 2.0806
# Epoch 984/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.9082 - r_squared: 0.9874 - rmse: 1.9524 - val_loss: 8.0822 - val_r_squared: 0.9765 - val_rmse: 2.4808
# Epoch 985/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.5033 - r_squared: 0.9847 - rmse: 2.1108 - val_loss: 9.3416 - val_r_squared: 0.9717 - val_rmse: 2.7231
# Epoch 986/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.4085 - r_squared: 0.9854 - rmse: 2.1073 - val_loss: 11.9007 - val_r_squared: 0.9620 - val_rmse: 3.1581
# Epoch 987/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8887 - r_squared: 0.9842 - rmse: 2.1855 - val_loss: 7.6689 - val_r_squared: 0.9781 - val_rmse: 2.3963
# Epoch 988/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.7962 - r_squared: 0.9874 - rmse: 1.9634 - val_loss: 12.5559 - val_r_squared: 0.9595 - val_rmse: 3.2602
# Epoch 989/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.0978 - r_squared: 0.9832 - rmse: 2.2231 - val_loss: 6.4618 - val_r_squared: 0.9827 - val_rmse: 2.1298
# Epoch 990/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 4.9861 - r_squared: 0.9900 - rmse: 1.7450 - val_loss: 6.2923 - val_r_squared: 0.9833 - val_rmse: 2.0896
# Epoch 991/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 5.8177 - r_squared: 0.9865 - rmse: 1.9807 - val_loss: 6.6566 - val_r_squared: 0.9820 - val_rmse: 2.1750
# Epoch 992/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 8.9498 - r_squared: 0.9772 - rmse: 2.5699 - val_loss: 9.4264 - val_r_squared: 0.9714 - val_rmse: 2.7388
# Epoch 993/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 6.3195 - r_squared: 0.9858 - rmse: 2.0516 - val_loss: 6.4928 - val_r_squared: 0.9826 - val_rmse: 2.1373
# Epoch 994/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 6.8187 - r_squared: 0.9839 - rmse: 2.1901 - val_loss: 10.2250 - val_r_squared: 0.9683 - val_rmse: 2.8810
# Epoch 995/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.6154 - r_squared: 0.9816 - rmse: 2.3508 - val_loss: 13.5204 - val_r_squared: 0.9558 - val_rmse: 3.4053
# Epoch 996/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.6504 - r_squared: 0.9818 - rmse: 2.3163 - val_loss: 9.6465 - val_r_squared: 0.9705 - val_rmse: 2.7790
# Epoch 997/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 9.4505 - r_squared: 0.9757 - rmse: 2.6193 - val_loss: 14.8599 - val_r_squared: 0.9507 - val_rmse: 3.5967
# Epoch 998/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 7.1046 - r_squared: 0.9831 - rmse: 2.2313 - val_loss: 7.0556 - val_r_squared: 0.9804 - val_rmse: 2.2655
# Epoch 999/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.4580 - r_squared: 0.9885 - rmse: 1.8594 - val_loss: 6.5300 - val_r_squared: 0.9824 - val_rmse: 2.1463
# Epoch 1000/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 5.3240 - r_squared: 0.9892 - rmse: 1.7980 - val_loss: 8.2695 - val_r_squared: 0.9758 - val_rmse: 2.5192
# Early stopping did not occur.
# 5/5 [==============================] - 0s 589us/step - loss: 10.3069 - r_squared: 0.9745 - rmse: 2.7528
# Test Loss (MSE): 10.306937217712402
# Test Accuracy: 97.45235443115234
# Test RMSE: 2.7527925968170166

# %%
# Used to save the model
#model.compile(optimizer='adam', loss='mse')
model.save('BestModel275.keras')

# %%
import matplotlib.pyplot as plt

# Generate predictions on the test data
with tf.device('/GPU:0'):  # Optional
    y_pred = model.predict(x_test)

# Flatten y_test and y_pred for plotting
y_test_flat = y_test.numpy().flatten()
y_pred_flat = y_pred.flatten()

# Create scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(y_test_flat, y_pred_flat, alpha=0.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')

# Plot a 45-degree line for reference
plt.plot([-100, 1200], [-100, 1200], '--', color='gray')

plt.show()
# Out:
# 5/5 [==============================] - 0s 517us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = model.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 195us/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RelativeHumidity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 41
#      38 filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]
#      40 # Plotting
# ---> 41 plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)
#      44 # Labels and title
#      45 plt.xlabel('Resistance')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'RelativeHumidity'

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = model.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 197us/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RelativeHumidity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 41
#      38 filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]
#      40 # Plotting
# ---> 41 plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)
#      44 # Labels and title
#      45 plt.xlabel('Resistance')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'RelativeHumidity'

# %%
try:
        # Try loading the model without compiling
    loadedModel = tf.keras.models.load_model(
            "/Users/benfunk/DataspellProjects/MethaneDataScience/Ben's Analysis/BestMethaneModel292-968-4nodes.keras",custom_objects={"mse_loss": mse_loss},compile=False)
        # Then, compile the model manually
    loadedModel.compile(optimizer='adam', loss=mse_loss)
except Exception as e2:
    print(f"Failed again due to: {e2}")

# %%
testData = pd.read_csv('../Raw Data/CorrectedLog.csv')
def placeholder_function(vout, vref):
    return (vref*(5-vout))/(vout*(5-vref))  # Example placeholder function

# Calculate the time difference in days since the first row (assuming each row is 5 seconds)
df1 = pd.DataFrame()
df2 = pd.DataFrame()
# Iterate through the Vout and Vref columns to create rr columns
for i in range(8):
    vout_col = f'Vout_{i}'
    vref_col = f'Vref_{i}'
    rr_col = f'rr_{i}'

    df1[rr_col] = testData.apply(lambda row: placeholder_function(row[vout_col], row[vref_col]), axis=1)
    df2[rr_col] = df1[rr_col].rolling(window=5000).mean()  # Apply rolling average


calculatedResistance = df2.mean(axis=1)


T = 23
H = 40

# New DataFrame to store calculated values
fixed_temp = pd.Series([T]*len(calculatedResistance), name='FixedTemp')
fixed_humid = pd.Series([H]*len(calculatedResistance), name='FixedHumid')

final_test_data = pd.concat([calculatedResistance.reset_index(drop=True), fixed_temp, fixed_humid], axis=1)

# Perform prediction
predictions = loadedModel.predict(final_test_data)
if len(predictions.shape) == 2 and predictions.shape[1] == 1:
    predictions = predictions.flatten()

# Create an index list
index_list = list(range(len(predictions)))
df2['Days'] = df['Days']
first_4_days_df = df2[df2['Days'] < 1]

# Calculate the mean of all columns for each of the first days
daily_averages = first_4_days_df[rr_col].mean(axis=1)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(index_list, predictions+45, linestyle='-')
plt.xlabel('Index')
plt.ylabel('Predicted PPM')
plt.title('Line Plot of Predicted PPM using Neural Network')
plt.grid(True)
plt.show()
# Out:
# 17271/17271 [==============================] - 3s 182us/step
