# %%
import tensorflow as tf
from keras import regularizers
from keras.callbacks import EarlyStopping
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity import keras as sparsity
from sklearn.model_selection import GridSearchCV
import pandas as pd
import matplotlib.pyplot as plt
import csv
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras

# %%
# Setting the random seed so there is consistent data splitting between runs
tf.random.set_seed(42)
# importing the lowPPM matrix
allData = r"../../Output/BenSummaryJustMatrix.csv"

# Reading in the data to csv and removing any data at 150 ppm as this was incorrect data from testing
# NOTE: the 150 ppm is not in all outputs. but it is left in as a safeguard
df = pd.read_csv(allData)
df=df[df['Target PPM']!=150]
# Dropping all unneeded columns from the output
df = df.drop(columns=['Unnamed: 0','lowInterval','highInterval','Ratio'])
print(df.head())

# Declaring what sensor is used for the test set
test_sensor_id = 0  # Replace with the ID of the sensor you want in the test set
train_data = df[df['SensorID'] != test_sensor_id]
test_data = df[df['SensorID'] == test_sensor_id]

# Drop the SensorID column as we don't need it anymore
train_data = train_data.drop(columns=['SensorID'])
test_data = test_data.drop(columns=['SensorID'])
# Convert to TensorFlow tensors
train_data_tf = tf.convert_to_tensor(train_data, dtype=tf.float32)
test_data_tf = tf.convert_to_tensor(test_data, dtype=tf.float32)
# Out:
#    SensorID  Target PPM  Resistance  Temperature  RelativeHumidity
# 0       0.0         0.0    7.812575     35.42292         45.221903
# 1       1.0         0.0    7.314638     35.42292         45.221903
# 2       2.0         0.0    6.600787     35.42292         45.221903
# 3       3.0         0.0    6.089138     35.42292         45.221903
# 4       4.0         0.0    6.809271     35.42292         45.221903

# %%
# Randomizes the data for training to minimize fitting to false trends
train_data_shuffled = tf.random.shuffle(train_data_tf, seed=42)

# Separate features and labels
x_train, y_train = train_data_shuffled[:, 1:], train_data_shuffled[:, 0]
x_test, y_test = test_data_tf[:, 1:], test_data_tf[:, 0]

# %%
@keras.saving.register_keras_serializable()
def mse_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_pred - y_true))

@keras.saving.register_keras_serializable()
def rmse(y_true, y_pred):
    return tf.sqrt(mse_loss(y_pred, y_true))

@keras.saving.register_keras_serializable()
def r_squared(y_true, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y_true, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y_true, tf.reduce_mean(y_true))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# Used to trace history of RMSE as the neural network gets trained
class RMSEHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE = []
        self.validationRMSE = []

    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            logs = {}
        self.modelRMSE.append(logs.get('rmse'))
        self.validationRMSE.append(logs.get('val_rmse'))

# %%
rmse_history = RMSEHistory()
# Compile and train the model
input_shape = (x_train.shape[1],)

# %%
# Initialize a CSV file to store the results
csvfile = open('experiment_results.csv', 'w', newline='')
csvwriter = csv.writer(csvfile)
csvwriter.writerow(['BaseNum', 'Run', 'Test_RMSE', 'Test_Accuracy'])

for baseNum in tqdm(range(1, 16), desc='BaseNum Loop'):  # Wrap outer loop with tqdm
    for run in tqdm(range(1, 101), desc=f'Run Loop for BaseNum {baseNum}', leave=False):  # Wrap inner loop with tqdm

# Define your original model with regularization
        def build_model(input_shape, regularization_factor=0.01):
            model = tf.keras.Sequential([
                tf.keras.layers.Dense(baseNum*2, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
                tf.keras.layers.Dense(baseNum*4, activation='mish', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
                tf.keras.layers.Dense(1)
            ])
            return model

        with tf.device('/GPU:0'):
            model = build_model(input_shape)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[rmse_history],verbose=0)
            test_metrics = model.evaluate(x_test, y_test,verbose=0)
            test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
        # Save the results
        csvwriter.writerow([baseNum, run, test_rmse, test_accuracy])
        csvfile.flush()
csvfile.close()

# %%
df1 = pd.read_csv("./experiment_results.csv")

# Create a figure and axis object for the boxplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Create a boxplot for Test_RMSE grouped by BaseNum
df1.boxplot(column='Test_RMSE', by='BaseNum', ax=ax[0])
ax[0].set_title('Boxplot of Test_RMSE Grouped by BaseNum')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Test_RMSE')

# Create a boxplot for Test_Accuracy grouped by BaseNum
df1.boxplot(column='Test_Accuracy', by='BaseNum', ax=ax[1])
ax[1].set_title('Boxplot of Test_Accuracy Grouped by BaseNum')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Test_Accuracy')

# Show the plots
plt.suptitle('Boxplots Grouped by BaseNum')
plt.show()

# Group by BaseNum and calculate the mean
grouped_means = df1.groupby('BaseNum').mean()

# Create a figure and axis objects
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the mean of Test_RMSE
ax[0].plot(grouped_means.index, grouped_means['Test_RMSE'], label='Test_RMSE', marker='o')
ax[0].set_xlabel('BaseNum')
ax[0].set_ylabel('Mean of Test_RMSE')
ax[0].set_title('Mean of Test_RMSE Grouped by BaseNum')
ax[0].legend()

# Plot the mean of Test_Accuracy
ax[1].plot(grouped_means.index, grouped_means['Test_Accuracy'], label='Test_Accuracy', marker='x')
ax[1].set_xlabel('BaseNum')
ax[1].set_ylabel('Mean of Test_Accuracy')
ax[1].set_title('Mean of Test_Accuracy Grouped by BaseNum')
ax[1].legend()

# Show the plot
plt.show()

# %%
import random
from keras.src.losses import mean_squared_error

activation_functions = ['relu', 'sigmoid', 'elu', 'selu', 'swish', 'linear']

best_activation = None
lowest_mse = float('inf')
baseNum = 4
n=100
def build_model(input_shape, activations, regularization_factor=0.01,):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation=activations[0], kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation=activations[1], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation=activations[2], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation=activations[3], kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model
for _ in tqdm(range(n), desc='BaseNum Loop'):
    # Randomly select activation functions for each layer
    activation = [random.choice(activation_functions) for _ in range(4)]
    rmse_list = []

    early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
    for _ in range(int(n/4)):
        # Create and train the model
        with tf.device('/GPU:0'):
    #regular model training
            model = build_model(input_shape,activation)
            model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
            model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)

        # Evaluate on validation data
            y_val_pred = model.predict(x_test,verbose=0)
            rmse1 = rmse(y_test, y_val_pred)
            rmse_list.append(rmse1)

    # Average RMSE for this sequence of activations
    avg_rmse = np.mean(rmse_list)
    print(f"Average RMSE with activations {activation}: {avg_rmse}")

    # Update the best activation function if needed
    if avg_rmse < lowest_mse:
        best_activation = activation
        lowest_mse = avg_rmse

print(f"Best activation function is {best_activation} with RMSE {lowest_mse}")
# Out:
# BaseNum Loop:   1%|          | 1/100 [02:00<3:19:09, 120.70s/it]
# Average RMSE with activations ['swish', 'selu', 'relu', 'relu']: 23.442481994628906
# BaseNum Loop:   1%|          | 1/100 [02:28<4:04:41, 148.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 31
#      29     model = build_model(input_shape,activation)
#      30     model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
# ---> 31     model.fit(x_train, y_train, epochs=1000, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history],verbose=0)
#      33 # Evaluate on validation data
#      34     y_val_pred = model.predict(x_test,verbose=0)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:2189, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2187 self._test_counter.assign(0)
#    2188 callbacks.on_test_begin()
# -> 2189 for (
#    2190     _,
#    2191     dataset_or_iterator,
#    2192 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2193     self.reset_metrics()
#    2194     with data_handler.catch_stop_iteration():
#
# File ~/anaconda3/lib/python3.10/site-packages/keras/src/engine/data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3420, in make_iterator(dataset, iterator, name)
#    3418 if tld.is_eager:
#    3419   try:
# -> 3420     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3421       _ctx, "MakeIterator", name, dataset, iterator)
#    3422     return _result
#    3423   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# NOTE: with =2 (Or any small int) it is hit or miss whether the model will go down the best optimized path. rerun a few times to determine what the best value is
#Used to quickly change size of neural net
baseNum = 4

# Define your original model with regularization
def build_model(input_shape, regularization_factor=0.01):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(baseNum*2, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor), input_shape=input_shape),
        tf.keras.layers.Dense(baseNum*4, activation='elu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*4, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(baseNum*2, activation='linear', kernel_regularizer=regularizers.l2(regularization_factor)),
        # tf.keras.layers.Dense(baseNum, activation='relu', kernel_regularizer=regularizers.l2(regularization_factor)),
        tf.keras.layers.Dense(1)
    ])
    return model

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

with tf.device('/GPU:0'):
    #regular model training
    model = build_model(input_shape)
    model.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])
    model.fit(x_train, y_train, epochs=500, batch_size=50, validation_split=0.2, callbacks=[early_stopping,rmse_history])
    # if no improvement has been made in 100 generations (epochs) stop the model
    if early_stopping.stopped_epoch > 0:
        print(f"Early stopping occurred at epoch {early_stopping.stopped_epoch}")
        print(f"Restoring model weights from the end of the best epoch.")
    else:
        print("Early stopping did not occur.")

    test_metrics = model.evaluate(x_test, y_test)
    test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
    print(f"Test Loss (MSE): {test_loss}")
    print(f"Test Accuracy: {test_accuracy*100}")
    print(f"Test RMSE: {test_rmse}")
    # Plotting RMSE values
    plt.figure(figsize=(10, 5))
    plt.plot(rmse_history.modelRMSE, label='Train RMSE')
    plt.plot(rmse_history.validationRMSE, label='Validation RMSE')
    plt.xlabel('Generation')
    plt.ylabel('RMSE')
    plt.title('RMSE During Training')
    plt.legend()
    plt.show()

    # Pruning model. use the final_sparsity to trim the model. 0.5 means 50% of the nodes get trimmed, 0.9 means 90% of the nodes get trimmed. typically 0.6 is a good starting point for this when using large models
    pruning_params = {
        'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.0,
                                                    final_sparsity=0.4,
                                                    begin_step=len(x_train) // 50 * 10,
                                                    end_step=len(x_train) // 50 * 500)
    }

    model_for_pruning = sparsity.prune_low_magnitude(model, **pruning_params)
    model_for_pruning.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared,rmse])

    callbacks = [
        sparsity.UpdatePruningStep(),
        early_stopping,
        rmse_history
    ]

    model_for_pruning.fit(x_train, y_train, epochs=200, batch_size=50, validation_split=0.2, callbacks=callbacks)

    # Remove the pruning wrappers to finalize the model
    modelFinal = sparsity.strip_pruning(model_for_pruning)
    modelFinal.compile(optimizer='adam', loss=mse_loss, metrics=[r_squared, rmse])

if early_stopping.stopped_epoch > 0:
    print(f"Early stopping occurred at epoch {early_stopping.stopped_epoch}")
    print(f"Restoring model weights from the end of the best epoch.")
else:
    print("Early stopping did not occur.")

# Make predictions
with tf.device('/GPU:0'):  # This line is optional
    test_metrics = modelFinal.evaluate(x_test, y_test)
    test_loss, test_accuracy, test_rmse = test_metrics[0], test_metrics[1], test_metrics[2]
    print(f"Test Loss (MSE): {test_loss}")
    print(f"Test Accuracy: {test_accuracy*100}")
    print(f"Test RMSE: {test_rmse}")


# Plotting RMSE values
plt.figure(figsize=(10, 5))
plt.plot(rmse_history.modelRMSE, label='Train RMSE')
plt.plot(rmse_history.validationRMSE, label='Validation RMSE')
plt.xlabel('Generation')
plt.ylabel('RMSE')
plt.title('RMSE During Pruning')
plt.legend()
plt.show()
# model.save('MethaneModel.keras')
# Out:
# Epoch 1/500
# 25/25 [==============================] - 0s 3ms/step - loss: 253654.0000 - r_squared: -1.4015 - rmse: 502.3386 - val_loss: 227675.6094 - val_r_squared: -inf - val_rmse: 509.3149
# Epoch 2/500
# 25/25 [==============================] - 0s 827us/step - loss: 221597.7344 - r_squared: -1.0686 - rmse: 468.5376 - val_loss: 191996.5625 - val_r_squared: -inf - val_rmse: 466.3369
# Epoch 3/500
# 25/25 [==============================] - 0s 858us/step - loss: 175849.0938 - r_squared: -0.6945 - rmse: 419.9719 - val_loss: 151555.2812 - val_r_squared: -inf - val_rmse: 407.9539
# Epoch 4/500
# 25/25 [==============================] - 0s 841us/step - loss: 137176.3906 - r_squared: -0.3123 - rmse: 370.3882 - val_loss: 141977.8438 - val_r_squared: -inf - val_rmse: 378.9770
# Epoch 5/500
# 25/25 [==============================] - 0s 783us/step - loss: 129731.7109 - r_squared: -0.2471 - rmse: 358.2926 - val_loss: 141699.5312 - val_r_squared: -inf - val_rmse: 377.6888
# Epoch 6/500
# 25/25 [==============================] - 0s 714us/step - loss: 128617.5078 - r_squared: -0.2368 - rmse: 360.9496 - val_loss: 140071.3906 - val_r_squared: -inf - val_rmse: 376.9087
# Epoch 7/500
# 25/25 [==============================] - 0s 761us/step - loss: 127443.5234 - r_squared: -0.1955 - rmse: 353.3269 - val_loss: 139756.9844 - val_r_squared: -inf - val_rmse: 375.2168
# Epoch 8/500
# 25/25 [==============================] - 0s 697us/step - loss: 126018.0234 - r_squared: -0.1917 - rmse: 354.4902 - val_loss: 137173.2656 - val_r_squared: -inf - val_rmse: 373.0313
# Epoch 9/500
# 25/25 [==============================] - 0s 807us/step - loss: 123424.9531 - r_squared: -0.1678 - rmse: 350.8780 - val_loss: 133466.4062 - val_r_squared: -inf - val_rmse: 367.0614
# Epoch 10/500
# 25/25 [==============================] - 0s 752us/step - loss: 118556.3672 - r_squared: -0.1138 - rmse: 342.6007 - val_loss: 130649.8203 - val_r_squared: -inf - val_rmse: 360.7377
# Epoch 11/500
# 25/25 [==============================] - 0s 749us/step - loss: 114530.5625 - r_squared: -0.0894 - rmse: 335.1654 - val_loss: 125900.0625 - val_r_squared: -inf - val_rmse: 355.5987
# Epoch 12/500
# 25/25 [==============================] - 0s 770us/step - loss: 110531.7500 - r_squared: -0.0509 - rmse: 330.6346 - val_loss: 123625.2031 - val_r_squared: -inf - val_rmse: 349.8847
# Epoch 13/500
# 25/25 [==============================] - 0s 694us/step - loss: 107496.2422 - r_squared: -0.0253 - rmse: 322.0643 - val_loss: 119115.6328 - val_r_squared: -inf - val_rmse: 346.0334
# Epoch 14/500
# 25/25 [==============================] - 0s 741us/step - loss: 104609.1250 - r_squared: 0.0053 - rmse: 318.9797 - val_loss: 116398.3125 - val_r_squared: -inf - val_rmse: 341.4751
# Epoch 15/500
# 25/25 [==============================] - 0s 648us/step - loss: 101854.7500 - r_squared: 0.0255 - rmse: 316.0419 - val_loss: 119391.3438 - val_r_squared: -inf - val_rmse: 338.1155
# Epoch 16/500
# 25/25 [==============================] - 0s 740us/step - loss: 100690.7656 - r_squared: 0.0271 - rmse: 317.2683 - val_loss: 111210.0625 - val_r_squared: -inf - val_rmse: 333.6489
# Epoch 17/500
# 25/25 [==============================] - 0s 665us/step - loss: 97214.1562 - r_squared: 0.0534 - rmse: 313.5581 - val_loss: 108647.0859 - val_r_squared: -inf - val_rmse: 330.0334
# Epoch 18/500
# 25/25 [==============================] - 0s 711us/step - loss: 94900.0859 - r_squared: 0.0921 - rmse: 306.1950 - val_loss: 106705.5859 - val_r_squared: -inf - val_rmse: 325.9392
# Epoch 19/500
# 25/25 [==============================] - 0s 679us/step - loss: 93399.8906 - r_squared: 0.1121 - rmse: 302.5115 - val_loss: 103831.2031 - val_r_squared: -inf - val_rmse: 323.3339
# Epoch 20/500
# 25/25 [==============================] - 0s 704us/step - loss: 91058.8359 - r_squared: 0.1359 - rmse: 301.7222 - val_loss: 101931.5781 - val_r_squared: -inf - val_rmse: 319.2183
# Epoch 21/500
# 25/25 [==============================] - 0s 689us/step - loss: 89136.1719 - r_squared: 0.1113 - rmse: 297.7948 - val_loss: 99313.6641 - val_r_squared: -inf - val_rmse: 316.4625
# Epoch 22/500
# 25/25 [==============================] - 0s 696us/step - loss: 87499.0391 - r_squared: 0.1666 - rmse: 293.7004 - val_loss: 97431.1953 - val_r_squared: -inf - val_rmse: 313.4258
# Epoch 23/500
# 25/25 [==============================] - 0s 663us/step - loss: 85852.5547 - r_squared: 0.1911 - rmse: 292.7243 - val_loss: 95503.3750 - val_r_squared: -inf - val_rmse: 314.3822
# Epoch 24/500
# 25/25 [==============================] - 0s 714us/step - loss: 84598.8906 - r_squared: 0.1893 - rmse: 286.4425 - val_loss: 93411.5703 - val_r_squared: -inf - val_rmse: 307.8557
# Epoch 25/500
# 25/25 [==============================] - 0s 730us/step - loss: 83164.8281 - r_squared: 0.1853 - rmse: 284.5982 - val_loss: 91416.7734 - val_r_squared: -inf - val_rmse: 305.9951
# Epoch 26/500
# 25/25 [==============================] - 0s 704us/step - loss: 81851.1797 - r_squared: 0.2304 - rmse: 282.9621 - val_loss: 91788.6484 - val_r_squared: -inf - val_rmse: 301.1103
# Epoch 27/500
# 25/25 [==============================] - 0s 692us/step - loss: 79783.2578 - r_squared: 0.2367 - rmse: 280.3944 - val_loss: 87978.6016 - val_r_squared: -inf - val_rmse: 300.3218
# Epoch 28/500
# 25/25 [==============================] - 0s 692us/step - loss: 78574.6250 - r_squared: 0.2550 - rmse: 279.2491 - val_loss: 86380.0625 - val_r_squared: -inf - val_rmse: 297.6783
# Epoch 29/500
# 25/25 [==============================] - 0s 717us/step - loss: 77361.2578 - r_squared: 0.2649 - rmse: 276.5397 - val_loss: 85084.2656 - val_r_squared: -inf - val_rmse: 293.9551
# Epoch 30/500
# 25/25 [==============================] - 0s 687us/step - loss: 76316.6719 - r_squared: 0.2637 - rmse: 277.9050 - val_loss: 83850.8047 - val_r_squared: -inf - val_rmse: 290.8026
# Epoch 31/500
# 25/25 [==============================] - 0s 702us/step - loss: 75128.2734 - r_squared: 0.2766 - rmse: 269.0214 - val_loss: 81974.9688 - val_r_squared: -inf - val_rmse: 290.8289
# Epoch 32/500
# 25/25 [==============================] - 0s 664us/step - loss: 73465.5781 - r_squared: 0.3082 - rmse: 269.4945 - val_loss: 80887.0703 - val_r_squared: -inf - val_rmse: 290.2594
# Epoch 33/500
# 25/25 [==============================] - 0s 724us/step - loss: 72773.5547 - r_squared: 0.2846 - rmse: 264.2109 - val_loss: 79780.8750 - val_r_squared: -inf - val_rmse: 289.4219
# Epoch 34/500
# 25/25 [==============================] - 0s 674us/step - loss: 72122.0547 - r_squared: 0.3109 - rmse: 267.7696 - val_loss: 79200.4297 - val_r_squared: -inf - val_rmse: 289.2813
# Epoch 35/500
# 25/25 [==============================] - 0s 703us/step - loss: 70382.3359 - r_squared: 0.3263 - rmse: 262.9040 - val_loss: 76573.0859 - val_r_squared: -inf - val_rmse: 278.9804
# Epoch 36/500
# 25/25 [==============================] - 0s 669us/step - loss: 68863.1172 - r_squared: 0.3379 - rmse: 262.9354 - val_loss: 75126.6250 - val_r_squared: -inf - val_rmse: 276.9444
# Epoch 37/500
# 25/25 [==============================] - 0s 715us/step - loss: 67438.9297 - r_squared: 0.3736 - rmse: 257.0380 - val_loss: 73993.5234 - val_r_squared: -inf - val_rmse: 274.7804
# Epoch 38/500
# 25/25 [==============================] - 0s 668us/step - loss: 66471.5859 - r_squared: 0.3659 - rmse: 255.3832 - val_loss: 72470.9766 - val_r_squared: -inf - val_rmse: 272.2718
# Epoch 39/500
# 25/25 [==============================] - 0s 717us/step - loss: 65332.1719 - r_squared: 0.3778 - rmse: 255.3007 - val_loss: 71347.5078 - val_r_squared: -inf - val_rmse: 269.6087
# Epoch 40/500
# 25/25 [==============================] - 0s 666us/step - loss: 64017.3008 - r_squared: 0.4024 - rmse: 247.2339 - val_loss: 69912.1328 - val_r_squared: -inf - val_rmse: 268.9901
# Epoch 41/500
# 25/25 [==============================] - 0s 721us/step - loss: 62690.1172 - r_squared: 0.4165 - rmse: 245.3136 - val_loss: 69313.3438 - val_r_squared: -inf - val_rmse: 263.8465
# Epoch 42/500
# 25/25 [==============================] - 0s 646us/step - loss: 62066.6797 - r_squared: 0.4048 - rmse: 244.5637 - val_loss: 69557.2109 - val_r_squared: -inf - val_rmse: 271.0655
# Epoch 43/500
# 25/25 [==============================] - 0s 712us/step - loss: 61510.6055 - r_squared: 0.4115 - rmse: 247.8419 - val_loss: 66453.5078 - val_r_squared: -inf - val_rmse: 261.6945
# Epoch 44/500
# 25/25 [==============================] - 0s 686us/step - loss: 59223.7812 - r_squared: 0.4404 - rmse: 239.8603 - val_loss: 64788.6875 - val_r_squared: -inf - val_rmse: 257.3905
# Epoch 45/500
# 25/25 [==============================] - 0s 723us/step - loss: 58478.6133 - r_squared: 0.4399 - rmse: 237.7255 - val_loss: 63771.2617 - val_r_squared: -inf - val_rmse: 257.3903
# Epoch 46/500
# 25/25 [==============================] - 0s 674us/step - loss: 56968.1797 - r_squared: 0.4561 - rmse: 235.1179 - val_loss: 63239.0352 - val_r_squared: -inf - val_rmse: 256.3954
# Epoch 47/500
# 25/25 [==============================] - 0s 730us/step - loss: 56286.3945 - r_squared: 0.4650 - rmse: 235.2813 - val_loss: 61149.0742 - val_r_squared: -inf - val_rmse: 249.1676
# Epoch 48/500
# 25/25 [==============================] - 0s 680us/step - loss: 54802.8203 - r_squared: 0.4743 - rmse: 233.5917 - val_loss: 59663.4531 - val_r_squared: -inf - val_rmse: 247.6480
# Epoch 49/500
# 25/25 [==============================] - 0s 734us/step - loss: 53510.1211 - r_squared: 0.4921 - rmse: 227.9476 - val_loss: 58463.3203 - val_r_squared: -inf - val_rmse: 245.5125
# Epoch 50/500
# 25/25 [==============================] - 0s 664us/step - loss: 52327.9570 - r_squared: 0.5019 - rmse: 227.2040 - val_loss: 58118.3281 - val_r_squared: -inf - val_rmse: 246.6777
# Epoch 51/500
# 25/25 [==============================] - 0s 750us/step - loss: 51474.7773 - r_squared: 0.5178 - rmse: 223.3198 - val_loss: 55857.4258 - val_r_squared: -inf - val_rmse: 240.0326
# Epoch 52/500
# 25/25 [==============================] - 0s 700us/step - loss: 50470.3008 - r_squared: 0.4877 - rmse: 224.3095 - val_loss: 54400.7539 - val_r_squared: -inf - val_rmse: 236.5878
# Epoch 53/500
# 25/25 [==============================] - 0s 758us/step - loss: 50697.3164 - r_squared: 0.5288 - rmse: 222.2774 - val_loss: 54166.4141 - val_r_squared: -inf - val_rmse: 237.7346
# Epoch 54/500
# 25/25 [==============================] - 0s 686us/step - loss: 49254.0625 - r_squared: 0.5247 - rmse: 222.0652 - val_loss: 52499.5312 - val_r_squared: -inf - val_rmse: 230.1944
# Epoch 55/500
# 25/25 [==============================] - 0s 738us/step - loss: 47333.7422 - r_squared: 0.5641 - rmse: 213.5130 - val_loss: 50848.8633 - val_r_squared: -inf - val_rmse: 228.9504
# Epoch 56/500
# 25/25 [==============================] - 0s 671us/step - loss: 45430.6289 - r_squared: 0.5767 - rmse: 208.6253 - val_loss: 49435.7773 - val_r_squared: -inf - val_rmse: 226.5738
# Epoch 57/500
# 25/25 [==============================] - 0s 692us/step - loss: 44004.9141 - r_squared: 0.5697 - rmse: 208.3229 - val_loss: 47847.4141 - val_r_squared: -inf - val_rmse: 222.2140
# Epoch 58/500
# 25/25 [==============================] - 0s 677us/step - loss: 42765.7734 - r_squared: 0.5969 - rmse: 205.6667 - val_loss: 46710.8984 - val_r_squared: -inf - val_rmse: 220.3191
# Epoch 59/500
# 25/25 [==============================] - 0s 706us/step - loss: 41348.6289 - r_squared: 0.6073 - rmse: 201.7889 - val_loss: 45134.9883 - val_r_squared: -inf - val_rmse: 217.0517
# Epoch 60/500
# 25/25 [==============================] - 0s 670us/step - loss: 40381.1367 - r_squared: 0.6153 - rmse: 197.3262 - val_loss: 44775.5508 - val_r_squared: -inf - val_rmse: 216.4461
# Epoch 61/500
# 25/25 [==============================] - 0s 724us/step - loss: 39317.2031 - r_squared: 0.6327 - rmse: 195.5329 - val_loss: 43608.5742 - val_r_squared: -inf - val_rmse: 214.5218
# Epoch 62/500
# 25/25 [==============================] - 0s 660us/step - loss: 37794.5469 - r_squared: 0.6388 - rmse: 191.7508 - val_loss: 40752.7070 - val_r_squared: -inf - val_rmse: 206.4473
# Epoch 63/500
# 25/25 [==============================] - 0s 695us/step - loss: 35993.0312 - r_squared: 0.6599 - rmse: 188.2786 - val_loss: 38906.2656 - val_r_squared: -inf - val_rmse: 201.7431
# Epoch 64/500
# 25/25 [==============================] - 0s 664us/step - loss: 34414.9375 - r_squared: 0.6842 - rmse: 181.6989 - val_loss: 37487.0078 - val_r_squared: -inf - val_rmse: 197.1863
# Epoch 65/500
# 25/25 [==============================] - 0s 729us/step - loss: 33462.6328 - r_squared: 0.6789 - rmse: 180.8747 - val_loss: 35460.1797 - val_r_squared: -inf - val_rmse: 190.9153
# Epoch 66/500
# 25/25 [==============================] - 0s 676us/step - loss: 31649.2578 - r_squared: 0.7026 - rmse: 175.8664 - val_loss: 33755.6602 - val_r_squared: -inf - val_rmse: 186.5046
# Epoch 67/500
# 25/25 [==============================] - 0s 722us/step - loss: 30676.8652 - r_squared: 0.7040 - rmse: 173.5068 - val_loss: 32570.9180 - val_r_squared: -inf - val_rmse: 184.8675
# Epoch 68/500
# 25/25 [==============================] - 0s 664us/step - loss: 29159.7520 - r_squared: 0.7212 - rmse: 170.0668 - val_loss: 30590.3633 - val_r_squared: -inf - val_rmse: 178.6524
# Epoch 69/500
# 25/25 [==============================] - 0s 710us/step - loss: 27371.4062 - r_squared: 0.7376 - rmse: 164.0862 - val_loss: 29884.2109 - val_r_squared: -inf - val_rmse: 178.0870
# Epoch 70/500
# 25/25 [==============================] - 0s 682us/step - loss: 26024.4180 - r_squared: 0.7525 - rmse: 160.9291 - val_loss: 28487.8555 - val_r_squared: -inf - val_rmse: 169.6132
# Epoch 71/500
# 25/25 [==============================] - 0s 732us/step - loss: 24737.3301 - r_squared: 0.7618 - rmse: 156.9163 - val_loss: 25953.0352 - val_r_squared: -inf - val_rmse: 165.3133
# Epoch 72/500
# 25/25 [==============================] - 0s 668us/step - loss: 22989.1973 - r_squared: 0.7800 - rmse: 151.7066 - val_loss: 25096.2402 - val_r_squared: -inf - val_rmse: 163.3632
# Epoch 73/500
# 25/25 [==============================] - 0s 730us/step - loss: 21537.3984 - r_squared: 0.7825 - rmse: 147.5653 - val_loss: 23130.2637 - val_r_squared: -inf - val_rmse: 154.3640
# Epoch 74/500
# 25/25 [==============================] - 0s 684us/step - loss: 20293.4102 - r_squared: 0.8101 - rmse: 138.7035 - val_loss: 21531.6543 - val_r_squared: -inf - val_rmse: 149.5823
# Epoch 75/500
# 25/25 [==============================] - 0s 715us/step - loss: 19841.0430 - r_squared: 0.8142 - rmse: 138.1313 - val_loss: 23881.8027 - val_r_squared: -inf - val_rmse: 161.0548
# Epoch 76/500
# 25/25 [==============================] - 0s 661us/step - loss: 18633.7637 - r_squared: 0.8238 - rmse: 136.0428 - val_loss: 18993.2012 - val_r_squared: -inf - val_rmse: 141.4209
# Epoch 77/500
# 25/25 [==============================] - 0s 713us/step - loss: 19236.4863 - r_squared: 0.8203 - rmse: 136.2702 - val_loss: 18166.7578 - val_r_squared: -inf - val_rmse: 136.3764
# Epoch 78/500
# 25/25 [==============================] - 0s 666us/step - loss: 15938.9756 - r_squared: 0.8519 - rmse: 123.2405 - val_loss: 17381.4531 - val_r_squared: -inf - val_rmse: 135.8039
# Epoch 79/500
# 25/25 [==============================] - 0s 730us/step - loss: 14797.9951 - r_squared: 0.8630 - rmse: 119.8248 - val_loss: 15739.0938 - val_r_squared: -inf - val_rmse: 128.4033
# Epoch 80/500
# 25/25 [==============================] - 0s 637us/step - loss: 14646.3779 - r_squared: 0.8603 - rmse: 119.4171 - val_loss: 16086.5742 - val_r_squared: -inf - val_rmse: 131.2544
# Epoch 81/500
# 25/25 [==============================] - 0s 730us/step - loss: 13454.4443 - r_squared: 0.8626 - rmse: 117.4541 - val_loss: 16078.9404 - val_r_squared: -inf - val_rmse: 131.3566
# Epoch 82/500
# 25/25 [==============================] - 0s 693us/step - loss: 12782.8232 - r_squared: 0.8765 - rmse: 112.6067 - val_loss: 13698.5615 - val_r_squared: -inf - val_rmse: 119.5784
# Epoch 83/500
# 25/25 [==============================] - 0s 706us/step - loss: 12391.0488 - r_squared: 0.8824 - rmse: 110.8007 - val_loss: 12471.9658 - val_r_squared: -inf - val_rmse: 113.3811
# Epoch 84/500
# 25/25 [==============================] - 0s 662us/step - loss: 11378.7842 - r_squared: 0.8932 - rmse: 106.2224 - val_loss: 11915.3066 - val_r_squared: -inf - val_rmse: 111.2250
# Epoch 85/500
# 25/25 [==============================] - 0s 720us/step - loss: 10639.5801 - r_squared: 0.8980 - rmse: 101.6473 - val_loss: 11425.4492 - val_r_squared: -inf - val_rmse: 108.7241
# Epoch 86/500
# 25/25 [==============================] - 0s 675us/step - loss: 10473.6836 - r_squared: 0.8992 - rmse: 101.6315 - val_loss: 10909.0107 - val_r_squared: -inf - val_rmse: 105.4633
# Epoch 87/500
# 25/25 [==============================] - 0s 692us/step - loss: 10037.6514 - r_squared: 0.9038 - rmse: 99.2117 - val_loss: 13256.6338 - val_r_squared: -inf - val_rmse: 119.0906
# Epoch 88/500
# 25/25 [==============================] - 0s 680us/step - loss: 9932.7471 - r_squared: 0.9023 - rmse: 99.8670 - val_loss: 10249.6914 - val_r_squared: -inf - val_rmse: 102.8524
# Epoch 89/500
# 25/25 [==============================] - 0s 710us/step - loss: 9192.7109 - r_squared: 0.9087 - rmse: 96.2327 - val_loss: 10031.8262 - val_r_squared: -inf - val_rmse: 102.1179
# Epoch 90/500
# 25/25 [==============================] - 0s 671us/step - loss: 8761.4717 - r_squared: 0.9176 - rmse: 92.4586 - val_loss: 9409.2461 - val_r_squared: -inf - val_rmse: 96.8861
# Epoch 91/500
# 25/25 [==============================] - 0s 712us/step - loss: 8725.1484 - r_squared: 0.9162 - rmse: 91.9576 - val_loss: 10343.0557 - val_r_squared: -inf - val_rmse: 104.2168
# Epoch 92/500
# 25/25 [==============================] - 0s 659us/step - loss: 9662.2109 - r_squared: 0.9075 - rmse: 97.1958 - val_loss: 9154.2100 - val_r_squared: -inf - val_rmse: 97.2865
# Epoch 93/500
# 25/25 [==============================] - 0s 725us/step - loss: 8083.7607 - r_squared: 0.9214 - rmse: 90.3248 - val_loss: 9045.1504 - val_r_squared: -inf - val_rmse: 96.2146
# Epoch 94/500
# 25/25 [==============================] - 0s 684us/step - loss: 7931.2295 - r_squared: 0.9249 - rmse: 88.0043 - val_loss: 8677.2422 - val_r_squared: -inf - val_rmse: 94.2047
# Epoch 95/500
# 25/25 [==============================] - 0s 712us/step - loss: 7670.3062 - r_squared: 0.9231 - rmse: 88.0840 - val_loss: 8179.8818 - val_r_squared: -inf - val_rmse: 91.3618
# Epoch 96/500
# 25/25 [==============================] - 0s 669us/step - loss: 7710.1104 - r_squared: 0.9272 - rmse: 87.0917 - val_loss: 7994.4976 - val_r_squared: -inf - val_rmse: 90.0514
# Epoch 97/500
# 25/25 [==============================] - 0s 714us/step - loss: 7400.2334 - r_squared: 0.9293 - rmse: 85.0350 - val_loss: 7911.6313 - val_r_squared: -inf - val_rmse: 89.7716
# Epoch 98/500
# 25/25 [==============================] - 0s 688us/step - loss: 7740.4795 - r_squared: 0.9266 - rmse: 86.8815 - val_loss: 7483.3901 - val_r_squared: -inf - val_rmse: 86.8890
# Epoch 99/500
# 25/25 [==============================] - 0s 726us/step - loss: 7220.4165 - r_squared: 0.9320 - rmse: 83.9598 - val_loss: 7303.9355 - val_r_squared: -inf - val_rmse: 86.1294
# Epoch 100/500
# 25/25 [==============================] - 0s 656us/step - loss: 7065.2964 - r_squared: 0.9312 - rmse: 83.3743 - val_loss: 7382.1792 - val_r_squared: -inf - val_rmse: 86.3183
# Epoch 101/500
# 25/25 [==============================] - 0s 735us/step - loss: 7115.3047 - r_squared: 0.9322 - rmse: 84.4542 - val_loss: 7486.3423 - val_r_squared: -inf - val_rmse: 87.7716
# Epoch 102/500
# 25/25 [==============================] - 0s 694us/step - loss: 6779.0474 - r_squared: 0.9352 - rmse: 81.9038 - val_loss: 7014.4800 - val_r_squared: -inf - val_rmse: 84.0462
# Epoch 103/500
# 25/25 [==============================] - 0s 716us/step - loss: 6685.7563 - r_squared: 0.9356 - rmse: 81.5209 - val_loss: 8769.9004 - val_r_squared: -inf - val_rmse: 96.0707
# Epoch 104/500
# 25/25 [==============================] - 0s 673us/step - loss: 6812.8481 - r_squared: 0.9339 - rmse: 81.8641 - val_loss: 6826.1724 - val_r_squared: -inf - val_rmse: 83.5241
# Epoch 105/500
# 25/25 [==============================] - 0s 707us/step - loss: 6534.6396 - r_squared: 0.9343 - rmse: 80.3900 - val_loss: 7496.2271 - val_r_squared: -inf - val_rmse: 88.5088
# Epoch 106/500
# 25/25 [==============================] - 0s 692us/step - loss: 6472.1743 - r_squared: 0.9385 - rmse: 79.3650 - val_loss: 6817.6978 - val_r_squared: -inf - val_rmse: 84.0792
# Epoch 107/500
# 25/25 [==============================] - 0s 698us/step - loss: 6263.6221 - r_squared: 0.9394 - rmse: 78.9947 - val_loss: 6494.1958 - val_r_squared: -inf - val_rmse: 81.0972
# Epoch 108/500
# 25/25 [==============================] - 0s 649us/step - loss: 6312.6504 - r_squared: 0.9408 - rmse: 78.3926 - val_loss: 6522.4668 - val_r_squared: -inf - val_rmse: 81.5712
# Epoch 109/500
# 25/25 [==============================] - 0s 726us/step - loss: 6441.2803 - r_squared: 0.9385 - rmse: 80.2851 - val_loss: 6405.8867 - val_r_squared: -inf - val_rmse: 81.1536
# Epoch 110/500
# 25/25 [==============================] - 0s 677us/step - loss: 6743.4453 - r_squared: 0.9371 - rmse: 81.0633 - val_loss: 6099.8940 - val_r_squared: -inf - val_rmse: 79.0390
# Epoch 111/500
# 25/25 [==============================] - 0s 714us/step - loss: 6024.0933 - r_squared: 0.9434 - rmse: 76.2691 - val_loss: 7080.2632 - val_r_squared: -inf - val_rmse: 86.1131
# Epoch 112/500
# 25/25 [==============================] - 0s 672us/step - loss: 6187.9600 - r_squared: 0.9409 - rmse: 78.3055 - val_loss: 6820.4360 - val_r_squared: -inf - val_rmse: 84.4794
# Epoch 113/500
# 25/25 [==============================] - 0s 732us/step - loss: 5952.8096 - r_squared: 0.9434 - rmse: 76.7305 - val_loss: 6062.1821 - val_r_squared: -inf - val_rmse: 77.5348
# Epoch 114/500
# 25/25 [==============================] - 0s 665us/step - loss: 5888.1001 - r_squared: 0.9422 - rmse: 76.8046 - val_loss: 5898.2227 - val_r_squared: -inf - val_rmse: 77.3666
# Epoch 115/500
# 25/25 [==============================] - 0s 695us/step - loss: 5718.5122 - r_squared: 0.9425 - rmse: 76.1942 - val_loss: 5850.4497 - val_r_squared: -inf - val_rmse: 76.7396
# Epoch 116/500
# 25/25 [==============================] - 0s 676us/step - loss: 5895.3809 - r_squared: 0.9444 - rmse: 76.0681 - val_loss: 5617.4604 - val_r_squared: -inf - val_rmse: 75.4183
# Epoch 117/500
# 25/25 [==============================] - 0s 719us/step - loss: 5951.8750 - r_squared: 0.9438 - rmse: 75.5195 - val_loss: 5730.5161 - val_r_squared: -inf - val_rmse: 76.9537
# Epoch 118/500
# 25/25 [==============================] - 0s 656us/step - loss: 5658.0542 - r_squared: 0.9456 - rmse: 74.9409 - val_loss: 7100.4233 - val_r_squared: -inf - val_rmse: 86.7400
# Epoch 119/500
# 25/25 [==============================] - 0s 852us/step - loss: 5791.5166 - r_squared: 0.9441 - rmse: 76.5498 - val_loss: 5570.2251 - val_r_squared: -inf - val_rmse: 75.5017
# Epoch 120/500
# 25/25 [==============================] - 0s 697us/step - loss: 5678.8506 - r_squared: 0.9469 - rmse: 74.5603 - val_loss: 5629.6704 - val_r_squared: -inf - val_rmse: 75.1688
# Epoch 121/500
# 25/25 [==============================] - 0s 643us/step - loss: 5753.2852 - r_squared: 0.9420 - rmse: 76.8814 - val_loss: 5879.7676 - val_r_squared: -inf - val_rmse: 77.9865
# Epoch 122/500
# 25/25 [==============================] - 0s 711us/step - loss: 5719.2368 - r_squared: 0.9458 - rmse: 75.2387 - val_loss: 5321.4907 - val_r_squared: -inf - val_rmse: 73.2905
# Epoch 123/500
# 25/25 [==============================] - 0s 666us/step - loss: 5447.4399 - r_squared: 0.9488 - rmse: 72.8277 - val_loss: 5770.8545 - val_r_squared: -inf - val_rmse: 75.8759
# Epoch 124/500
# 25/25 [==============================] - 0s 730us/step - loss: 5579.3789 - r_squared: 0.9452 - rmse: 74.9169 - val_loss: 5971.9624 - val_r_squared: -inf - val_rmse: 79.4263
# Epoch 125/500
# 25/25 [==============================] - 0s 665us/step - loss: 5660.4604 - r_squared: 0.9455 - rmse: 74.7986 - val_loss: 5615.5493 - val_r_squared: -inf - val_rmse: 75.1929
# Epoch 126/500
# 25/25 [==============================] - 0s 772us/step - loss: 5552.9434 - r_squared: 0.9472 - rmse: 73.9768 - val_loss: 5496.9458 - val_r_squared: -inf - val_rmse: 76.2405
# Epoch 127/500
# 25/25 [==============================] - 0s 751us/step - loss: 5277.5347 - r_squared: 0.9496 - rmse: 72.0849 - val_loss: 5079.7725 - val_r_squared: -inf - val_rmse: 72.1320
# Epoch 128/500
# 25/25 [==============================] - 0s 789us/step - loss: 5987.0767 - r_squared: 0.9433 - rmse: 75.9953 - val_loss: 5032.3291 - val_r_squared: -inf - val_rmse: 71.8326
# Epoch 129/500
# 25/25 [==============================] - 0s 765us/step - loss: 5455.0078 - r_squared: 0.9483 - rmse: 72.2940 - val_loss: 5366.4282 - val_r_squared: -inf - val_rmse: 75.2269
# Epoch 130/500
# 25/25 [==============================] - 0s 729us/step - loss: 5262.2681 - r_squared: 0.9494 - rmse: 72.0264 - val_loss: 5206.6255 - val_r_squared: -inf - val_rmse: 73.5119
# Epoch 131/500
# 25/25 [==============================] - 0s 691us/step - loss: 5551.1675 - r_squared: 0.9476 - rmse: 73.4162 - val_loss: 5745.5122 - val_r_squared: -inf - val_rmse: 78.2843
# Epoch 132/500
# 25/25 [==============================] - 0s 654us/step - loss: 5484.5825 - r_squared: 0.9476 - rmse: 73.6696 - val_loss: 5063.3286 - val_r_squared: -inf - val_rmse: 71.3210
# Epoch 133/500
# 25/25 [==============================] - 0s 718us/step - loss: 5348.5820 - r_squared: 0.9495 - rmse: 71.6539 - val_loss: 6047.9150 - val_r_squared: -inf - val_rmse: 80.3135
# Epoch 134/500
# 25/25 [==============================] - 0s 665us/step - loss: 5343.6787 - r_squared: 0.9485 - rmse: 71.7944 - val_loss: 4995.3032 - val_r_squared: -inf - val_rmse: 71.8771
# Epoch 135/500
# 25/25 [==============================] - 0s 718us/step - loss: 5207.1680 - r_squared: 0.9506 - rmse: 71.4313 - val_loss: 4813.2080 - val_r_squared: -inf - val_rmse: 70.1573
# Epoch 136/500
# 25/25 [==============================] - 0s 663us/step - loss: 5919.9292 - r_squared: 0.9441 - rmse: 75.8794 - val_loss: 5929.6479 - val_r_squared: -inf - val_rmse: 79.8761
# Epoch 137/500
# 25/25 [==============================] - 0s 700us/step - loss: 5424.5103 - r_squared: 0.9448 - rmse: 73.3637 - val_loss: 4884.2979 - val_r_squared: -inf - val_rmse: 70.6598
# Epoch 138/500
# 25/25 [==============================] - 0s 704us/step - loss: 5463.6069 - r_squared: 0.9434 - rmse: 74.0981 - val_loss: 6361.4004 - val_r_squared: -inf - val_rmse: 83.4162
# Epoch 139/500
# 25/25 [==============================] - 0s 727us/step - loss: 5346.7222 - r_squared: 0.9481 - rmse: 71.8895 - val_loss: 4748.8364 - val_r_squared: -inf - val_rmse: 70.8087
# Epoch 140/500
# 25/25 [==============================] - 0s 644us/step - loss: 4953.2290 - r_squared: 0.9517 - rmse: 69.4972 - val_loss: 4721.5918 - val_r_squared: -inf - val_rmse: 70.4154
# Epoch 141/500
# 25/25 [==============================] - 0s 688us/step - loss: 5064.3208 - r_squared: 0.9515 - rmse: 70.0516 - val_loss: 5099.3662 - val_r_squared: -inf - val_rmse: 73.9920
# Epoch 142/500
# 25/25 [==============================] - 0s 655us/step - loss: 5364.4185 - r_squared: 0.9466 - rmse: 71.4608 - val_loss: 6936.1265 - val_r_squared: -inf - val_rmse: 84.7988
# Epoch 143/500
# 25/25 [==============================] - 0s 701us/step - loss: 5906.2642 - r_squared: 0.9419 - rmse: 75.8208 - val_loss: 5063.4297 - val_r_squared: -inf - val_rmse: 73.8304
# Epoch 144/500
# 25/25 [==============================] - 0s 680us/step - loss: 4964.4351 - r_squared: 0.9526 - rmse: 69.8140 - val_loss: 4667.7285 - val_r_squared: -inf - val_rmse: 69.9429
# Epoch 145/500
# 25/25 [==============================] - 0s 715us/step - loss: 4964.2993 - r_squared: 0.9524 - rmse: 69.7343 - val_loss: 5510.7969 - val_r_squared: -inf - val_rmse: 77.4244
# Epoch 146/500
# 25/25 [==============================] - 0s 678us/step - loss: 5106.7378 - r_squared: 0.9515 - rmse: 70.6455 - val_loss: 4491.1768 - val_r_squared: -inf - val_rmse: 67.9258
# Epoch 147/500
# 25/25 [==============================] - 0s 701us/step - loss: 4858.8306 - r_squared: 0.9534 - rmse: 70.0760 - val_loss: 4680.6465 - val_r_squared: -inf - val_rmse: 68.9658
# Epoch 148/500
# 25/25 [==============================] - 0s 697us/step - loss: 5098.3882 - r_squared: 0.9510 - rmse: 72.0411 - val_loss: 4400.0503 - val_r_squared: -inf - val_rmse: 67.5900
# Epoch 149/500
# 25/25 [==============================] - 0s 688us/step - loss: 5228.8896 - r_squared: 0.9505 - rmse: 71.5762 - val_loss: 5898.6362 - val_r_squared: -inf - val_rmse: 79.8848
# Epoch 150/500
# 25/25 [==============================] - 0s 685us/step - loss: 4811.2354 - r_squared: 0.9544 - rmse: 68.6100 - val_loss: 4367.9326 - val_r_squared: -inf - val_rmse: 66.9688
# Epoch 151/500
# 25/25 [==============================] - 0s 713us/step - loss: 4997.0547 - r_squared: 0.9525 - rmse: 69.9344 - val_loss: 4616.4565 - val_r_squared: -inf - val_rmse: 69.5605
# Epoch 152/500
# 25/25 [==============================] - 0s 655us/step - loss: 4790.3477 - r_squared: 0.9546 - rmse: 68.6826 - val_loss: 4369.5718 - val_r_squared: -inf - val_rmse: 66.6974
# Epoch 153/500
# 25/25 [==============================] - 0s 709us/step - loss: 5123.2471 - r_squared: 0.9520 - rmse: 70.8859 - val_loss: 5195.2852 - val_r_squared: -inf - val_rmse: 74.6388
# Epoch 154/500
# 25/25 [==============================] - 0s 658us/step - loss: 4832.2354 - r_squared: 0.9531 - rmse: 69.7591 - val_loss: 4486.7031 - val_r_squared: -inf - val_rmse: 68.5570
# Epoch 155/500
# 25/25 [==============================] - 0s 701us/step - loss: 4667.0347 - r_squared: 0.9552 - rmse: 68.1361 - val_loss: 4397.9443 - val_r_squared: -inf - val_rmse: 67.6213
# Epoch 156/500
# 25/25 [==============================] - 0s 674us/step - loss: 4720.4805 - r_squared: 0.9553 - rmse: 67.7569 - val_loss: 5240.2651 - val_r_squared: -inf - val_rmse: 75.1463
# Epoch 157/500
# 25/25 [==============================] - 0s 690us/step - loss: 4850.7349 - r_squared: 0.9534 - rmse: 69.1193 - val_loss: 4323.8716 - val_r_squared: -inf - val_rmse: 66.9245
# Epoch 158/500
# 25/25 [==============================] - 0s 672us/step - loss: 4671.4082 - r_squared: 0.9543 - rmse: 68.4336 - val_loss: 4793.1558 - val_r_squared: -inf - val_rmse: 71.4623
# Epoch 159/500
# 25/25 [==============================] - 0s 764us/step - loss: 4841.4976 - r_squared: 0.9543 - rmse: 68.7796 - val_loss: 4261.5161 - val_r_squared: -inf - val_rmse: 66.2354
# Epoch 160/500
# 25/25 [==============================] - 0s 656us/step - loss: 4716.7847 - r_squared: 0.9553 - rmse: 68.0734 - val_loss: 4319.0566 - val_r_squared: -inf - val_rmse: 66.0957
# Epoch 161/500
# 25/25 [==============================] - 0s 701us/step - loss: 5062.1455 - r_squared: 0.9517 - rmse: 69.8675 - val_loss: 4736.8115 - val_r_squared: -inf - val_rmse: 71.3651
# Epoch 162/500
# 25/25 [==============================] - 0s 663us/step - loss: 4704.8442 - r_squared: 0.9547 - rmse: 66.7794 - val_loss: 4352.0845 - val_r_squared: -inf - val_rmse: 67.5334
# Epoch 163/500
# 25/25 [==============================] - 0s 703us/step - loss: 4731.3271 - r_squared: 0.9553 - rmse: 67.4903 - val_loss: 4738.5269 - val_r_squared: -inf - val_rmse: 71.1120
# Epoch 164/500
# 25/25 [==============================] - 0s 671us/step - loss: 4836.1714 - r_squared: 0.9533 - rmse: 68.8029 - val_loss: 4300.4321 - val_r_squared: -inf - val_rmse: 66.9217
# Epoch 165/500
# 25/25 [==============================] - 0s 701us/step - loss: 5319.6982 - r_squared: 0.9489 - rmse: 72.7639 - val_loss: 4488.4980 - val_r_squared: -inf - val_rmse: 67.3017
# Epoch 166/500
# 25/25 [==============================] - 0s 666us/step - loss: 5715.7847 - r_squared: 0.9452 - rmse: 74.1030 - val_loss: 4747.7603 - val_r_squared: -inf - val_rmse: 70.5068
# Epoch 167/500
# 25/25 [==============================] - 0s 718us/step - loss: 4631.4692 - r_squared: 0.9552 - rmse: 66.9579 - val_loss: 4399.3823 - val_r_squared: -inf - val_rmse: 67.7356
# Epoch 168/500
# 25/25 [==============================] - 0s 660us/step - loss: 4695.9414 - r_squared: 0.9554 - rmse: 68.1672 - val_loss: 4893.5669 - val_r_squared: -inf - val_rmse: 72.3400
# Epoch 169/500
# 25/25 [==============================] - 0s 706us/step - loss: 4571.9927 - r_squared: 0.9558 - rmse: 67.2273 - val_loss: 4597.4043 - val_r_squared: -inf - val_rmse: 69.6566
# Epoch 170/500
# 25/25 [==============================] - 0s 664us/step - loss: 4721.0557 - r_squared: 0.9545 - rmse: 68.2024 - val_loss: 4535.8657 - val_r_squared: -inf - val_rmse: 67.0873
# Epoch 171/500
# 25/25 [==============================] - 0s 678us/step - loss: 4936.5347 - r_squared: 0.9505 - rmse: 69.1327 - val_loss: 4410.0020 - val_r_squared: -inf - val_rmse: 68.0198
# Epoch 172/500
# 25/25 [==============================] - 0s 654us/step - loss: 5117.2979 - r_squared: 0.9510 - rmse: 70.8603 - val_loss: 4353.1050 - val_r_squared: -inf - val_rmse: 67.6434
# Epoch 173/500
# 25/25 [==============================] - 0s 746us/step - loss: 4622.5820 - r_squared: 0.9552 - rmse: 66.6988 - val_loss: 4169.1353 - val_r_squared: -inf - val_rmse: 65.3217
# Epoch 174/500
# 25/25 [==============================] - 0s 661us/step - loss: 4752.1235 - r_squared: 0.9554 - rmse: 67.6114 - val_loss: 4423.1782 - val_r_squared: -inf - val_rmse: 66.8696
# Epoch 175/500
# 25/25 [==============================] - 0s 688us/step - loss: 4768.9448 - r_squared: 0.9536 - rmse: 68.0735 - val_loss: 4187.1392 - val_r_squared: -inf - val_rmse: 64.8172
# Epoch 176/500
# 25/25 [==============================] - 0s 668us/step - loss: 4540.0059 - r_squared: 0.9578 - rmse: 65.6704 - val_loss: 5319.2715 - val_r_squared: -inf - val_rmse: 75.5902
# Epoch 177/500
# 25/25 [==============================] - 0s 726us/step - loss: 4864.0454 - r_squared: 0.9534 - rmse: 69.1562 - val_loss: 4011.6960 - val_r_squared: -inf - val_rmse: 63.9841
# Epoch 178/500
# 25/25 [==============================] - 0s 660us/step - loss: 4551.0386 - r_squared: 0.9565 - rmse: 67.1773 - val_loss: 4142.4316 - val_r_squared: -inf - val_rmse: 64.9850
# Epoch 179/500
# 25/25 [==============================] - 0s 693us/step - loss: 4820.0132 - r_squared: 0.9544 - rmse: 68.6629 - val_loss: 4047.6321 - val_r_squared: -inf - val_rmse: 64.0674
# Epoch 180/500
# 25/25 [==============================] - 0s 675us/step - loss: 5077.4810 - r_squared: 0.9526 - rmse: 69.8433 - val_loss: 4305.2056 - val_r_squared: -inf - val_rmse: 67.1518
# Epoch 181/500
# 25/25 [==============================] - 0s 722us/step - loss: 4747.4141 - r_squared: 0.9541 - rmse: 68.5960 - val_loss: 4014.0645 - val_r_squared: -inf - val_rmse: 64.0728
# Epoch 182/500
# 25/25 [==============================] - 0s 671us/step - loss: 4577.5723 - r_squared: 0.9543 - rmse: 67.0630 - val_loss: 4317.5205 - val_r_squared: -inf - val_rmse: 66.0469
# Epoch 183/500
# 25/25 [==============================] - 0s 712us/step - loss: 4968.3394 - r_squared: 0.9538 - rmse: 68.6419 - val_loss: 6315.2959 - val_r_squared: -inf - val_rmse: 83.5680
# Epoch 184/500
# 25/25 [==============================] - 0s 669us/step - loss: 5247.3501 - r_squared: 0.9511 - rmse: 70.8930 - val_loss: 4036.0686 - val_r_squared: -inf - val_rmse: 64.0345
# Epoch 185/500
# 25/25 [==============================] - 0s 731us/step - loss: 5181.2065 - r_squared: 0.9510 - rmse: 70.3544 - val_loss: 3979.3289 - val_r_squared: -inf - val_rmse: 63.5761
# Epoch 186/500
# 25/25 [==============================] - 0s 657us/step - loss: 5210.6851 - r_squared: 0.9502 - rmse: 70.7919 - val_loss: 5297.8535 - val_r_squared: -inf - val_rmse: 75.9955
# Epoch 187/500
# 25/25 [==============================] - 0s 727us/step - loss: 5150.6157 - r_squared: 0.9499 - rmse: 71.2172 - val_loss: 4004.4233 - val_r_squared: -inf - val_rmse: 64.4970
# Epoch 188/500
# 25/25 [==============================] - 0s 658us/step - loss: 4651.6860 - r_squared: 0.9549 - rmse: 67.3532 - val_loss: 4038.7158 - val_r_squared: -inf - val_rmse: 64.1953
# Epoch 189/500
# 25/25 [==============================] - 0s 705us/step - loss: 4569.6167 - r_squared: 0.9554 - rmse: 67.7373 - val_loss: 4007.0334 - val_r_squared: -inf - val_rmse: 64.2212
# Epoch 190/500
# 25/25 [==============================] - 0s 671us/step - loss: 4390.2773 - r_squared: 0.9575 - rmse: 65.5291 - val_loss: 3973.5808 - val_r_squared: -inf - val_rmse: 63.6699
# Epoch 191/500
# 25/25 [==============================] - 0s 746us/step - loss: 4823.4717 - r_squared: 0.9531 - rmse: 69.0386 - val_loss: 4016.9224 - val_r_squared: -inf - val_rmse: 64.5340
# Epoch 192/500
# 25/25 [==============================] - 0s 688us/step - loss: 5421.5703 - r_squared: 0.9466 - rmse: 73.5415 - val_loss: 4442.6450 - val_r_squared: -inf - val_rmse: 66.7165
# Epoch 193/500
# 25/25 [==============================] - 0s 708us/step - loss: 4440.0576 - r_squared: 0.9578 - rmse: 65.8629 - val_loss: 3995.7812 - val_r_squared: -inf - val_rmse: 64.0358
# Epoch 194/500
# 25/25 [==============================] - 0s 674us/step - loss: 4399.1460 - r_squared: 0.9582 - rmse: 65.4615 - val_loss: 4160.3345 - val_r_squared: -inf - val_rmse: 65.7078
# Epoch 195/500
# 25/25 [==============================] - 0s 724us/step - loss: 4689.5850 - r_squared: 0.9551 - rmse: 68.0618 - val_loss: 3992.3398 - val_r_squared: -inf - val_rmse: 63.3759
# Epoch 196/500
# 25/25 [==============================] - 0s 670us/step - loss: 4780.0117 - r_squared: 0.9542 - rmse: 67.8937 - val_loss: 5256.6543 - val_r_squared: -inf - val_rmse: 75.4909
# Epoch 197/500
# 25/25 [==============================] - 0s 686us/step - loss: 5062.7075 - r_squared: 0.9528 - rmse: 69.1658 - val_loss: 4110.8638 - val_r_squared: -inf - val_rmse: 63.8882
# Epoch 198/500
# 25/25 [==============================] - 0s 660us/step - loss: 4764.6514 - r_squared: 0.9513 - rmse: 69.5375 - val_loss: 4187.9243 - val_r_squared: -inf - val_rmse: 65.1910
# Epoch 199/500
# 25/25 [==============================] - 0s 733us/step - loss: 5376.7300 - r_squared: 0.9488 - rmse: 72.5678 - val_loss: 3920.5920 - val_r_squared: -inf - val_rmse: 63.4462
# Epoch 200/500
# 25/25 [==============================] - 0s 661us/step - loss: 4945.8286 - r_squared: 0.9521 - rmse: 69.5327 - val_loss: 4160.4990 - val_r_squared: -inf - val_rmse: 64.7807
# Epoch 201/500
# 25/25 [==============================] - 0s 713us/step - loss: 4550.8662 - r_squared: 0.9572 - rmse: 66.3832 - val_loss: 4082.6084 - val_r_squared: -inf - val_rmse: 64.8655
# Epoch 202/500
# 25/25 [==============================] - 0s 646us/step - loss: 4389.8950 - r_squared: 0.9566 - rmse: 65.9352 - val_loss: 5429.6191 - val_r_squared: -inf - val_rmse: 76.8623
# Epoch 203/500
# 25/25 [==============================] - 0s 705us/step - loss: 4593.1162 - r_squared: 0.9559 - rmse: 67.1692 - val_loss: 3880.0400 - val_r_squared: -inf - val_rmse: 62.5221
# Epoch 204/500
# 25/25 [==============================] - 0s 672us/step - loss: 4629.3979 - r_squared: 0.9564 - rmse: 66.6626 - val_loss: 4087.9167 - val_r_squared: -inf - val_rmse: 65.2505
# Epoch 205/500
# 25/25 [==============================] - 0s 712us/step - loss: 4664.1689 - r_squared: 0.9558 - rmse: 67.7906 - val_loss: 3980.9575 - val_r_squared: -inf - val_rmse: 63.5642
# Epoch 206/500
# 25/25 [==============================] - 0s 643us/step - loss: 4895.6177 - r_squared: 0.9510 - rmse: 69.5532 - val_loss: 5682.0308 - val_r_squared: -inf - val_rmse: 78.4327
# Epoch 207/500
# 25/25 [==============================] - 0s 715us/step - loss: 4786.3247 - r_squared: 0.9528 - rmse: 68.4074 - val_loss: 4000.6782 - val_r_squared: -inf - val_rmse: 63.4794
# Epoch 208/500
# 25/25 [==============================] - 0s 664us/step - loss: 4401.5718 - r_squared: 0.9583 - rmse: 66.0195 - val_loss: 3891.4258 - val_r_squared: -inf - val_rmse: 62.7812
# Epoch 209/500
# 25/25 [==============================] - 0s 728us/step - loss: 4497.4404 - r_squared: 0.9571 - rmse: 65.8674 - val_loss: 3913.1177 - val_r_squared: -inf - val_rmse: 62.6791
# Epoch 210/500
# 25/25 [==============================] - 0s 658us/step - loss: 5119.9536 - r_squared: 0.9516 - rmse: 68.7621 - val_loss: 5730.4219 - val_r_squared: -inf - val_rmse: 78.7079
# Epoch 211/500
# 25/25 [==============================] - 0s 713us/step - loss: 4655.9741 - r_squared: 0.9533 - rmse: 68.3409 - val_loss: 3929.1716 - val_r_squared: -inf - val_rmse: 63.8814
# Epoch 212/500
# 25/25 [==============================] - 0s 670us/step - loss: 4399.2573 - r_squared: 0.9592 - rmse: 64.8899 - val_loss: 4228.8818 - val_r_squared: -inf - val_rmse: 66.6126
# Epoch 213/500
# 25/25 [==============================] - 0s 707us/step - loss: 4728.9531 - r_squared: 0.9551 - rmse: 67.8267 - val_loss: 4115.8447 - val_r_squared: -inf - val_rmse: 64.2804
# Epoch 214/500
# 25/25 [==============================] - 0s 667us/step - loss: 4584.2271 - r_squared: 0.9574 - rmse: 66.1252 - val_loss: 3931.6113 - val_r_squared: -inf - val_rmse: 62.7887
# Epoch 215/500
# 25/25 [==============================] - 0s 717us/step - loss: 4479.1807 - r_squared: 0.9574 - rmse: 66.5797 - val_loss: 4084.9062 - val_r_squared: -inf - val_rmse: 64.2812
# Epoch 216/500
# 25/25 [==============================] - 0s 672us/step - loss: 4853.4253 - r_squared: 0.9545 - rmse: 68.4364 - val_loss: 3914.4761 - val_r_squared: -inf - val_rmse: 63.6690
# Epoch 217/500
# 25/25 [==============================] - 0s 699us/step - loss: 4366.4106 - r_squared: 0.9584 - rmse: 65.6960 - val_loss: 3894.4187 - val_r_squared: -inf - val_rmse: 63.4898
# Epoch 218/500
# 25/25 [==============================] - 0s 662us/step - loss: 4867.0483 - r_squared: 0.9546 - rmse: 67.8577 - val_loss: 4402.7598 - val_r_squared: -inf - val_rmse: 68.4763
# Epoch 219/500
# 25/25 [==============================] - 0s 738us/step - loss: 4420.8457 - r_squared: 0.9586 - rmse: 65.3781 - val_loss: 4312.1982 - val_r_squared: -inf - val_rmse: 67.6245
# Epoch 220/500
# 25/25 [==============================] - 0s 664us/step - loss: 4372.4692 - r_squared: 0.9574 - rmse: 65.9725 - val_loss: 4130.3022 - val_r_squared: -inf - val_rmse: 65.7803
# Epoch 221/500
# 25/25 [==============================] - 0s 705us/step - loss: 4571.0874 - r_squared: 0.9570 - rmse: 65.9349 - val_loss: 4032.6377 - val_r_squared: -inf - val_rmse: 65.0142
# Epoch 222/500
# 25/25 [==============================] - 0s 656us/step - loss: 4589.0068 - r_squared: 0.9567 - rmse: 66.6224 - val_loss: 4180.7686 - val_r_squared: -inf - val_rmse: 66.6016
# Epoch 223/500
# 25/25 [==============================] - 0s 707us/step - loss: 4881.4746 - r_squared: 0.9538 - rmse: 68.7403 - val_loss: 5593.9502 - val_r_squared: -inf - val_rmse: 78.4489
# Epoch 224/500
# 25/25 [==============================] - 0s 664us/step - loss: 5099.5923 - r_squared: 0.9514 - rmse: 70.3978 - val_loss: 4585.8628 - val_r_squared: -inf - val_rmse: 70.2712
# Epoch 225/500
# 25/25 [==============================] - 0s 703us/step - loss: 4924.9478 - r_squared: 0.9510 - rmse: 69.9965 - val_loss: 4961.5693 - val_r_squared: -inf - val_rmse: 70.3673
# Epoch 226/500
# 25/25 [==============================] - 0s 656us/step - loss: 4882.4482 - r_squared: 0.9534 - rmse: 68.5039 - val_loss: 4207.8447 - val_r_squared: -inf - val_rmse: 66.8017
# Epoch 227/500
# 25/25 [==============================] - 0s 707us/step - loss: 4429.8735 - r_squared: 0.9576 - rmse: 66.4412 - val_loss: 4901.1372 - val_r_squared: -inf - val_rmse: 72.4723
# Epoch 228/500
# 25/25 [==============================] - 0s 676us/step - loss: 4329.9868 - r_squared: 0.9564 - rmse: 65.5746 - val_loss: 4504.3247 - val_r_squared: -inf - val_rmse: 69.5285
# Epoch 229/500
# 25/25 [==============================] - 0s 742us/step - loss: 4322.8896 - r_squared: 0.9587 - rmse: 64.5601 - val_loss: 3869.3850 - val_r_squared: -inf - val_rmse: 62.7218
# Epoch 230/500
# 25/25 [==============================] - 0s 657us/step - loss: 4337.2100 - r_squared: 0.9586 - rmse: 65.3157 - val_loss: 4353.0747 - val_r_squared: -inf - val_rmse: 68.1640
# Epoch 231/500
# 25/25 [==============================] - 0s 714us/step - loss: 4372.8979 - r_squared: 0.9578 - rmse: 65.7306 - val_loss: 3962.7136 - val_r_squared: -inf - val_rmse: 64.3551
# Epoch 232/500
# 25/25 [==============================] - 0s 674us/step - loss: 4436.5308 - r_squared: 0.9589 - rmse: 65.1854 - val_loss: 4544.0410 - val_r_squared: -inf - val_rmse: 68.0385
# Epoch 233/500
# 25/25 [==============================] - 0s 718us/step - loss: 4478.1504 - r_squared: 0.9582 - rmse: 65.7745 - val_loss: 3851.4014 - val_r_squared: -inf - val_rmse: 63.2726
# Epoch 234/500
# 25/25 [==============================] - 0s 684us/step - loss: 4577.5898 - r_squared: 0.9576 - rmse: 65.6879 - val_loss: 4728.9712 - val_r_squared: -inf - val_rmse: 71.6775
# Epoch 235/500
# 25/25 [==============================] - 0s 715us/step - loss: 4430.8140 - r_squared: 0.9578 - rmse: 66.1156 - val_loss: 3857.7207 - val_r_squared: -inf - val_rmse: 62.7115
# Epoch 236/500
# 25/25 [==============================] - 0s 678us/step - loss: 4457.6362 - r_squared: 0.9573 - rmse: 65.9482 - val_loss: 3820.9385 - val_r_squared: -inf - val_rmse: 63.0934
# Epoch 237/500
# 25/25 [==============================] - 0s 706us/step - loss: 4432.5366 - r_squared: 0.9590 - rmse: 65.2917 - val_loss: 3829.8853 - val_r_squared: -inf - val_rmse: 62.8123
# Epoch 238/500
# 25/25 [==============================] - 0s 657us/step - loss: 4348.2842 - r_squared: 0.9588 - rmse: 64.3911 - val_loss: 3834.9265 - val_r_squared: -inf - val_rmse: 62.6162
# Epoch 239/500
# 25/25 [==============================] - 0s 715us/step - loss: 4883.4912 - r_squared: 0.9542 - rmse: 68.6750 - val_loss: 4249.4473 - val_r_squared: -inf - val_rmse: 67.1753
# Epoch 240/500
# 25/25 [==============================] - 0s 661us/step - loss: 4920.9175 - r_squared: 0.9483 - rmse: 69.8648 - val_loss: 3792.1868 - val_r_squared: -inf - val_rmse: 62.7056
# Epoch 241/500
# 25/25 [==============================] - 0s 694us/step - loss: 4415.3286 - r_squared: 0.9575 - rmse: 65.8354 - val_loss: 4094.3044 - val_r_squared: -inf - val_rmse: 65.8859
# Epoch 242/500
# 25/25 [==============================] - 0s 679us/step - loss: 4432.4390 - r_squared: 0.9518 - rmse: 66.6472 - val_loss: 4282.8594 - val_r_squared: -inf - val_rmse: 67.4703
# Epoch 243/500
# 25/25 [==============================] - 0s 729us/step - loss: 4417.3315 - r_squared: 0.9578 - rmse: 65.7648 - val_loss: 3926.1096 - val_r_squared: -inf - val_rmse: 63.9998
# Epoch 244/500
# 25/25 [==============================] - 0s 667us/step - loss: 5009.9443 - r_squared: 0.9529 - rmse: 69.8439 - val_loss: 3774.9390 - val_r_squared: -inf - val_rmse: 62.5839
# Epoch 245/500
# 25/25 [==============================] - 0s 694us/step - loss: 4277.7598 - r_squared: 0.9597 - rmse: 64.0746 - val_loss: 3926.8398 - val_r_squared: -inf - val_rmse: 63.9916
# Epoch 246/500
# 25/25 [==============================] - 0s 657us/step - loss: 4304.9556 - r_squared: 0.9593 - rmse: 64.9917 - val_loss: 4006.6428 - val_r_squared: -inf - val_rmse: 64.9875
# Epoch 247/500
# 25/25 [==============================] - 0s 735us/step - loss: 4386.1343 - r_squared: 0.9578 - rmse: 64.8389 - val_loss: 5074.1743 - val_r_squared: -inf - val_rmse: 74.2730
# Epoch 248/500
# 25/25 [==============================] - 0s 662us/step - loss: 4510.1143 - r_squared: 0.9562 - rmse: 66.2125 - val_loss: 4087.6814 - val_r_squared: -inf - val_rmse: 65.9533
# Epoch 249/500
# 25/25 [==============================] - 0s 681us/step - loss: 4464.8184 - r_squared: 0.9567 - rmse: 66.8818 - val_loss: 4912.7402 - val_r_squared: -inf - val_rmse: 73.1249
# Epoch 250/500
# 25/25 [==============================] - 0s 662us/step - loss: 4792.9214 - r_squared: 0.9545 - rmse: 67.5337 - val_loss: 3848.8953 - val_r_squared: -inf - val_rmse: 63.4576
# Epoch 251/500
# 25/25 [==============================] - 0s 690us/step - loss: 4213.5874 - r_squared: 0.9604 - rmse: 64.1034 - val_loss: 4608.2188 - val_r_squared: -inf - val_rmse: 70.4941
# Epoch 252/500
# 25/25 [==============================] - 0s 692us/step - loss: 4272.1616 - r_squared: 0.9592 - rmse: 65.0093 - val_loss: 3852.4875 - val_r_squared: -inf - val_rmse: 63.4024
# Epoch 253/500
# 25/25 [==============================] - 0s 694us/step - loss: 4441.6226 - r_squared: 0.9572 - rmse: 66.2176 - val_loss: 3911.4785 - val_r_squared: -inf - val_rmse: 63.1759
# Epoch 254/500
# 25/25 [==============================] - 0s 657us/step - loss: 4597.1982 - r_squared: 0.9548 - rmse: 66.5439 - val_loss: 4049.0574 - val_r_squared: -inf - val_rmse: 65.6386
# Epoch 255/500
# 25/25 [==============================] - 0s 684us/step - loss: 4345.5005 - r_squared: 0.9572 - rmse: 66.1754 - val_loss: 3884.1365 - val_r_squared: -inf - val_rmse: 63.7575
# Epoch 256/500
# ...
# Epoch 475/500
# 25/25 [==============================] - 0s 655us/step - loss: 4054.7256 - r_squared: 0.9624 - rmse: 62.6681 - val_loss: 4366.5093 - val_r_squared: -inf - val_rmse: 70.7479
# Epoch 476/500
# 25/25 [==============================] - 0s 713us/step - loss: 4201.1528 - r_squared: 0.9597 - rmse: 63.3380 - val_loss: 3631.7314 - val_r_squared: -inf - val_rmse: 64.1335
# Epoch 477/500
# 25/25 [==============================] - 0s 667us/step - loss: 3854.0256 - r_squared: 0.9626 - rmse: 61.2058 - val_loss: 4007.3491 - val_r_squared: -inf - val_rmse: 67.4567
# Epoch 478/500
# 25/25 [==============================] - 0s 703us/step - loss: 3966.5054 - r_squared: 0.9625 - rmse: 61.9151 - val_loss: 3982.0623 - val_r_squared: -inf - val_rmse: 67.4206
# Epoch 479/500
# 25/25 [==============================] - 0s 643us/step - loss: 3989.2705 - r_squared: 0.9617 - rmse: 62.2854 - val_loss: 3515.2344 - val_r_squared: -inf - val_rmse: 62.6861
# Epoch 480/500
# 25/25 [==============================] - 0s 722us/step - loss: 3936.0801 - r_squared: 0.9633 - rmse: 61.3615 - val_loss: 3489.0178 - val_r_squared: -inf - val_rmse: 62.2272
# Epoch 481/500
# 25/25 [==============================] - 0s 662us/step - loss: 3952.3530 - r_squared: 0.9638 - rmse: 61.3724 - val_loss: 3493.0383 - val_r_squared: -inf - val_rmse: 62.5529
# Epoch 482/500
# 25/25 [==============================] - 0s 687us/step - loss: 4114.9429 - r_squared: 0.9614 - rmse: 63.8528 - val_loss: 4163.4331 - val_r_squared: -inf - val_rmse: 69.0095
# Epoch 483/500
# 25/25 [==============================] - 0s 671us/step - loss: 5151.9072 - r_squared: 0.9517 - rmse: 69.7888 - val_loss: 3576.5364 - val_r_squared: -inf - val_rmse: 63.2068
# Epoch 484/500
# 25/25 [==============================] - 0s 707us/step - loss: 3863.4670 - r_squared: 0.9637 - rmse: 61.0470 - val_loss: 3734.6323 - val_r_squared: -inf - val_rmse: 65.1939
# Epoch 485/500
# 25/25 [==============================] - 0s 661us/step - loss: 3878.2822 - r_squared: 0.9625 - rmse: 61.6249 - val_loss: 3526.1819 - val_r_squared: -inf - val_rmse: 62.9904
# Epoch 486/500
# 25/25 [==============================] - 0s 698us/step - loss: 4199.3857 - r_squared: 0.9601 - rmse: 64.5822 - val_loss: 3532.8516 - val_r_squared: -inf - val_rmse: 63.0970
# Epoch 487/500
# 25/25 [==============================] - 0s 664us/step - loss: 3861.6560 - r_squared: 0.9620 - rmse: 61.8512 - val_loss: 3513.8345 - val_r_squared: -inf - val_rmse: 62.6816
# Epoch 488/500
# 25/25 [==============================] - 0s 694us/step - loss: 3885.4768 - r_squared: 0.9622 - rmse: 62.3746 - val_loss: 3935.0896 - val_r_squared: -inf - val_rmse: 65.9038
# Epoch 489/500
# 25/25 [==============================] - 0s 675us/step - loss: 4155.2212 - r_squared: 0.9600 - rmse: 62.5868 - val_loss: 3860.5586 - val_r_squared: -inf - val_rmse: 66.2285
# Epoch 490/500
# 25/25 [==============================] - 0s 661us/step - loss: 3841.9104 - r_squared: 0.9629 - rmse: 61.2935 - val_loss: 5192.0547 - val_r_squared: -inf - val_rmse: 77.4353
# Epoch 491/500
# 25/25 [==============================] - 0s 662us/step - loss: 4561.0957 - r_squared: 0.9567 - rmse: 66.8898 - val_loss: 3610.6494 - val_r_squared: -inf - val_rmse: 63.4545
# Epoch 492/500
# 25/25 [==============================] - 0s 718us/step - loss: 3837.5952 - r_squared: 0.9635 - rmse: 61.2641 - val_loss: 3466.8972 - val_r_squared: -inf - val_rmse: 62.3525
# Epoch 493/500
# 25/25 [==============================] - 0s 662us/step - loss: 4001.4365 - r_squared: 0.9623 - rmse: 62.0445 - val_loss: 3762.6897 - val_r_squared: -inf - val_rmse: 65.3681
# Epoch 494/500
# 25/25 [==============================] - 0s 689us/step - loss: 4009.8577 - r_squared: 0.9615 - rmse: 63.4836 - val_loss: 4134.5063 - val_r_squared: -inf - val_rmse: 68.5430
# Epoch 495/500
# 25/25 [==============================] - 0s 689us/step - loss: 3797.5525 - r_squared: 0.9604 - rmse: 61.0278 - val_loss: 4034.3904 - val_r_squared: -inf - val_rmse: 67.8066
# Early stopping occurred at epoch 494
# Restoring model weights from the end of the best epoch.
# 4/4 [==============================] - 0s 656us/step - loss: 2611.2493 - r_squared: 0.9690 - rmse: 51.8716
# Test Loss (MSE): 2611.249267578125
# Test Accuracy: 96.9046413898468
# Test RMSE: 51.871585845947266
# Epoch 1/200
# 25/25 [==============================] - 1s 9ms/step - loss: 5093.6064 - r_squared: 0.9527 - rmse: 68.9619 - val_loss: 3701.0017 - val_r_squared: -inf - val_rmse: 64.5873
# Epoch 2/200
# 25/25 [==============================] - 0s 1ms/step - loss: 3999.4622 - r_squared: 0.9630 - rmse: 61.5718 - val_loss: 4163.9585 - val_r_squared: -inf - val_rmse: 68.8459
# Epoch 3/200
# 25/25 [==============================] - 0s 1ms/step - loss: 4041.0742 - r_squared: 0.9608 - rmse: 63.4899 - val_loss: 3564.2112 - val_r_squared: -inf - val_rmse: 63.4266
# Epoch 4/200
# 25/25 [==============================] - 0s 933us/step - loss: 4003.4487 - r_squared: 0.9609 - rmse: 63.1838 - val_loss: 3644.4778 - val_r_squared: -inf - val_rmse: 63.7584
# Epoch 5/200
# 25/25 [==============================] - 0s 829us/step - loss: 4092.7476 - r_squared: 0.9566 - rmse: 64.7195 - val_loss: 4033.3181 - val_r_squared: -inf - val_rmse: 67.5958
# Epoch 6/200
# 25/25 [==============================] - 0s 865us/step - loss: 4090.6213 - r_squared: 0.9605 - rmse: 63.9797 - val_loss: 3490.0061 - val_r_squared: -inf - val_rmse: 62.1625
# Epoch 7/200
# 25/25 [==============================] - 0s 796us/step - loss: 4155.7954 - r_squared: 0.9606 - rmse: 63.1427 - val_loss: 4550.0649 - val_r_squared: -inf - val_rmse: 71.9245
# Epoch 8/200
# 25/25 [==============================] - 0s 839us/step - loss: 4320.4204 - r_squared: 0.9598 - rmse: 63.7710 - val_loss: 3755.7542 - val_r_squared: -inf - val_rmse: 65.1578
# Epoch 9/200
# 25/25 [==============================] - 0s 771us/step - loss: 4116.2974 - r_squared: 0.9604 - rmse: 63.9678 - val_loss: 4472.4980 - val_r_squared: -inf - val_rmse: 71.4372
# Epoch 10/200
# 25/25 [==============================] - 0s 818us/step - loss: 3822.7026 - r_squared: 0.9622 - rmse: 62.0289 - val_loss: 3521.5710 - val_r_squared: -inf - val_rmse: 62.7029
# Epoch 11/200
# 25/25 [==============================] - 0s 819us/step - loss: 3833.8757 - r_squared: 0.9631 - rmse: 60.9953 - val_loss: 3466.8391 - val_r_squared: -inf - val_rmse: 62.3573
# Epoch 12/200
# 25/25 [==============================] - 0s 814us/step - loss: 4261.4116 - r_squared: 0.9571 - rmse: 64.5641 - val_loss: 4224.6313 - val_r_squared: -inf - val_rmse: 69.3927
# Epoch 13/200
# 25/25 [==============================] - 0s 805us/step - loss: 3907.8877 - r_squared: 0.9619 - rmse: 61.4497 - val_loss: 3877.6584 - val_r_squared: -inf - val_rmse: 66.1558
# Epoch 14/200
# 25/25 [==============================] - 0s 757us/step - loss: 3899.0049 - r_squared: 0.9631 - rmse: 60.9091 - val_loss: 3552.8596 - val_r_squared: -inf - val_rmse: 62.8434
# Epoch 15/200
# 25/25 [==============================] - 0s 816us/step - loss: 4129.0327 - r_squared: 0.9613 - rmse: 62.5343 - val_loss: 3852.5737 - val_r_squared: -inf - val_rmse: 65.9413
# Epoch 16/200
# 25/25 [==============================] - 0s 781us/step - loss: 4083.4038 - r_squared: 0.9582 - rmse: 64.5989 - val_loss: 3639.8049 - val_r_squared: -inf - val_rmse: 63.9913
# Epoch 17/200
# 25/25 [==============================] - 0s 788us/step - loss: 3961.1775 - r_squared: 0.9619 - rmse: 61.2837 - val_loss: 3659.3276 - val_r_squared: -inf - val_rmse: 64.0017
# Epoch 18/200
# 25/25 [==============================] - 0s 779us/step - loss: 3939.8384 - r_squared: 0.9605 - rmse: 62.5422 - val_loss: 3877.8994 - val_r_squared: -inf - val_rmse: 66.1902
# Epoch 19/200
# 25/25 [==============================] - 0s 777us/step - loss: 4371.2969 - r_squared: 0.9584 - rmse: 65.0170 - val_loss: 3740.5354 - val_r_squared: -inf - val_rmse: 65.0907
# Epoch 20/200
# 25/25 [==============================] - 0s 807us/step - loss: 3952.2500 - r_squared: 0.9633 - rmse: 61.1468 - val_loss: 3625.5286 - val_r_squared: -inf - val_rmse: 63.9158
# Epoch 21/200
# 25/25 [==============================] - 0s 783us/step - loss: 3834.1177 - r_squared: 0.9629 - rmse: 60.7483 - val_loss: 5188.6846 - val_r_squared: -inf - val_rmse: 77.0358
# Epoch 22/200
# 25/25 [==============================] - 0s 806us/step - loss: 4899.6284 - r_squared: 0.9529 - rmse: 68.4397 - val_loss: 3637.8403 - val_r_squared: -inf - val_rmse: 63.5900
# Epoch 23/200
# 25/25 [==============================] - 0s 776us/step - loss: 3919.7693 - r_squared: 0.9631 - rmse: 61.7591 - val_loss: 3566.4600 - val_r_squared: -inf - val_rmse: 62.6254
# Epoch 24/200
# 25/25 [==============================] - 0s 762us/step - loss: 4060.8899 - r_squared: 0.9609 - rmse: 62.5135 - val_loss: 3799.7686 - val_r_squared: -inf - val_rmse: 65.2556
# Epoch 25/200
# 25/25 [==============================] - 0s 819us/step - loss: 3969.2703 - r_squared: 0.9548 - rmse: 63.2163 - val_loss: 3495.0420 - val_r_squared: -inf - val_rmse: 62.3980
# Epoch 26/200
# 25/25 [==============================] - 0s 785us/step - loss: 4566.6304 - r_squared: 0.9564 - rmse: 66.7141 - val_loss: 4205.7710 - val_r_squared: -inf - val_rmse: 69.1736
# Epoch 27/200
# 25/25 [==============================] - 0s 750us/step - loss: 4665.9795 - r_squared: 0.9539 - rmse: 68.1358 - val_loss: 3615.1643 - val_r_squared: -inf - val_rmse: 62.8663
# Epoch 28/200
# 25/25 [==============================] - 0s 812us/step - loss: 4014.3372 - r_squared: 0.9627 - rmse: 61.9032 - val_loss: 4119.3916 - val_r_squared: -inf - val_rmse: 68.2326
# Epoch 29/200
# 25/25 [==============================] - 0s 762us/step - loss: 3878.0498 - r_squared: 0.9634 - rmse: 61.4706 - val_loss: 3513.3547 - val_r_squared: -inf - val_rmse: 62.6849
# Epoch 30/200
# 25/25 [==============================] - 0s 803us/step - loss: 3851.4468 - r_squared: 0.9622 - rmse: 62.5609 - val_loss: 3505.7615 - val_r_squared: -inf - val_rmse: 62.6748
# Epoch 31/200
# 25/25 [==============================] - 0s 788us/step - loss: 3845.7756 - r_squared: 0.9638 - rmse: 60.0700 - val_loss: 3508.9419 - val_r_squared: -inf - val_rmse: 62.6679
# Epoch 32/200
# 25/25 [==============================] - 0s 814us/step - loss: 3930.6704 - r_squared: 0.9630 - rmse: 61.5576 - val_loss: 3592.2280 - val_r_squared: -inf - val_rmse: 63.5002
# Epoch 33/200
# 25/25 [==============================] - 0s 754us/step - loss: 3967.5288 - r_squared: 0.9601 - rmse: 61.0944 - val_loss: 4651.6665 - val_r_squared: -inf - val_rmse: 73.0042
# Epoch 34/200
# 25/25 [==============================] - 0s 793us/step - loss: 3907.1057 - r_squared: 0.9630 - rmse: 61.4912 - val_loss: 4000.0964 - val_r_squared: -inf - val_rmse: 67.4667
# Epoch 35/200
# 25/25 [==============================] - 0s 770us/step - loss: 3907.4595 - r_squared: 0.9628 - rmse: 61.7180 - val_loss: 4159.5005 - val_r_squared: -inf - val_rmse: 68.8654
# Epoch 36/200
# 25/25 [==============================] - 0s 772us/step - loss: 4099.2192 - r_squared: 0.9601 - rmse: 64.1069 - val_loss: 3760.0139 - val_r_squared: -inf - val_rmse: 64.5819
# Epoch 37/200
# 25/25 [==============================] - 0s 823us/step - loss: 4073.1399 - r_squared: 0.9608 - rmse: 64.3624 - val_loss: 3598.3049 - val_r_squared: -inf - val_rmse: 63.3651
# Epoch 38/200
# 25/25 [==============================] - 0s 796us/step - loss: 3929.3003 - r_squared: 0.9615 - rmse: 62.1751 - val_loss: 3518.3569 - val_r_squared: -inf - val_rmse: 63.2215
# Epoch 39/200
# 25/25 [==============================] - 0s 857us/step - loss: 3961.8013 - r_squared: 0.9622 - rmse: 61.6585 - val_loss: 4285.6880 - val_r_squared: -inf - val_rmse: 69.9725
# Epoch 40/200
# 25/25 [==============================] - 0s 851us/step - loss: 4069.6143 - r_squared: 0.9619 - rmse: 62.0497 - val_loss: 4012.3069 - val_r_squared: -inf - val_rmse: 67.4538
# Epoch 41/200
# 25/25 [==============================] - 0s 835us/step - loss: 3912.6853 - r_squared: 0.9632 - rmse: 61.1877 - val_loss: 3682.1643 - val_r_squared: -inf - val_rmse: 63.8448
# Epoch 42/200
# 25/25 [==============================] - 0s 841us/step - loss: 3763.4485 - r_squared: 0.9638 - rmse: 60.1853 - val_loss: 4562.7114 - val_r_squared: -inf - val_rmse: 72.4855
# Epoch 43/200
# 25/25 [==============================] - 0s 785us/step - loss: 4113.9331 - r_squared: 0.9611 - rmse: 63.4067 - val_loss: 3726.1245 - val_r_squared: -inf - val_rmse: 64.1812
# Epoch 44/200
# 25/25 [==============================] - 0s 806us/step - loss: 3965.1975 - r_squared: 0.9625 - rmse: 61.3566 - val_loss: 3718.3774 - val_r_squared: -inf - val_rmse: 64.3003
# Epoch 45/200
# 25/25 [==============================] - 0s 784us/step - loss: 3962.7285 - r_squared: 0.9628 - rmse: 60.9968 - val_loss: 4113.7139 - val_r_squared: -inf - val_rmse: 68.6136
# Epoch 46/200
# 25/25 [==============================] - 0s 765us/step - loss: 4027.3386 - r_squared: 0.9631 - rmse: 61.4019 - val_loss: 3788.3887 - val_r_squared: -inf - val_rmse: 65.2028
# Epoch 47/200
# 25/25 [==============================] - 0s 815us/step - loss: 3931.5884 - r_squared: 0.9621 - rmse: 62.0252 - val_loss: 3526.4253 - val_r_squared: -inf - val_rmse: 62.9148
# Epoch 48/200
# 25/25 [==============================] - 0s 777us/step - loss: 10702.6816 - r_squared: 0.7067 - rmse: 92.6006 - val_loss: 830742.8750 - val_r_squared: -inf - val_rmse: 931.9061
# Epoch 49/200
# 25/25 [==============================] - 0s 781us/step - loss: 196745.3438 - r_squared: -0.9860 - rmse: 401.9739 - val_loss: 98342.5547 - val_r_squared: -inf - val_rmse: 313.7630
# Epoch 50/200
# 25/25 [==============================] - 0s 812us/step - loss: 63727.2148 - r_squared: 0.3999 - rmse: 249.7066 - val_loss: 48188.0859 - val_r_squared: -inf - val_rmse: 220.6143
# Epoch 51/200
# 25/25 [==============================] - 0s 783us/step - loss: 34109.5000 - r_squared: 0.6814 - rmse: 182.3207 - val_loss: 28343.6797 - val_r_squared: -inf - val_rmse: 167.1864
# Epoch 52/200
# 25/25 [==============================] - 0s 779us/step - loss: 23881.4941 - r_squared: 0.7542 - rmse: 154.7489 - val_loss: 20364.8359 - val_r_squared: -inf - val_rmse: 141.5874
# Epoch 53/200
# 25/25 [==============================] - 0s 795us/step - loss: 18266.1230 - r_squared: 0.8312 - rmse: 133.7497 - val_loss: 15834.4883 - val_r_squared: -inf - val_rmse: 125.3472
# Epoch 54/200
# 25/25 [==============================] - 0s 772us/step - loss: 14827.4385 - r_squared: 0.8592 - rmse: 121.7313 - val_loss: 12921.1250 - val_r_squared: -inf - val_rmse: 114.8072
# Epoch 55/200
# 25/25 [==============================] - 0s 784us/step - loss: 12283.6777 - r_squared: 0.8846 - rmse: 110.1786 - val_loss: 10745.6826 - val_r_squared: -inf - val_rmse: 102.8999
# Epoch 56/200
# 25/25 [==============================] - 0s 856us/step - loss: 10426.5039 - r_squared: 0.8980 - rmse: 101.5285 - val_loss: 10062.7256 - val_r_squared: -inf - val_rmse: 103.4028
# Epoch 57/200
# 25/25 [==============================] - 0s 781us/step - loss: 9085.0254 - r_squared: 0.9142 - rmse: 93.6004 - val_loss: 8115.9531 - val_r_squared: -inf - val_rmse: 90.9260
# Epoch 58/200
# 25/25 [==============================] - 0s 799us/step - loss: 7835.5571 - r_squared: 0.9261 - rmse: 88.5372 - val_loss: 7097.6641 - val_r_squared: -inf - val_rmse: 84.1623
# Epoch 59/200
# 25/25 [==============================] - 0s 798us/step - loss: 7080.2964 - r_squared: 0.9292 - rmse: 84.7117 - val_loss: 6697.2622 - val_r_squared: -inf - val_rmse: 82.2859
# Epoch 60/200
# 25/25 [==============================] - 0s 797us/step - loss: 6593.9688 - r_squared: 0.9359 - rmse: 80.4115 - val_loss: 6476.2905 - val_r_squared: -inf - val_rmse: 81.2506
# Epoch 61/200
# 25/25 [==============================] - 0s 828us/step - loss: 6293.3818 - r_squared: 0.9393 - rmse: 78.9610 - val_loss: 6020.9878 - val_r_squared: -inf - val_rmse: 77.8510
# Early stopping occurred at epoch 60
# Restoring model weights from the end of the best epoch.
# 4/4 [==============================] - 0s 771us/step - loss: 2921.4307 - r_squared: 0.9646 - rmse: 55.4464
# Test Loss (MSE): 2921.4306640625
# Test Accuracy: 96.46480083465576
# Test RMSE: 55.44636154174805

# %%
# Used to save the model
# model.compile(optimizer='adam', loss='mse')
# model.save('BestMethaneModel292-968-4nodes.h5')
# Out:
# /Users/benfunk/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

# Generate predictions on the test data
with tf.device('/GPU:0'):  # Optional
    y_pred = model.predict(x_test)

# Flatten y_test and y_pred for plotting
y_test_flat = y_test.numpy().flatten()
y_pred_flat = y_pred.flatten()

# Create scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(y_test_flat, y_pred_flat, alpha=0.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')

# Plot a 45-degree line for reference
plt.plot([-100, 1200], [-100, 1200], '--', color='gray')

plt.show()
# Out:
# 4/4 [==============================] - 0s 543us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = modelFinal.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 179us/step

# %%
# Generate a grid for contour plotting
resistance_range = np.linspace(0, 35, 1000)
rh_range = np.linspace(0, 70, 1000)
temp = 20

# Create a grid (meshgrid) of Resistance and Relative Humidity values
resistance_values, rh_values = np.meshgrid(resistance_range, rh_range)

# Flatten the 2D arrays to 1D arrays
flat_resistance = resistance_values.ravel()
flat_rh = rh_values.ravel()

# Create a constant array filled with the temperature value
flat_temp = np.full_like(flat_resistance, temp)

# Prepare the grid data for prediction
grid_data = np.column_stack((flat_resistance, flat_temp, flat_rh))
grid_data_tf = tf.convert_to_tensor(grid_data, dtype=tf.float32)

# Use the trained model to make predictions on the grid
with tf.device('/GPU:0'):
    pred_ppm = model.predict(grid_data_tf)

# Reshape the predicted data to match the grid shape
pred_ppm = pred_ppm.reshape(resistance_values.shape)

# Create contour plot
plt.figure(figsize=(12, 10))

# Defining color range limits
vmin_val = min(pred_ppm.min(), df['Target PPM'].min())
vmax_val = max(pred_ppm.max(), df['Target PPM'].max())

contour = plt.contourf(resistance_range, rh_range, pred_ppm, 50, cmap='viridis', vmin=vmin_val, vmax=vmax_val)
plt.colorbar(label='Predicted PPM')

# Overlay actual data points
filtered_df = df[(df['Temperature'] >= temp-5) & (df['Temperature'] <= temp+5)]

# Plotting
plt.scatter(filtered_df['Resistance'], filtered_df['RelativeHumidity'], c=filtered_df['Target PPM'], cmap='viridis', vmin=vmin_val, vmax=vmax_val)


# Labels and title
plt.xlabel('Resistance')
plt.ylabel('Relative Humidity')
plt.title('Contour plot with actual data overlayed')

plt.show()
# Out:
# 31250/31250 [==============================] - 6s 196us/step

# %%
try:
        # Try loading the model without compiling
    loadedModel = tf.keras.models.load_model(
            "/Users/benfunk/DataspellProjects/MethaneDataScience/Ben's Analysis/BestMethaneModel292-968-4nodes.keras",custom_objects={"mse_loss": mse_loss},compile=False)
        # Then, compile the model manually
    loadedModel.compile(optimizer='adam', loss=mse_loss)
except Exception as e2:
    print(f"Failed again due to: {e2}")

# %%
testData = pd.read_csv('../Raw Data/CorrectedLog.csv')
def placeholder_function(vout, vref):
    return (vref*(5-vout))/(vout*(5-vref))  # Example placeholder function

# Calculate the time difference in days since the first row (assuming each row is 5 seconds)
df1 = pd.DataFrame()
df2 = pd.DataFrame()
# Iterate through the Vout and Vref columns to create rr columns
for i in range(8):
    vout_col = f'Vout_{i}'
    vref_col = f'Vref_{i}'
    rr_col = f'rr_{i}'

    df1[rr_col] = testData.apply(lambda row: placeholder_function(row[vout_col], row[vref_col]), axis=1)
    df2[rr_col] = df1[rr_col].rolling(window=5000).mean()  # Apply rolling average


calculatedResistance = df2.mean(axis=1)


T = 23
H = 40

# New DataFrame to store calculated values
fixed_temp = pd.Series([T]*len(calculatedResistance), name='FixedTemp')
fixed_humid = pd.Series([H]*len(calculatedResistance), name='FixedHumid')

final_test_data = pd.concat([calculatedResistance.reset_index(drop=True), fixed_temp, fixed_humid], axis=1)

# Perform prediction
predictions = loadedModel.predict(final_test_data)
if len(predictions.shape) == 2 and predictions.shape[1] == 1:
    predictions = predictions.flatten()

# Create an index list
index_list = list(range(len(predictions)))
df2['Days'] = df['Days']
first_4_days_df = df2[df2['Days'] < 1]

# Calculate the mean of all columns for each of the first days
daily_averages = first_4_days_df[rr_col].mean(axis=1)
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(index_list, predictions+45, linestyle='-')
plt.xlabel('Index')
plt.ylabel('Predicted PPM')
plt.title('Line Plot of Predicted PPM using Neural Network')
plt.grid(True)
plt.show()
# Out:
# 17271/17271 [==============================] - 3s 182us/step
